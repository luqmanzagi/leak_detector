# %% [markdown]
# # Simple Analyzer for Leak Detector
# ## Give no Response for CMPS Version

# %%
import pandas as pd
import re
import os
from urllib.parse import urlparse

# %%
def print_leak_to_csv(df):
    """
    Check dataframe if there are colomn with name: url_leaks, referer_leaks,
    and post_leaks. If there are, then print the dataframe to csv file.

    :param df: dataframe

    :return: csv file with specific name
    """
  


    # if 'url_leaks' in df and 'referer_leaks' in df and 'post_leaks' in df:
    #     return df.to_csv(extract_date + '_print_raw_leaks.csv')
    if 'url_leaks' in df:
        return df.to_csv("data_seg/"+ extract_date + '_' + extract_type +'_print_url_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optin_url_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optout_url_leaks.csv')
    elif 'referer_leaks' in df:
        return df.to_csv("data_seg/"+ extract_date + '_' + extract_type + '_print_referer_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optin_referer_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optout_referer_leaks.csv')
    elif 'post_leaks' in df:
        return df.to_csv("data_seg/"+ extract_date + '_' + extract_type + '_print_post_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optin_post_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_opt_out_post_leaks.csv')

# %%
def extract_leak(data, leak):
    """
    extract data with when 'leak' row is not empty

    :param dataframe data: input dataframe
    :param str leak: column name

    :return: dataframe with non-empty 'leak' column
    """
 
    return data[(data['leaks'].str.contains(leak, na=False))]

# %%
def drop_non_leak(data, leak):
    """
    drop data that not related to the leak

    :param data: dataframe
    :param leak: column name

    :return: dataframe with non-empty 'leak' column
    """
    data_seed = extract_leak(data, leak)
    if leak == 'url_leaks':
        return data_seed.drop(['post_leaks', 'ref_data', 'referer_leaks', 'post_data'], axis=1)
    elif leak == 'referer_leaks':
        return data_seed.drop(['url_leaks', 'post_leaks', 'post_data'], axis=1)
    elif leak == 'post_leaks':
        return data_seed.drop(['url_leaks', 'referer_leaks', 'ref_data'], axis=1)

# %%
def check_urlparse(row):
    """check if the referer_leaks contain the netloc, path, params, query, and fragment from the final_url

    :param row: row of dataframe

    :return: dictionary of the referer_leaks
    """
    parsed_url = urlparse(row['final_url'])
    parsed_url_list = [parsed_url.netloc, parsed_url.path, parsed_url.params, parsed_url.query, parsed_url.fragment]
    # print(parsed_url_list)
    if 'referer_leaks' in row:    
        desired_list = row['referer_leaks'].split("'") 
    elif 'url_leaks' in row:
        desired_list = row['url_leaks'].split("'")
    elif 'post_leaks' in row:
        desired_list = row['post_leaks'].split("'")
    # print (desired_list)
    undesired_list = ['[', 
                    ']', 
                    ',', 
                    'None', 
                    '', 
                    '[(',
                    ')]', 
                    ',)]',
                    '), (',
                    ', ']
    result = {}
    netloc, path, query ,params, fragments = '', '', '', '', ''
    for item in desired_list:
        if item not in undesired_list:
            if item in parsed_url_list:
                if item == parsed_url.netloc:
                    netloc = parsed_url.netloc
                if item == parsed_url.path:
                    path = parsed_url.path
                if item == parsed_url.query:
                    query = parsed_url.query
                # it should be not include in referer 
                if item == parsed_url.params:
                    params = parsed_url.params
                if item == parsed_url.fragment:
                    fragments = parsed_url.fragment

    return netloc, path, query, params, fragments

# %%
def check_violation(row):
    """
    Check if the referer_leaks violate the policy or not

    :param dataframe row: a dataframe row that contain "ref_pol_data" colomn as
    the referer policy and check if the referer_leaks violate the policy or not

    :return str: Send "Violation" if the referer_leaks violate the policy,
    send "Safe" if the referer_leaks is safe, send "Warning" if the referer_leaks
    """
    ref_pol = row['ref_pol_data']
    if ((row ['params']) or (row ['fragments'])):
        return "Warning"
    match ref_pol:
        case 'no-referrer':
            if ((row ['netloc']) or (row ['path']) or (row ['query'])):
                return "Violation"
            else:
                return "Safe"
        case 'same-origin':
            if ((row ['netloc']) or (row ['path']) or (row ['query'])):
                return "Violation"
            else:  
                return "Safe"
        case 'no-referrer-when-downgrade':
            return "Safe"
        case 'unsafe-url':
            return "Safe"
        case 'origin':
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:
                return "Safe"
        case 'origin-when-cross-origin':
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:   
                return "Safe"
        case 'strict-origin' :
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:   
                return "Safe"
        case 'strict-origin-when-cross-origin':
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:
                return "Safe"
        case _:
            return "Blank"

# %% [markdown]
# ## Convert CSV to Dataframe

# %%
csv_file = './data_raw/2023-12-07_non_leaks_raw.csv'
# csv_file = './data_raw/2023-11-29_optIn_leaks_raw.csv'
# csv_file = './data_raw/test.csv'
extract_type = csv_file.split("_")[2]

extract_date = re.findall(r'20(.*?)_', csv_file)
extract_date = ''.join(extract_date)  # Convert the list to a string

os.makedirs("data_seg", exist_ok=True)

extracted_df = pd.read_csv(csv_file)
extracted_df
# Out:
#                                                 init_url  \
# 0                          https://www.ox.ac.uk/research
# 1                          https://www.ox.ac.uk/research
# 2                          https://www.ox.ac.uk/research
# 3                          https://www.ox.ac.uk/research
# 4                          https://www.ox.ac.uk/research
# ...                                                  ...
# 103296  https://www.mbga.jp/_game_intro?game_id=12016007
# 103297  https://www.mbga.jp/_game_intro?game_id=12016007
# 103298  https://www.mbga.jp/_game_intro?game_id=12016007
# 103299  https://www.mbga.jp/_game_intro?game_id=12016007
# 103300  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 103296  https://www.andapp.jp/apps/12016007?from=www_m...
# 103297  https://www.andapp.jp/apps/12016007?from=www_m...
# 103298  https://www.andapp.jp/apps/12016007?from=www_m...
# 103299  https://www.andapp.jp/apps/12016007?from=www_m...
# 103300  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 0       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...        GET
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 3       https://apikeys.civiccomputing.com/c/v?d=www.o...        GET
# 4       https://www.linkedin.com/px/li_sync?redirect=h...        GET
# ...                                                   ...        ...
# 103296  https://6015542.fls.doubleclick.net/ddm/fls/r/...        GET
# 103297  https://www.google.com/pagead/1p-user-list/878...        GET
# 103298  https://aw.dw.impact-ad.jp/ut/rep?u=2714&v=2&r...        GET
# 103299  https://www.youtube.com/youtubei/v1/log_event?...       POST
# 103300                https://id5-sync.com/g/v2/1270.json       POST
#
#                            ref_pol_data  \
# 0       strict-origin-when-cross-origin
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 3       strict-origin-when-cross-origin
# 4       strict-origin-when-cross-origin
# ...                                 ...
# 103296  strict-origin-when-cross-origin
# 103297  strict-origin-when-cross-origin
# 103298  strict-origin-when-cross-origin
# 103299  strict-origin-when-cross-origin
# 103300  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 0                                   https://www.ox.ac.uk/
# 1                                   https://www.ox.ac.uk/
# 2                                   https://www.ox.ac.uk/
# 3                                   https://www.ox.ac.uk/
# 4                                   https://www.ox.ac.uk/
# ...                                                   ...
# 103296               https://6015542.fls.doubleclick.net/
# 103297                             https://www.andapp.jp/
# 103298               https://6015542.fls.doubleclick.net/
# 103299  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103300               https://6015542.fls.doubleclick.net/
#
#                                                 post_data  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 103296                                                NaN
# 103297                                                NaN
# 103298                                                NaN
# 103299  {"context":{"client":{"hl":"en","gl":"US","cli...
# 103300  {"partner":1270,"v":"1.0.36","o":"api","tml":"...
#
#                                                 url_leaks  \
# 0       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 1       [('urlencode', '/research'), ('urlencode', 'ww...
# 2       [('urlencode', '/research'), ('urlencode', 'ww...
# 3       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 4       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 103296                               [('www.andapp.jp',)]
# 103297  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103298  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103299                                                 []
# 103300                                                 []
#
#                   post_leaks  \
# 0                         []
# 1                         []
# 2                         []
# 3                         []
# 4                         []
# ...                      ...
# 103296                    []
# 103297                    []
# 103298                    []
# 103299  [('www.andapp.jp',)]
# 103300  [('www.andapp.jp',)]
#
#                                             referer_leaks  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 103296                                                 []
# 103297                                                 []
# 103298                                                 []
# 103299  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103300                                                 []
#
#                              leaks
# 0                        url_leaks
# 1                        url_leaks
# 2                        url_leaks
# 3                        url_leaks
# 4                        url_leaks
# ...                            ...
# 103296                   url_leaks
# 103297                   url_leaks
# 103298                   url_leaks
# 103299  post_leaks - referer_leaks
# 103300                  post_leaks
#
# [103301 rows x 11 columns]

# %% [markdown]
# ## Leaks on Referer
#
# We still need to compare with the referrer policy to make it accurate

# %%
# create a new dataframe with non-empty 'referer_leaks' column
referer_leaks_df = drop_non_leak(extracted_df, 'referer_leaks')
referer_leaks_df
# Out:
#                                                 init_url  \
# 5                          https://www.ox.ac.uk/research
# 6                          https://www.ox.ac.uk/research
# 7                          https://www.ox.ac.uk/research
# 20                         https://www.ox.ac.uk/research
# 21                         https://www.ox.ac.uk/research
# ...                                                  ...
# 103287  https://www.mbga.jp/_game_intro?game_id=12016007
# 103288  https://www.mbga.jp/_game_intro?game_id=12016007
# 103289  https://www.mbga.jp/_game_intro?game_id=12016007
# 103291  https://www.mbga.jp/_game_intro?game_id=12016007
# 103299  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 5                           https://www.ox.ac.uk/research
# 6                           https://www.ox.ac.uk/research
# 7                           https://www.ox.ac.uk/research
# 20                          https://www.ox.ac.uk/research
# 21                          https://www.ox.ac.uk/research
# ...                                                   ...
# 103287  https://www.andapp.jp/apps/12016007?from=www_m...
# 103288  https://www.andapp.jp/apps/12016007?from=www_m...
# 103289  https://www.andapp.jp/apps/12016007?from=www_m...
# 103291  https://www.andapp.jp/apps/12016007?from=www_m...
# 103299  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 5       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 6       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 7       https://www.youtube.com/s/player/dee96cfa/play...        GET
# 20      https://www.youtube.com/youtubei/v1/player?key...       POST
# 21      https://www.youtube.com/s/player/dee96cfa/play...        GET
# ...                                                   ...        ...
# 103287  https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 103288  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 103289  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 103291        https://www.youtube.com/generate_204?0fnMlA        GET
# 103299  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 5       strict-origin-when-cross-origin
# 6       strict-origin-when-cross-origin
# 7       strict-origin-when-cross-origin
# 20      strict-origin-when-cross-origin
# 21      strict-origin-when-cross-origin
# ...                                 ...
# 103287  strict-origin-when-cross-origin
# 103288  strict-origin-when-cross-origin
# 103289  strict-origin-when-cross-origin
# 103291  strict-origin-when-cross-origin
# 103299  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 5       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 6       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 7       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 20      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 21      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# ...                                                   ...
# 103287  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103288  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103289  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103291  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103299  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 5       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 6       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 7       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 20      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 21      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 103287  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103288  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103289  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103291  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103299  [('www.andapp.jp',), ('urlencode', 'www.andapp...
#
#                              leaks
# 5                    referer_leaks
# 6                    referer_leaks
# 7                    referer_leaks
# 20      post_leaks - referer_leaks
# 21                   referer_leaks
# ...                            ...
# 103287               referer_leaks
# 103288               referer_leaks
# 103289               referer_leaks
# 103291               referer_leaks
# 103299  post_leaks - referer_leaks
#
# [54495 rows x 8 columns]

# %%
# show the dataframe with more than one leaks in "leaks" colomn
referer_leaks_df[referer_leaks_df['leaks'] != "referer_leaks"]
# Out:
#                                                  init_url  \
# 20                          https://www.ox.ac.uk/research
# 28                          https://www.ox.ac.uk/research
# 30                          https://www.ox.ac.uk/research
# 32                          https://www.ox.ac.uk/research
# 35                          https://www.ox.ac.uk/research
# ...                                                   ...
# 103003                 https://mashable.com/entertainment
# 103006                 https://mashable.com/entertainment
# 103013                 https://mashable.com/entertainment
# 103113  https://www.mcafee.com/en-us/consumer-corporat...
# 103299   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 20                          https://www.ox.ac.uk/research
# 28                          https://www.ox.ac.uk/research
# 30                          https://www.ox.ac.uk/research
# 32                          https://www.ox.ac.uk/research
# 35                          https://www.ox.ac.uk/research
# ...                                                   ...
# 103003                 https://mashable.com/entertainment
# 103006                 https://mashable.com/entertainment
# 103013                 https://mashable.com/entertainment
# 103113  https://www.mcafee.com/en-us/consumer-corporat...
# 103299  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 20      https://www.youtube.com/youtubei/v1/player?key...       POST
# 28      https://www.youtube.com/youtubei/v1/player?key...       POST
# 30      https://www.youtube.com/youtubei/v1/player?key...       POST
# 32      https://www.youtube.com/api/stats/qoe?fmt=247&...       POST
# 35      https://www.youtube.com/youtubei/v1/next?key=A...       POST
# ...                                                   ...        ...
# 103003  https://gum.criteo.com/sid/json?origin=publish...        GET
# 103006  https://stags.bluekai.com/site/30629?ret=html&...        GET
# 103013  https://ping.chartbeat.net/ping?h=mashable.com...        GET
# 103113  https://adobedc.demdex.net/ee/v1/interact?conf...       POST
# 103299  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 20      strict-origin-when-cross-origin
# 28      strict-origin-when-cross-origin
# 30      strict-origin-when-cross-origin
# 32      strict-origin-when-cross-origin
# 35      strict-origin-when-cross-origin
# ...                                 ...
# 103003  strict-origin-when-cross-origin
# 103006       no-referrer-when-downgrade
# 103013       no-referrer-when-downgrade
# 103113       no-referrer-when-downgrade
# 103299  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 20      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 28      https://www.youtube.com/embed/ogkc1FmfiuI?wmod...
# 30      https://www.youtube.com/embed/MJNz9_M3kFg?wmod...
# 32      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 35      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# ...                                                   ...
# 103003  https://gum.criteo.com/syncframe?origin=publis...
# 103006                 https://mashable.com/entertainment
# 103013                 https://mashable.com/entertainment
# 103113  https://www.mcafee.com/en-us/consumer-corporat...
# 103299  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 20      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 28      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 30      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 32      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 35      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 103003  [('mashable.com',), ('urlencode', 'mashable.co...
# 103006                              [('/entertainment',)]
# 103013                              [('/entertainment',)]
# 103113    [('/en-us/consumer-corporate/investors.html',)]
# 103299  [('www.andapp.jp',), ('urlencode', 'www.andapp...
#
#                              leaks
# 20      post_leaks - referer_leaks
# 28      post_leaks - referer_leaks
# 30      post_leaks - referer_leaks
# 32       url_leaks - referer_leaks
# 35      post_leaks - referer_leaks
# ...                            ...
# 103003   url_leaks - referer_leaks
# 103006   url_leaks - referer_leaks
# 103013   url_leaks - referer_leaks
# 103113  post_leaks - referer_leaks
# 103299  post_leaks - referer_leaks
#
# [13160 rows x 8 columns]

# %%
#expand the dataframe with the result from check_urlparse function
referer_leaks_df[['netloc', 'path', 'query', 'params', 'fragments']] = referer_leaks_df.apply(check_urlparse, axis=1, result_type='expand')
referer_leaks_df
# Out:
#                                                 init_url  \
# 5                          https://www.ox.ac.uk/research
# 6                          https://www.ox.ac.uk/research
# 7                          https://www.ox.ac.uk/research
# 20                         https://www.ox.ac.uk/research
# 21                         https://www.ox.ac.uk/research
# ...                                                  ...
# 103287  https://www.mbga.jp/_game_intro?game_id=12016007
# 103288  https://www.mbga.jp/_game_intro?game_id=12016007
# 103289  https://www.mbga.jp/_game_intro?game_id=12016007
# 103291  https://www.mbga.jp/_game_intro?game_id=12016007
# 103299  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 5                           https://www.ox.ac.uk/research
# 6                           https://www.ox.ac.uk/research
# 7                           https://www.ox.ac.uk/research
# 20                          https://www.ox.ac.uk/research
# 21                          https://www.ox.ac.uk/research
# ...                                                   ...
# 103287  https://www.andapp.jp/apps/12016007?from=www_m...
# 103288  https://www.andapp.jp/apps/12016007?from=www_m...
# 103289  https://www.andapp.jp/apps/12016007?from=www_m...
# 103291  https://www.andapp.jp/apps/12016007?from=www_m...
# 103299  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 5       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 6       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 7       https://www.youtube.com/s/player/dee96cfa/play...        GET
# 20      https://www.youtube.com/youtubei/v1/player?key...       POST
# 21      https://www.youtube.com/s/player/dee96cfa/play...        GET
# ...                                                   ...        ...
# 103287  https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 103288  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 103289  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 103291        https://www.youtube.com/generate_204?0fnMlA        GET
# 103299  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 5       strict-origin-when-cross-origin
# 6       strict-origin-when-cross-origin
# 7       strict-origin-when-cross-origin
# 20      strict-origin-when-cross-origin
# 21      strict-origin-when-cross-origin
# ...                                 ...
# 103287  strict-origin-when-cross-origin
# 103288  strict-origin-when-cross-origin
# 103289  strict-origin-when-cross-origin
# 103291  strict-origin-when-cross-origin
# 103299  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 5       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 6       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 7       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 20      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 21      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# ...                                                   ...
# 103287  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103288  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103289  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103291  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103299  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 5       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 6       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 7       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 20      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 21      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 103287  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103288  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103289  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103291  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103299  [('www.andapp.jp',), ('urlencode', 'www.andapp...
#
#                              leaks         netloc path query params fragments
# 5                    referer_leaks   www.ox.ac.uk
# 6                    referer_leaks   www.ox.ac.uk
# 7                    referer_leaks   www.ox.ac.uk
# 20      post_leaks - referer_leaks   www.ox.ac.uk
# 21                   referer_leaks   www.ox.ac.uk
# ...                            ...            ...  ...   ...    ...       ...
# 103287               referer_leaks  www.andapp.jp
# 103288               referer_leaks  www.andapp.jp
# 103289               referer_leaks  www.andapp.jp
# 103291               referer_leaks  www.andapp.jp
# 103299  post_leaks - referer_leaks  www.andapp.jp
#
# [54495 rows x 13 columns]

# %%
# create a new colomn with the result from check_violation function
referer_leaks_df['violation'] = referer_leaks_df.apply(check_violation, axis=1, result_type='expand')
referer_leaks_df
# Out:
#                                                 init_url  \
# 5                          https://www.ox.ac.uk/research
# 6                          https://www.ox.ac.uk/research
# 7                          https://www.ox.ac.uk/research
# 20                         https://www.ox.ac.uk/research
# 21                         https://www.ox.ac.uk/research
# ...                                                  ...
# 103287  https://www.mbga.jp/_game_intro?game_id=12016007
# 103288  https://www.mbga.jp/_game_intro?game_id=12016007
# 103289  https://www.mbga.jp/_game_intro?game_id=12016007
# 103291  https://www.mbga.jp/_game_intro?game_id=12016007
# 103299  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 5                           https://www.ox.ac.uk/research
# 6                           https://www.ox.ac.uk/research
# 7                           https://www.ox.ac.uk/research
# 20                          https://www.ox.ac.uk/research
# 21                          https://www.ox.ac.uk/research
# ...                                                   ...
# 103287  https://www.andapp.jp/apps/12016007?from=www_m...
# 103288  https://www.andapp.jp/apps/12016007?from=www_m...
# 103289  https://www.andapp.jp/apps/12016007?from=www_m...
# 103291  https://www.andapp.jp/apps/12016007?from=www_m...
# 103299  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 5       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 6       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 7       https://www.youtube.com/s/player/dee96cfa/play...        GET
# 20      https://www.youtube.com/youtubei/v1/player?key...       POST
# 21      https://www.youtube.com/s/player/dee96cfa/play...        GET
# ...                                                   ...        ...
# 103287  https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 103288  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 103289  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 103291        https://www.youtube.com/generate_204?0fnMlA        GET
# 103299  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 5       strict-origin-when-cross-origin
# 6       strict-origin-when-cross-origin
# 7       strict-origin-when-cross-origin
# 20      strict-origin-when-cross-origin
# 21      strict-origin-when-cross-origin
# ...                                 ...
# 103287  strict-origin-when-cross-origin
# 103288  strict-origin-when-cross-origin
# 103289  strict-origin-when-cross-origin
# 103291  strict-origin-when-cross-origin
# 103299  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 5       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 6       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 7       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 20      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 21      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# ...                                                   ...
# 103287  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103288  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103289  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103291  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 103299  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 5       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 6       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 7       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 20      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 21      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 103287  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103288  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103289  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103291  [('www.andapp.jp',), ('urlencode', 'www.andapp...
# 103299  [('www.andapp.jp',), ('urlencode', 'www.andapp...
#
#                              leaks         netloc path query params fragments  \
# 5                    referer_leaks   www.ox.ac.uk
# 6                    referer_leaks   www.ox.ac.uk
# 7                    referer_leaks   www.ox.ac.uk
# 20      post_leaks - referer_leaks   www.ox.ac.uk
# 21                   referer_leaks   www.ox.ac.uk
# ...                            ...            ...  ...   ...    ...       ...
# 103287               referer_leaks  www.andapp.jp
# 103288               referer_leaks  www.andapp.jp
# 103289               referer_leaks  www.andapp.jp
# 103291               referer_leaks  www.andapp.jp
# 103299  post_leaks - referer_leaks  www.andapp.jp
#
#        violation
# 5           Safe
# 6           Safe
# 7           Safe
# 20          Safe
# 21          Safe
# ...          ...
# 103287      Safe
# 103288      Safe
# 103289      Safe
# 103291      Safe
# 103299      Safe
#
# [54495 rows x 14 columns]

# %%
# Check wheter the params or fragments leak on referrer 
referer_leaks_df[referer_leaks_df['violation'] == "Warning"]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, ref_data, referer_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %% [markdown]
# ### Referer Leaks that did not follow referer policy
#
# This case is similar with the youtube case. Maybe, it's an TRC error.
# But it's also possible that there is a problem from Chrome

# %%
referer_leaks_vioilation_df = referer_leaks_df[referer_leaks_df['violation'] == "Violation"]
referer_leaks_vioilation_df.to_csv("data_seg/"+ extract_date + '_' + extract_type + '_print_referer_leaks_violation.csv')
referer_leaks_vioilation_df
# Out:
#                                             init_url  \
# 853      https://wpengine.com/agency-partner-program
# 854      https://wpengine.com/agency-partner-program
# 855      https://wpengine.com/agency-partner-program
# 858      https://wpengine.com/agency-partner-program
# 859      https://wpengine.com/agency-partner-program
# ...                                              ...
# 103218  https://www.docker.com/products/docker-scout
# 103219  https://www.docker.com/products/docker-scout
# 103229  https://www.docker.com/products/docker-scout
# 103230  https://www.docker.com/products/docker-scout
# 103231  https://www.docker.com/products/docker-scout
#
#                                             final_url  \
# 853      https://wpengine.com/agency-partner-program/
# 854      https://wpengine.com/agency-partner-program/
# 855      https://wpengine.com/agency-partner-program/
# 858      https://wpengine.com/agency-partner-program/
# 859      https://wpengine.com/agency-partner-program/
# ...                                               ...
# 103218  https://www.docker.com/products/docker-scout/
# 103219  https://www.docker.com/products/docker-scout/
# 103229  https://www.docker.com/products/docker-scout/
# 103230  https://www.docker.com/products/docker-scout/
# 103231  https://www.docker.com/products/docker-scout/
#
#                                                   req_url req_method  \
# 853     https://js.driftt.com/core/assets/js/runtime~m...        GET
# 854     https://js.driftt.com/core/assets/js/9.4a3e980...        GET
# 855     https://js.driftt.com/core/assets/js/main~493d...        GET
# 858     https://js.driftt.com/core/assets/js/51.558be3...        GET
# 859     https://js.driftt.com/core/assets/js/35.d0f1cc...        GET
# ...                                                   ...        ...
# 103218  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 103219  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 103229  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 103230  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 103231  https://rc-widget-frame.js.driftt.com/core/ass...        GET
#
#                            ref_pol_data  \
# 853     strict-origin-when-cross-origin
# 854     strict-origin-when-cross-origin
# 855     strict-origin-when-cross-origin
# 858     strict-origin-when-cross-origin
# 859     strict-origin-when-cross-origin
# ...                                 ...
# 103218  strict-origin-when-cross-origin
# 103219  strict-origin-when-cross-origin
# 103229  strict-origin-when-cross-origin
# 103230  strict-origin-when-cross-origin
# 103231  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 853     https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 854     https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 855     https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 858     https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 859     https://js.driftt.com/core?d=1&embedId=5hrxis5...
# ...                                                   ...
# 103218  https://rc-widget-frame.js.driftt.com/core?d=1...
# 103219  https://rc-widget-frame.js.driftt.com/core?d=1...
# 103229  https://rc-widget-frame.js.driftt.com/core?d=1...
# 103230  https://rc-widget-frame.js.driftt.com/core?d=1...
# 103231  https://rc-widget-frame.js.driftt.com/core?d=1...
#
#                                             referer_leaks          leaks  \
# 853     [('urlencode', 'wpengine.com'), ('wpengine.com...  referer_leaks
# 854     [('urlencode', 'wpengine.com'), ('wpengine.com...  referer_leaks
# 855     [('urlencode', 'wpengine.com'), ('wpengine.com...  referer_leaks
# 858     [('urlencode', 'wpengine.com'), ('wpengine.com...  referer_leaks
# 859     [('urlencode', 'wpengine.com'), ('wpengine.com...  referer_leaks
# ...                                                   ...            ...
# 103218  [('www.docker.com',), ('urlencode', '/products...  referer_leaks
# 103219  [('www.docker.com',), ('urlencode', '/products...  referer_leaks
# 103229  [('www.docker.com',), ('urlencode', '/products...  referer_leaks
# 103230  [('www.docker.com',), ('urlencode', '/products...  referer_leaks
# 103231  [('www.docker.com',), ('urlencode', '/products...  referer_leaks
#
#                 netloc                      path query params fragments  \
# 853       wpengine.com  /agency-partner-program/
# 854       wpengine.com  /agency-partner-program/
# 855       wpengine.com  /agency-partner-program/
# 858       wpengine.com  /agency-partner-program/
# 859       wpengine.com  /agency-partner-program/
# ...                ...                       ...   ...    ...       ...
# 103218  www.docker.com   /products/docker-scout/
# 103219  www.docker.com   /products/docker-scout/
# 103229  www.docker.com   /products/docker-scout/
# 103230  www.docker.com   /products/docker-scout/
# 103231  www.docker.com   /products/docker-scout/
#
#         violation
# 853     Violation
# 854     Violation
# 855     Violation
# 858     Violation
# 859     Violation
# ...           ...
# 103218  Violation
# 103219  Violation
# 103229  Violation
# 103230  Violation
# 103231  Violation
#
# [2759 rows x 14 columns]

# %%
print_leak_to_csv(referer_leaks_vioilation_df)

# %%
referer_leaks_vioilation_df.count()
# Out:
# init_url         2759
# final_url        2759
# req_url          2759
# req_method       2759
# ref_pol_data     2759
# ref_data         2759
# referer_leaks    2759
# leaks            2759
# netloc           2759
# path             2759
# query            2759
# params           2759
# fragments        2759
# violation        2759
# dtype: int64

# %%
referer_leaks_vioilation_df.drop_duplicates(subset=['final_url']).count()
# Out:
# init_url         205
# final_url        205
# req_url          205
# req_method       205
# ref_pol_data     205
# ref_data         205
# referer_leaks    205
# leaks            205
# netloc           205
# path             205
# query            205
# params           205
# fragments        205
# violation        205
# dtype: int64

# %%
referer_leaks_vioilation_df.final_url.value_counts()
# Out:
# https://www.parse.ly/getdemo/                                                                                                         88
# https://www.docker.com/products/docker-scout/                                                                                         41
# https://www.docker.com/careers/                                                                                                       41
# https://www.docker.com/resources/what-container/                                                                                      41
# https://www.docker.com/why-docker/                                                                                                    41
#                                                                                                                                       ..
# https://tenki.jp/pm25/                                                                                                                 1
# https://www.criteo.com/get-started/                                                                                                    1
# https://www.wsj.com/articles/how-you-can-use-social-media-to-support-evan-gershkovich-c7bb2167?mod=hp_theme_evangershkovich-ribbon     1
# https://www.kargo.com/contact-us                                                                                                       1
# https://www.wikihow.com/Study-Efficiently                                                                                              1
# Name: final_url, Length: 205, dtype: int64

# %%
referer_leaks_vioilation_df.req_url.value_counts()
# Out:
# https://s.yimg.jp/images/advertising/common/js/iicon.min.js                                                                                                   67
# https://js.driftt.com/core/assets/js/runtime~main.95493482.js                                                                                                 52
# https://js.driftt.com/core/assets/css/8.7602338c.chunk.css                                                                                                    52
# https://js.driftt.com/core/assets/js/9.4a3e9801.chunk.js                                                                                                      52
# https://js.driftt.com/core/assets/js/57.28dde8ce.chunk.js                                                                                                     52
#                                                                                                                                                               ..
# https://platform.twitter.com/embed/embed.ondemand.i18n.fr-js.5f978eb0eb74beba794d.js                                                                           1
# https://platform.twitter.com/embed/embed.ondemand.horizon-web.i18n.fr-js.9d35cf0ad9d16371806d.js                                                               1
# https://asia.creativecdn.com/topics-membership?ntk=WGWbURufYgRBaINXdRtLfVaKUedhX4Nf_B8VPm7adW9aZCzWc5bNq66beHQrz3pY0j64S9hgUf-6jCm4dyJRAA                      1
# https://asia.creativecdn.com/ig-membership?ntk=j0M2GhXalnpkIACzfoHtStTMztZpkmSeSlQqzgeRwkftTwj8H_iuiAJpf7oij0rJ-jrjLLTIkjZytrrYW1QUsWj3eVBDjHkYZDkT20YoT1Y     1
# https://lichess1.org/assets/_atroEr/images/icons/trash.svg                                                                                                     1
# Name: req_url, Length: 326, dtype: int64

# %%
referer_leaks_vioilation_df.req_method.value_counts()
# Out:
# GET     2737
# POST      22
# Name: req_method, dtype: int64

# %% [markdown]
# ### Google

# %%
# list of referer leaks to google
referer_leaks_vioilation_df[referer_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)]
# Out:
#                                                  init_url  \
# 10621                     https://www.india.com/rajasthan
# 10622                     https://www.india.com/rajasthan
# 16423   https://www.wikihow.com/make-christmas-come-fa...
# 22034   https://www.investopedia.com/the-american-drea...
# 22047   https://www.investopedia.com/the-american-drea...
# 22048   https://www.investopedia.com/the-american-drea...
# 22053   https://www.investopedia.com/the-american-drea...
# 22054   https://www.investopedia.com/the-american-drea...
# 27869                 https://www.fmkorea.com/fm24players
# 38224                    https://www.fmkorea.com/fm23tips
# 38225                    https://www.fmkorea.com/fm23tips
# 38226                    https://www.fmkorea.com/fm23tips
# 43612                         https://tenki.jp/forecast/4
# 43617                         https://tenki.jp/forecast/4
# 46441     https://www.youtube.com/@cozycoffeeshopofficial
# 50781                 https://www.fmkorea.com/fm23players
# 50782                 https://www.fmkorea.com/fm23players
# 56328                               https://tenki.jp/pm25
# 63129            https://www.dafont.com/theme.php?cat=403
# 66750           https://www.wikihow.com/study-efficiently
# 75657   https://www.haberler.com/ekonomi/nas-gerekcesi...
# 85850               https://www.wikihow.com/future-faking
# 85852               https://www.wikihow.com/future-faking
# 88420   https://www.cnnindonesia.com/nasional/20231206...
# 94046   https://www.haberler.com/3-sayfa/oktay-derelio...
# 94081   https://www.haberler.com/3-sayfa/oktay-derelio...
# 94082   https://www.haberler.com/3-sayfa/oktay-derelio...
# 97377                    https://www.fmkorea.com/fm23tqna
# 97379                    https://www.fmkorea.com/fm23tqna
# 97380                    https://www.fmkorea.com/fm23tqna
# 100408                        https://www.india.com/bihar
# 100756  https://apkpure.com/loklok-dramas-movies/com.a...
# 100757  https://apkpure.com/loklok-dramas-movies/com.a...
#
#                                                 final_url  \
# 10621                    https://www.india.com/rajasthan/
# 10622                    https://www.india.com/rajasthan/
# 16423   https://www.wikihow.com/Make-Christmas-Come-Fa...
# 22034   https://www.investopedia.com/the-american-drea...
# 22047   https://www.investopedia.com/the-american-drea...
# 22048   https://www.investopedia.com/the-american-drea...
# 22053   https://www.investopedia.com/the-american-drea...
# 22054   https://www.investopedia.com/the-american-drea...
# 27869                 https://www.fmkorea.com/fm24players
# 38224                    https://www.fmkorea.com/fm23tips
# 38225                    https://www.fmkorea.com/fm23tips
# 38226                    https://www.fmkorea.com/fm23tips
# 43612                        https://tenki.jp/forecast/4/
# 43617                        https://tenki.jp/forecast/4/
# 46441     https://www.youtube.com/@cozycoffeeshopofficial
# 50781                 https://www.fmkorea.com/fm23players
# 50782                 https://www.fmkorea.com/fm23players
# 56328                              https://tenki.jp/pm25/
# 63129            https://www.dafont.com/theme.php?cat=403
# 66750           https://www.wikihow.com/Study-Efficiently
# 75657   https://www.haberler.com/ekonomi/nas-gerekcesi...
# 85850               https://www.wikihow.com/Future-Faking
# 85852               https://www.wikihow.com/Future-Faking
# 88420   https://www.cnnindonesia.com/nasional/20231206...
# 94046   https://www.haberler.com/3-sayfa/oktay-derelio...
# 94081   https://www.haberler.com/3-sayfa/oktay-derelio...
# 94082   https://www.haberler.com/3-sayfa/oktay-derelio...
# 97377                    https://www.fmkorea.com/fm23tqna
# 97379                    https://www.fmkorea.com/fm23tqna
# 97380                    https://www.fmkorea.com/fm23tqna
# 100408                       https://www.india.com/bihar/
# 100756  https://apkpure.com/loklok-dramas-movies/com.a...
# 100757  https://apkpure.com/loklok-dramas-movies/com.a...
#
#                                                   req_url req_method  \
# 10621   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 10622   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 16423   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 22034   https://live-tag.creatopy.net/designs/l8z5yn8/...        GET
# 22047   https://live-tag.creatopy.net/designs/l8z5yn8/...        GET
# 22048   https://live-tag.creatopy.net/designs/l8z5yn8/...        GET
# 22053   https://live-tag.creatopy.net/designs/l8z5yn8/...        GET
# 22054   https://live-tag.creatopy.net/designs/l8z5yn8/...        GET
# 27869   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 38224   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 38225   https://googleads.g.doubleclick.net/dbm/ad?dbm...        GET
# 38226   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 43612   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 43617   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 46441   https://googleads.g.doubleclick.net/pagead/vie...        GET
# 50781   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 50782   https://googleads.g.doubleclick.net/dbm/ad?dbm...        GET
# 56328   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 63129   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 66750   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 75657   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 85850   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 85852   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 88420   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 94046   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 94081   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 94082   https://googleads.g.doubleclick.net/dbm/ad?dbm...        GET
# 97377   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 97379   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 97380   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 100408  https://googleads.g.doubleclick.net/pagead/adv...        GET
# 100756  https://googleads.g.doubleclick.net/pagead/adv...        GET
# 100757  https://googleads.g.doubleclick.net/pagead/drt...        GET
#
#                            ref_pol_data  \
# 10621   strict-origin-when-cross-origin
# 10622   strict-origin-when-cross-origin
# 16423   strict-origin-when-cross-origin
# 22034   strict-origin-when-cross-origin
# 22047   strict-origin-when-cross-origin
# 22048   strict-origin-when-cross-origin
# 22053   strict-origin-when-cross-origin
# 22054   strict-origin-when-cross-origin
# 27869   strict-origin-when-cross-origin
# 38224   strict-origin-when-cross-origin
# 38225   strict-origin-when-cross-origin
# 38226   strict-origin-when-cross-origin
# 43612   strict-origin-when-cross-origin
# 43617   strict-origin-when-cross-origin
# 46441   strict-origin-when-cross-origin
# 50781   strict-origin-when-cross-origin
# 50782   strict-origin-when-cross-origin
# 56328   strict-origin-when-cross-origin
# 63129   strict-origin-when-cross-origin
# 66750   strict-origin-when-cross-origin
# 75657   strict-origin-when-cross-origin
# 85850   strict-origin-when-cross-origin
# 85852   strict-origin-when-cross-origin
# 88420   strict-origin-when-cross-origin
# 94046   strict-origin-when-cross-origin
# 94081   strict-origin-when-cross-origin
# 94082   strict-origin-when-cross-origin
# 97377   strict-origin-when-cross-origin
# 97379   strict-origin-when-cross-origin
# 97380   strict-origin-when-cross-origin
# 100408  strict-origin-when-cross-origin
# 100756  strict-origin-when-cross-origin
# 100757  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 10621   https://googleads.g.doubleclick.net/pagead/ads...
# 10622   https://googleads.g.doubleclick.net/pagead/ads...
# 16423   https://googleads.g.doubleclick.net/pagead/ads...
# 22034   https://live-tag.creatopy.net/designs/l8z5yn8/...
# 22047   https://live-tag.creatopy.net/designs/l8z5yn8/...
# 22048   https://live-tag.creatopy.net/designs/l8z5yn8/...
# 22053   https://live-tag.creatopy.net/designs/l8z5yn8/...
# 22054   https://live-tag.creatopy.net/designs/l8z5yn8/...
# 27869   https://googleads.g.doubleclick.net/pagead/ads...
# 38224   https://googleads.g.doubleclick.net/pagead/ads...
# 38225   https://googleads.g.doubleclick.net/pagead/ads...
# 38226   https://googleads.g.doubleclick.net/pagead/ads...
# 43612   https://googleads.g.doubleclick.net/pagead/ads...
# 43617   https://googleads.g.doubleclick.net/pagead/ads...
# 46441     https://www.youtube.com/@cozycoffeeshopofficial
# 50781   https://googleads.g.doubleclick.net/pagead/ads...
# 50782   https://googleads.g.doubleclick.net/pagead/ads...
# 56328   https://googleads.g.doubleclick.net/pagead/ads...
# 63129   https://googleads.g.doubleclick.net/pagead/ads...
# 66750   https://googleads.g.doubleclick.net/pagead/ads...
# 75657   https://googleads.g.doubleclick.net/pagead/ads...
# 85850   https://googleads.g.doubleclick.net/pagead/ads...
# 85852   https://googleads.g.doubleclick.net/pagead/ads...
# 88420   https://googleads.g.doubleclick.net/pagead/ads...
# 94046   https://googleads.g.doubleclick.net/pagead/ads...
# 94081   https://googleads.g.doubleclick.net/pagead/ads...
# 94082   https://googleads.g.doubleclick.net/pagead/ads...
# 97377   https://googleads.g.doubleclick.net/pagead/ads...
# 97379   https://googleads.g.doubleclick.net/pagead/ads...
# 97380   https://googleads.g.doubleclick.net/pagead/ads...
# 100408  https://googleads.g.doubleclick.net/pagead/ads...
# 100756  https://googleads.g.doubleclick.net/pagead/ads...
# 100757  https://googleads.g.doubleclick.net/pagead/ads...
#
#                                             referer_leaks  \
# 10621   [('urlencode', '/rajasthan/'), ('urlencode', '...
# 10622   [('urlencode', '/rajasthan/'), ('urlencode', '...
# 16423   [('www.wikihow.com',), ('urlencode', 'www.wiki...
# 22034   [('www.investopedia.com',), ('urlencode', '/th...
# 22047   [('www.investopedia.com',), ('urlencode', '/th...
# 22048   [('www.investopedia.com',), ('urlencode', '/th...
# 22053   [('www.investopedia.com',), ('urlencode', '/th...
# 22054   [('www.investopedia.com',), ('urlencode', '/th...
# 27869   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 38224   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 38225   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 38226   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 43612   [('urlencode', '/forecast/4/'), ('urlencode', ...
# 43617   [('urlencode', '/forecast/4/'), ('urlencode', ...
# 46441                     [('/@cozycoffeeshopofficial',)]
# 50781   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 50782   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 56328   [('urlencode', 'tenki.jp'), ('urlencode', '/pm...
# 63129   [('urlencode', '/theme.php'), ('urlencode', 'c...
# 66750   [('urlencode', '/Study-Efficiently'), ('www.wi...
# 75657   [('urlencode', '/ekonomi/nas-gerekcesiyle-faiz...
# 85850   [('urlencode', 'www.wikihow.com'), ('urlencode...
# 85852   [('urlencode', 'www.wikihow.com'), ('urlencode...
# 88420   [('www.cnnindonesia.com',), ('urlencode', 'www...
# 94046   [('urlencode', '/3-sayfa/oktay-derelioglu-traf...
# 94081   [('urlencode', '/3-sayfa/oktay-derelioglu-traf...
# 94082   [('urlencode', '/3-sayfa/oktay-derelioglu-traf...
# 97377   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 97379   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 97380   [('urlencode', 'www.fmkorea.com'), ('www.fmkor...
# 100408  [('urlencode', 'www.india.com'), ('urlencode',...
# 100756  [('urlencode', '/loklok-dramas-movies/com.arte...
# 100757  [('urlencode', '/loklok-dramas-movies/com.arte...
#
#                             leaks                netloc  \
# 10621               referer_leaks         www.india.com
# 10622               referer_leaks         www.india.com
# 16423               referer_leaks       www.wikihow.com
# 22034               referer_leaks  www.investopedia.com
# 22047               referer_leaks  www.investopedia.com
# 22048               referer_leaks  www.investopedia.com
# 22053               referer_leaks  www.investopedia.com
# 22054               referer_leaks  www.investopedia.com
# 27869               referer_leaks       www.fmkorea.com
# 38224               referer_leaks       www.fmkorea.com
# 38225   url_leaks - referer_leaks       www.fmkorea.com
# 38226               referer_leaks       www.fmkorea.com
# 43612               referer_leaks              tenki.jp
# 43617               referer_leaks              tenki.jp
# 46441               referer_leaks
# 50781               referer_leaks       www.fmkorea.com
# 50782   url_leaks - referer_leaks       www.fmkorea.com
# 56328               referer_leaks              tenki.jp
# 63129               referer_leaks        www.dafont.com
# 66750               referer_leaks       www.wikihow.com
# 75657               referer_leaks      www.haberler.com
# 85850               referer_leaks       www.wikihow.com
# 85852               referer_leaks       www.wikihow.com
# 88420               referer_leaks  www.cnnindonesia.com
# 94046               referer_leaks      www.haberler.com
# 94081               referer_leaks      www.haberler.com
# 94082   url_leaks - referer_leaks      www.haberler.com
# 97377               referer_leaks       www.fmkorea.com
# 97379               referer_leaks       www.fmkorea.com
# 97380               referer_leaks       www.fmkorea.com
# 100408              referer_leaks         www.india.com
# 100756              referer_leaks           apkpure.com
# 100757              referer_leaks           apkpure.com
#
#                                                      path    query params  \
# 10621                                         /rajasthan/
# 10622                                         /rajasthan/
# 16423                         /Make-Christmas-Come-Faster
# 22034   /the-american-dream-now-costs-over-usd3-millio...
# 22047   /the-american-dream-now-costs-over-usd3-millio...
# 22048   /the-american-dream-now-costs-over-usd3-millio...
# 22053   /the-american-dream-now-costs-over-usd3-millio...
# 22054   /the-american-dream-now-costs-over-usd3-millio...
# 27869                                        /fm24players
# 38224                                           /fm23tips
# 38225                                           /fm23tips
# 38226                                           /fm23tips
# 43612                                        /forecast/4/
# 43617                                        /forecast/4/
# 46441                            /@cozycoffeeshopofficial
# 50781                                        /fm23players
# 50782                                        /fm23players
# 56328                                              /pm25/
# 63129                                          /theme.php  cat=403
# 66750                                  /Study-Efficiently
# 75657   /ekonomi/nas-gerekcesiyle-faizi-indirmeseydik-...
# 85850                                      /Future-Faking
# 85852                                      /Future-Faking
# 88420   /nasional/20231206195236-12-1033858/gibran-men...
# 94046   /3-sayfa/oktay-derelioglu-trafikte-darp-edildi...
# 94081   /3-sayfa/oktay-derelioglu-trafikte-darp-edildi...
# 94082   /3-sayfa/oktay-derelioglu-trafikte-darp-edildi...
# 97377                                           /fm23tqna
# 97379                                           /fm23tqna
# 97380                                           /fm23tqna
# 100408                                            /bihar/
# 100756           /loklok-dramas-movies/com.artem.scotepio
# 100757           /loklok-dramas-movies/com.artem.scotepio
#
#        fragments  violation
# 10621             Violation
# 10622             Violation
# 16423             Violation
# 22034             Violation
# 22047             Violation
# 22048             Violation
# 22053             Violation
# 22054             Violation
# 27869             Violation
# 38224             Violation
# 38225             Violation
# 38226             Violation
# 43612             Violation
# 43617             Violation
# 46441             Violation
# 50781             Violation
# 50782             Violation
# 56328             Violation
# 63129             Violation
# 66750             Violation
# 75657             Violation
# 85850             Violation
# 85852             Violation
# 88420             Violation
# 94046             Violation
# 94081             Violation
# 94082             Violation
# 97377             Violation
# 97379             Violation
# 97380             Violation
# 100408            Violation
# 100756            Violation
# 100757            Violation

# %%
# counting on referer leaks to google
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('google')
    .fillna(False)
    ].count()
# Out:
# init_url         33
# final_url        33
# req_url          33
# req_method       33
# ref_pol_data     33
# ref_data         33
# referer_leaks    33
# leaks            33
# netloc           33
# path             33
# query            33
# params           33
# fragments        33
# violation        33
# dtype: int64

# %% [markdown]
# ### META / Facebook

# %%
# list of referer leaks to Meta or Facebook
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('meta')
    | referer_leaks_vioilation_df['req_url']
        .str
        .contains('facebook')]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, ref_data, referer_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
# Counting on referer leaks to Meta or Facebook
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('meta') 
    | referer_leaks_vioilation_df['req_url']
        .str.
        contains('facebook')].count()
# Out:
# init_url         0
# final_url        0
# req_url          0
# req_method       0
# ref_pol_data     0
# ref_data         0
# referer_leaks    0
# leaks            0
# netloc           0
# path             0
# query            0
# params           0
# fragments        0
# violation        0
# dtype: int64

# %% [markdown]
# ### Tiktok

# %%
# list of referer leaks to tiktok
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('tiktok')
    .fillna(False)]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, ref_data, referer_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('tiktok')
    .fillna(False)].count()
# Out:
# init_url         0
# final_url        0
# req_url          0
# req_method       0
# ref_pol_data     0
# ref_data         0
# referer_leaks    0
# leaks            0
# netloc           0
# path             0
# query            0
# params           0
# fragments        0
# violation        0
# dtype: int64

# %% [markdown]
# ## Leaks on URL

# %%
# create a new dataframe with non-empty 'referer_leaks' column
url_leaks_df = drop_non_leak(extracted_df, 'url_leaks')
url_leaks_df
# Out:
#                                                 init_url  \
# 0                          https://www.ox.ac.uk/research
# 1                          https://www.ox.ac.uk/research
# 2                          https://www.ox.ac.uk/research
# 3                          https://www.ox.ac.uk/research
# 4                          https://www.ox.ac.uk/research
# ...                                                  ...
# 103294  https://www.mbga.jp/_game_intro?game_id=12016007
# 103295  https://www.mbga.jp/_game_intro?game_id=12016007
# 103296  https://www.mbga.jp/_game_intro?game_id=12016007
# 103297  https://www.mbga.jp/_game_intro?game_id=12016007
# 103298  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 103294  https://www.andapp.jp/apps/12016007?from=www_m...
# 103295  https://www.andapp.jp/apps/12016007?from=www_m...
# 103296  https://www.andapp.jp/apps/12016007?from=www_m...
# 103297  https://www.andapp.jp/apps/12016007?from=www_m...
# 103298  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 0       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...        GET
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 3       https://apikeys.civiccomputing.com/c/v?d=www.o...        GET
# 4       https://www.linkedin.com/px/li_sync?redirect=h...        GET
# ...                                                   ...        ...
# 103294  https://adservice.google.com/ddm/fls/i/dc_pre=...        GET
# 103295  https://googleads.g.doubleclick.net/pagead/vie...        GET
# 103296  https://6015542.fls.doubleclick.net/ddm/fls/r/...        GET
# 103297  https://www.google.com/pagead/1p-user-list/878...        GET
# 103298  https://aw.dw.impact-ad.jp/ut/rep?u=2714&v=2&r...        GET
#
#                            ref_pol_data  \
# 0       strict-origin-when-cross-origin
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 3       strict-origin-when-cross-origin
# 4       strict-origin-when-cross-origin
# ...                                 ...
# 103294  strict-origin-when-cross-origin
# 103295  strict-origin-when-cross-origin
# 103296  strict-origin-when-cross-origin
# 103297  strict-origin-when-cross-origin
# 103298  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks
# 0       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 1       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 2       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 3       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 4       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# ...                                                   ...        ...
# 103294                               [('www.andapp.jp',)]  url_leaks
# 103295  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103296                               [('www.andapp.jp',)]  url_leaks
# 103297  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103298  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
#
# [48017 rows x 7 columns]

# %%
# expand the datarame with the result from check_urlparse function and create a new colomn with the result from check_violation function
url_leaks_df[['netloc', 'path', 'query', 'params', 'fragments']] = url_leaks_df.apply(check_urlparse, axis=1, result_type='expand')

url_leaks_df['violation'] = url_leaks_df.apply(check_violation, axis=1, result_type='expand')

url_leaks_df
# Out:
#                                                 init_url  \
# 0                          https://www.ox.ac.uk/research
# 1                          https://www.ox.ac.uk/research
# 2                          https://www.ox.ac.uk/research
# 3                          https://www.ox.ac.uk/research
# 4                          https://www.ox.ac.uk/research
# ...                                                  ...
# 103294  https://www.mbga.jp/_game_intro?game_id=12016007
# 103295  https://www.mbga.jp/_game_intro?game_id=12016007
# 103296  https://www.mbga.jp/_game_intro?game_id=12016007
# 103297  https://www.mbga.jp/_game_intro?game_id=12016007
# 103298  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 103294  https://www.andapp.jp/apps/12016007?from=www_m...
# 103295  https://www.andapp.jp/apps/12016007?from=www_m...
# 103296  https://www.andapp.jp/apps/12016007?from=www_m...
# 103297  https://www.andapp.jp/apps/12016007?from=www_m...
# 103298  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 0       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...        GET
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 3       https://apikeys.civiccomputing.com/c/v?d=www.o...        GET
# 4       https://www.linkedin.com/px/li_sync?redirect=h...        GET
# ...                                                   ...        ...
# 103294  https://adservice.google.com/ddm/fls/i/dc_pre=...        GET
# 103295  https://googleads.g.doubleclick.net/pagead/vie...        GET
# 103296  https://6015542.fls.doubleclick.net/ddm/fls/r/...        GET
# 103297  https://www.google.com/pagead/1p-user-list/878...        GET
# 103298  https://aw.dw.impact-ad.jp/ut/rep?u=2714&v=2&r...        GET
#
#                            ref_pol_data  \
# 0       strict-origin-when-cross-origin
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 3       strict-origin-when-cross-origin
# 4       strict-origin-when-cross-origin
# ...                                 ...
# 103294  strict-origin-when-cross-origin
# 103295  strict-origin-when-cross-origin
# 103296  strict-origin-when-cross-origin
# 103297  strict-origin-when-cross-origin
# 103298  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 0       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 1       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 2       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 3       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 4       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# ...                                                   ...        ...
# 103294                               [('www.andapp.jp',)]  url_leaks
# 103295  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103296                               [('www.andapp.jp',)]  url_leaks
# 103297  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103298  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
#
#                netloc            path                query params fragments  \
# 0        www.ox.ac.uk
# 1        www.ox.ac.uk       /research
# 2        www.ox.ac.uk       /research
# 3        www.ox.ac.uk
# 4        www.ox.ac.uk
# ...               ...             ...                  ...    ...       ...
# 103294  www.andapp.jp
# 103295  www.andapp.jp  /apps/12016007  from=www_mbga_intro
# 103296  www.andapp.jp
# 103297  www.andapp.jp  /apps/12016007  from=www_mbga_intro
# 103298  www.andapp.jp
#
#         violation
# 0            Safe
# 1       Violation
# 2       Violation
# 3            Safe
# 4            Safe
# ...           ...
# 103294       Safe
# 103295  Violation
# 103296       Safe
# 103297  Violation
# 103298       Safe
#
# [48017 rows x 13 columns]

# %%
# Check wheter the params or fragments leak on url
url_leaks_df[url_leaks_df['violation'] == "Warning"]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, url_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
url_leaks_vioilation_df = url_leaks_df[url_leaks_df['violation'] == "Violation"]
url_leaks_vioilation_df
# Out:
#                                                  init_url  \
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 8                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 59      https://ameblo.jp/borderfreecosmetics/entry-12...
# ...                                                   ...
# 103284   https://www.mbga.jp/_game_intro?game_id=12016007
# 103292   https://www.mbga.jp/_game_intro?game_id=12016007
# 103293   https://www.mbga.jp/_game_intro?game_id=12016007
# 103295   https://www.mbga.jp/_game_intro?game_id=12016007
# 103297   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 8                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 59      https://ameblo.jp/borderfreecosmetics/entry-12...
# ...                                                   ...
# 103284  https://www.andapp.jp/apps/12016007?from=www_m...
# 103292  https://www.andapp.jp/apps/12016007?from=www_m...
# 103293  https://www.andapp.jp/apps/12016007?from=www_m...
# 103295  https://www.andapp.jp/apps/12016007?from=www_m...
# 103297  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 8       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 56      https://www.google-analytics.com/g/collect?v=2...       POST
# 59      https://ln.ameba.jp/v3/zBymKrvv?rd=03883547-4d...        GET
# ...                                                   ...        ...
# 103284  https://yjtag.yahoo.co.jp/tag?site=k36tMgw&ref...        GET
# 103292  https://www.facebook.com/v10.0/plugins/like.ph...        GET
# 103293  https://syndication.twitter.com/i/jot/embeds?l...        GET
# 103295  https://googleads.g.doubleclick.net/pagead/vie...        GET
# 103297  https://www.google.com/pagead/1p-user-list/878...        GET
#
#                            ref_pol_data  \
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 8       strict-origin-when-cross-origin
# 56                               origin
# 59                               origin
# ...                                 ...
# 103284  strict-origin-when-cross-origin
# 103292  strict-origin-when-cross-origin
# 103293  strict-origin-when-cross-origin
# 103295  strict-origin-when-cross-origin
# 103297  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 1       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 2       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 8       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 56      [('urlencode', '/borderfreecosmetics/entry-127...  url_leaks
# 59      [('urlencode', 'ameblo.jp'), ('urlencode', '/b...  url_leaks
# ...                                                   ...        ...
# 103284  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103292  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103293  [('urlencode', 'www.andapp.jp'), ('www.andapp....  url_leaks
# 103295  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103297  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
#
#                netloc                                         path  \
# 1        www.ox.ac.uk                                    /research
# 2        www.ox.ac.uk                                    /research
# 8        www.ox.ac.uk                                    /research
# 56          ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 59          ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# ...               ...                                          ...
# 103284  www.andapp.jp                               /apps/12016007
# 103292  www.andapp.jp                               /apps/12016007
# 103293  www.andapp.jp                               /apps/12016007
# 103295  www.andapp.jp                               /apps/12016007
# 103297  www.andapp.jp                               /apps/12016007
#
#                       query params fragments  violation
# 1                                             Violation
# 2                                             Violation
# 8                                             Violation
# 56                                            Violation
# 59                                            Violation
# ...                     ...    ...       ...        ...
# 103284  from=www_mbga_intro                   Violation
# 103292                                        Violation
# 103293  from=www_mbga_intro                   Violation
# 103295  from=www_mbga_intro                   Violation
# 103297  from=www_mbga_intro                   Violation
#
# [29234 rows x 13 columns]

# %% [markdown]
# ### Maybe some of them is false alarm
#
# For example is a language setting that can be shown on query. The pattern usually "lang=xx"

# %%
url_leaks_vioilation_df[
    (url_leaks_vioilation_df['query']
    .str
    .contains('lang', na=False))
          ]
# Out:
#                                                 init_url  \
# 7046          https://store.netgear.com/home/?lang=en_us
# 7075          https://store.netgear.com/home/?lang=en_us
# 7078          https://store.netgear.com/home/?lang=en_us
# 7081          https://store.netgear.com/home/?lang=en_us
# 7083          https://store.netgear.com/home/?lang=en_us
# ...                                                  ...
# 83826  https://dzen.ru/news/story/vpodmoskove_nashli_...
# 88428  https://dzen.ru/news/story/vnarodnom_sovete_ln...
# 95095                 https://businesshelp.snapchat.com/
# 96241  https://www.scorecardresearch.com/about.aspx?n...
# 96242  https://www.scorecardresearch.com/about.aspx?n...
#
#                                                final_url  \
# 7046   https://store.netgear.com/home/?lang=en_us&ref...
# 7075   https://store.netgear.com/home/?lang=en_us&ref...
# 7078   https://store.netgear.com/home/?lang=en_us&ref...
# 7081   https://store.netgear.com/home/?lang=en_us&ref...
# 7083   https://store.netgear.com/home/?lang=en_us&ref...
# ...                                                  ...
# 83826  https://dzen.ru/news/story/vpodmoskove_nashli_...
# 88428  https://dzen.ru/news/story/vnarodnom_sovete_ln...
# 95095  https://businesshelp.snapchat.com/s/?language=...
# 96241  https://www.scorecardresearch.com/about.aspx?n...
# 96242  https://www.scorecardresearch.com/about.aspx?n...
#
#                                                  req_url req_method  \
# 7046   https://reliably-main-silkworm.pgsdemo.com/?la...        GET
# 7075   https://www.facebook.com/tr/?id=43154253371256...        GET
# 7078   https://events.attentivemobile.com/e?v=4.25.43...       POST
# 7081   https://rp.liadm.com/j?dtstmp=1702007516121&ai...        GET
# 7083   https://netgear.attn.tv/unrenderedCreative?v=4...       POST
# ...                                                  ...        ...
# 83826  https://sso.passport.yandex.ru/push?uuid=65b5f...        GET
# 88428  https://sso.passport.yandex.ru/push?uuid=077d2...        GET
# 95095  https://www.google-analytics.com/j/collect?v=1...       POST
# 96241  https://www.google-analytics.com/j/collect?v=1...       POST
# 96242  https://www.google-analytics.com/g/collect?v=2...       POST
#
#                           ref_pol_data  \
# 7046   strict-origin-when-cross-origin
# 7075   strict-origin-when-cross-origin
# 7078   strict-origin-when-cross-origin
# 7081   strict-origin-when-cross-origin
# 7083   strict-origin-when-cross-origin
# ...                                ...
# 83826  strict-origin-when-cross-origin
# 88428  strict-origin-when-cross-origin
# 95095         origin-when-cross-origin
# 96241  strict-origin-when-cross-origin
# 96242  strict-origin-when-cross-origin
#
#                                                url_leaks      leaks  \
# 7046                  [('lang=en_us&referrerPageUrl=',)]  url_leaks
# 7075   [('urlencode', '/home/'), ('urlencode', 'lang=...  url_leaks
# 7078   [('urlencode', '/home/'), ('urlencode', 'lang=...  url_leaks
# 7081   [('urlencode', '/home/'), ('urlencode', 'lang=...  url_leaks
# 7083   [('urlencode', '/home/'), ('urlencode', 'store...  url_leaks
# ...                                                  ...        ...
# 83826  [('urlencode', 'dzen.ru'), ('urlencode', '/new...  url_leaks
# 88428  [('urlencode', 'dzen.ru'), ('urlencode', '/new...  url_leaks
# 95095  [('urlencode', 'language=en_US'), ('urlencode'...  url_leaks
# 96241  [('urlencode', 'www.scorecardresearch.com'), (...  url_leaks
# 96242  [('urlencode', 'www.scorecardresearch.com'), (...  url_leaks
#
#                           netloc  \
# 7046
# 7075           store.netgear.com
# 7078           store.netgear.com
# 7081           store.netgear.com
# 7083           store.netgear.com
# ...                          ...
# 83826                    dzen.ru
# 88428                    dzen.ru
# 95095  businesshelp.snapchat.com
# 96241  www.scorecardresearch.com
# 96242  www.scorecardresearch.com
#
#                                                     path  \
# 7046
# 7075                                              /home/
# 7078                                              /home/
# 7081                                              /home/
# 7083                                              /home/
# ...                                                  ...
# 83826  /news/story/vpodmoskove_nashli_telo_ehks-deput...
# 88428  /news/story/vnarodnom_sovete_lnr_podtverdili_g...
# 95095                                                /s/
# 96241                                        /about.aspx
# 96242                                        /about.aspx
#
#                                                    query params fragments  \
# 7046                         lang=en_us&referrerPageUrl=
# 7075                         lang=en_us&referrerPageUrl=
# 7078                         lang=en_us&referrerPageUrl=
# 7081                         lang=en_us&referrerPageUrl=
# 7083                         lang=en_us&referrerPageUrl=
# ...                                                  ...    ...       ...
# 83826  lang=ru&from=main_portal&fan=1&stid=wzlzk1zkik...
# 88428  lang=ru&from=main_portal&fan=1&stid=ppm0ktlu-g...
# 95095                                     language=en_US
# 96241                                      newlanguage=1
# 96242                                      newlanguage=1
#
#        violation
# 7046   Violation
# 7075   Violation
# 7078   Violation
# 7081   Violation
# 7083   Violation
# ...          ...
# 83826  Violation
# 88428  Violation
# 95095  Violation
# 96241  Violation
# 96242  Violation
#
# [144 rows x 13 columns]

# %%
# and print to csv

print_leak_to_csv(url_leaks_vioilation_df)

# %%
url_leaks_vioilation_df.count()
# Out:
# init_url        29234
# final_url       29234
# req_url         29234
# req_method      29234
# ref_pol_data    29234
# url_leaks       29234
# leaks           29234
# netloc          29234
# path            29234
# query           29234
# params          29234
# fragments       29234
# violation       29234
# dtype: int64

# %%
url_leaks_vioilation_df.req_method.value_counts()
# Out:
# GET        23847
# POST        5229
# OPTIONS      138
# HEAD          19
# PUT            1
# Name: req_method, dtype: int64

# %%
url_leaks_vioilation_df.drop_duplicates(subset=['final_url'])
# Out:
#                                                  init_url  \
# 1                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 72                            https://xmp.mobvista.com/cn
# 76        https://www.marktplaats.nl/cp/621/kleding-dames
# 94             https://email.nypost.com/israel-war-update
# ...                                                   ...
# 103052  https://www.finn.no/nettbil/velkommen?origin=f...
# 103090  https://www.washington.edu/news/?utm_source=wh...
# 103111  https://www.mcafee.com/en-us/consumer-corporat...
# 103126                          https://actu.fr/politique
# 103150       https://www.docker.com/products/docker-scout
#
#                                                 final_url  \
# 1                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 72                            https://xmp.mobvista.com/cn
# 76       https://www.marktplaats.nl/cp/621/kleding-dames/
# 94            https://email.nypost.com/israel-war-update/
# ...                                                   ...
# 103052  https://www.finn.no/nettbil?origin=frontpage_icon
# 103090  https://www.washington.edu/news/?utm_source=wh...
# 103111  https://www.mcafee.com/en-us/consumer-corporat...
# 103126                          https://actu.fr/politique
# 103150      https://www.docker.com/products/docker-scout/
#
#                                                   req_url req_method  \
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 56      https://www.google-analytics.com/g/collect?v=2...       POST
# 72      https://magnet.rayjump.com/pixel?campuuid=ss_x...        GET
# 76      https://www.google-analytics.com/j/collect?v=1...       POST
# 94      https://tr.outbrain.com/unifiedPixel?optOut=fa...       POST
# ...                                                   ...        ...
# 103052  https://static.finncdn.no/_c/nettbil-layout/_n...        GET
# 103090  https://www.google-analytics.com/j/collect?v=1...       POST
# 103111  https://sp.analytics.yahoo.com/sp.pl?a=10000&d...        GET
# 103126  https://trc.taboola.com/actufr-actufr/trc/3/js...        GET
# 103150  https://dev.visualwebsiteoptimizer.com/j.php?a...        GET
#
#                            ref_pol_data  \
# 1       strict-origin-when-cross-origin
# 56                               origin
# 72      strict-origin-when-cross-origin
# 76      strict-origin-when-cross-origin
# 94      strict-origin-when-cross-origin
# ...                                 ...
# 103052  strict-origin-when-cross-origin
# 103090  strict-origin-when-cross-origin
# 103111  strict-origin-when-cross-origin
# 103126  strict-origin-when-cross-origin
# 103150  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 1       [('urlencode', '/research'), ('urlencode', 'ww...  url_leaks
# 56      [('urlencode', '/borderfreecosmetics/entry-127...  url_leaks
# 72      [('xmp.mobvista.com',), ('urlencode', '/cn'), ...  url_leaks
# 76      [('urlencode', '/cp/621/kleding-dames/'), ('ur...  url_leaks
# 94      [('urlencode', 'email.nypost.com'), ('email.ny...  url_leaks
# ...                                                   ...        ...
# 103052                                    [('/nettbil',)]  url_leaks
# 103090  [('urlencode', '/news/'), ('www.washington.edu...  url_leaks
# 103111  [('www.mcafee.com',), ('urlencode', 'www.mcafe...  url_leaks
# 103126  [('actu.fr',), ('urlencode', 'actu.fr'), ('url...  url_leaks
# 103150  [('www.docker.com',), ('urlencode', '/products...  url_leaks
#
#                     netloc                                         path  \
# 1             www.ox.ac.uk                                    /research
# 56               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 72        xmp.mobvista.com                                          /cn
# 76      www.marktplaats.nl                       /cp/621/kleding-dames/
# 94        email.nypost.com                          /israel-war-update/
# ...                    ...                                          ...
# 103052                                                         /nettbil
# 103090  www.washington.edu                                       /news/
# 103111      www.mcafee.com     /en-us/consumer-corporate/investors.html
# 103126             actu.fr                                   /politique
# 103150      www.docker.com                      /products/docker-scout/
#
#                                                     query params fragments  \
# 1
# 56
# 72
# 76
# 94
# ...                                                   ...    ...       ...
# 103052
# 103090  utm_source=whitebar&utm_medium=click&utm_campa...
# 103111
# 103126
# 103150
#
#         violation
# 1       Violation
# 56      Violation
# 72      Violation
# 76      Violation
# 94      Violation
# ...           ...
# 103052  Violation
# 103090  Violation
# 103111  Violation
# 103126  Violation
# 103150  Violation
#
# [2033 rows x 13 columns]

# %% [markdown]
# ### GOOGLE

# %%
# count of url leaks to google
url_leaks_vioilation_df[url_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)].count()
# Out:
# init_url        9178
# final_url       9178
# req_url         9178
# req_method      9178
# ref_pol_data    9178
# url_leaks       9178
# leaks           9178
# netloc          9178
# path            9178
# query           9178
# params          9178
# fragments       9178
# violation       9178
# dtype: int64

# %%
# list of url leaks to google
url_leaks_vioilation_df[url_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)]
# Out:
#                                                  init_url  \
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 60      https://ameblo.jp/borderfreecosmetics/entry-12...
# 73                            https://xmp.mobvista.com/cn
# 75                            https://xmp.mobvista.com/cn
# 76        https://www.marktplaats.nl/cp/621/kleding-dames
# ...                                                   ...
# 103226       https://www.docker.com/products/docker-scout
# 103281   https://www.mbga.jp/_game_intro?game_id=12016007
# 103283   https://www.mbga.jp/_game_intro?game_id=12016007
# 103295   https://www.mbga.jp/_game_intro?game_id=12016007
# 103297   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 60      https://ameblo.jp/borderfreecosmetics/entry-12...
# 73                            https://xmp.mobvista.com/cn
# 75                            https://xmp.mobvista.com/cn
# 76       https://www.marktplaats.nl/cp/621/kleding-dames/
# ...                                                   ...
# 103226      https://www.docker.com/products/docker-scout/
# 103281  https://www.andapp.jp/apps/12016007?from=www_m...
# 103283  https://www.andapp.jp/apps/12016007?from=www_m...
# 103295  https://www.andapp.jp/apps/12016007?from=www_m...
# 103297  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 56      https://www.google-analytics.com/g/collect?v=2...       POST
# 60      https://www.google-analytics.com/j/collect?v=1...       POST
# 73      https://www.google-analytics.com/g/collect?v=2...       POST
# 75      https://www.google-analytics.com/g/collect?v=2...       POST
# 76      https://www.google-analytics.com/j/collect?v=1...       POST
# ...                                                   ...        ...
# 103226  https://analytics.google.com/g/collect?v=2&tid...       POST
# 103281  https://www.google-analytics.com/j/collect?v=1...       POST
# 103283  https://www.google-analytics.com/g/collect?v=2...       POST
# 103295  https://googleads.g.doubleclick.net/pagead/vie...        GET
# 103297  https://www.google.com/pagead/1p-user-list/878...        GET
#
#                            ref_pol_data  \
# 56                               origin
# 60                               origin
# 73      strict-origin-when-cross-origin
# 75      strict-origin-when-cross-origin
# 76      strict-origin-when-cross-origin
# ...                                 ...
# 103226  strict-origin-when-cross-origin
# 103281  strict-origin-when-cross-origin
# 103283  strict-origin-when-cross-origin
# 103295  strict-origin-when-cross-origin
# 103297  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 56      [('urlencode', '/borderfreecosmetics/entry-127...  url_leaks
# 60      [('urlencode', '/borderfreecosmetics/entry-127...  url_leaks
# 73      [('xmp.mobvista.com',), ('urlencode', '/cn'), ...  url_leaks
# 75      [('xmp.mobvista.com',), ('urlencode', '/cn'), ...  url_leaks
# 76      [('urlencode', '/cp/621/kleding-dames/'), ('ur...  url_leaks
# ...                                                   ...        ...
# 103226  [('www.docker.com',), ('urlencode', '/products...  url_leaks
# 103281  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103283  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103295  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
# 103297  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
#
#                     netloc                                         path  \
# 56               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 60               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 73        xmp.mobvista.com                                          /cn
# 75        xmp.mobvista.com                                          /cn
# 76      www.marktplaats.nl                       /cp/621/kleding-dames/
# ...                    ...                                          ...
# 103226      www.docker.com                      /products/docker-scout/
# 103281       www.andapp.jp                               /apps/12016007
# 103283       www.andapp.jp                               /apps/12016007
# 103295       www.andapp.jp                               /apps/12016007
# 103297       www.andapp.jp                               /apps/12016007
#
#                       query params fragments  violation
# 56                                            Violation
# 60                                            Violation
# 73                                            Violation
# 75                                            Violation
# 76                                            Violation
# ...                     ...    ...       ...        ...
# 103226                                        Violation
# 103281  from=www_mbga_intro                   Violation
# 103283  from=www_mbga_intro                   Violation
# 103295  from=www_mbga_intro                   Violation
# 103297  from=www_mbga_intro                   Violation
#
# [9178 rows x 13 columns]

# %% [markdown]
# ### Facebook or Meta

# %%
# count of url leaks to Meta or Facebook
url_leaks_vioilation_df[url_leaks_vioilation_df['req_url']
                        .str.contains('meta') 
                        | url_leaks_vioilation_df['req_url']
                            .str.contains('facebook')].count()
# Out:
# init_url        1577
# final_url       1577
# req_url         1577
# req_method      1577
# ref_pol_data    1577
# url_leaks       1577
# leaks           1577
# netloc          1577
# path            1577
# query           1577
# params          1577
# fragments       1577
# violation       1577
# dtype: int64

# %%
# list of url leaks to Meta or Facebook
url_leaks_vioilation_df[
    url_leaks_vioilation_df['req_url']
    .str.contains('meta') 
    | url_leaks_vioilation_df['req_url']
        .str.contains('facebook')]
# Out:
#                                                  init_url  \
# 168     https://www.amazon.com.mx/s/?_encoding=utf8&k=...
# 310        https://www.instagram.com/accounts/emailsignup
# 311                       https://ui.com/us/identity?s=us
# 319                       https://ui.com/us/identity?s=us
# 326                       https://ui.com/us/identity?s=us
# ...                                                   ...
# 103095  https://www.washington.edu/news/?utm_source=wh...
# 103162       https://www.docker.com/products/docker-scout
# 103232       https://www.docker.com/products/docker-scout
# 103235       https://www.docker.com/products/docker-scout
# 103292   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 168     https://www.amazon.com.mx/s?k=carteras&i=fashi...
# 310       https://www.instagram.com/accounts/emailsignup/
# 311                            https://ui.com/us/identity
# 319                            https://ui.com/us/identity
# 326                            https://ui.com/us/identity
# ...                                                   ...
# 103095  https://www.washington.edu/news/?utm_source=wh...
# 103162      https://www.docker.com/products/docker-scout/
# 103232      https://www.docker.com/products/docker-scout/
# 103235      https://www.docker.com/products/docker-scout/
# 103292  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 168     https://www.facebook.com/fr/r.php?p=5582933009...        GET
# 310     https://www.facebook.com/x/oauth/status?client...        GET
# 311     https://connect.facebook.net/signals/config/77...        GET
# 319     https://www.facebook.com/tr/?id=77134957013916...        GET
# 326     https://www.facebook.com/tr/?id=77134957013916...        GET
# ...                                                   ...        ...
# 103095  https://www.facebook.com/tr/?id=39956399904231...        GET
# 103162  https://www.facebook.com/tr/?id=16466388623210...        GET
# 103232  https://www.facebook.com/tr/?id=16466388623210...        GET
# 103235  https://www.facebook.com/tr/?id=16466388623210...        GET
# 103292  https://www.facebook.com/v10.0/plugins/like.ph...        GET
#
#                            ref_pol_data  \
# 168                         no-referrer
# 310     strict-origin-when-cross-origin
# 311                         same-origin
# 319                         same-origin
# 326                         same-origin
# ...                                 ...
# 103095  strict-origin-when-cross-origin
# 103162  strict-origin-when-cross-origin
# 103232  strict-origin-when-cross-origin
# 103235  strict-origin-when-cross-origin
# 103292  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 168         [('urlencode', '/s'), ('custom_map_1', '/S')]  url_leaks
# 310     [('urlencode', '/accounts/emailsignup/'), ('ur...  url_leaks
# 311                [('ui.com',), ('urlencode', 'ui.com')]  url_leaks
# 319     [('ui.com',), ('urlencode', '/us/identity'), (...  url_leaks
# 326     [('ui.com',), ('urlencode', '/us/identity'), (...  url_leaks
# ...                                                   ...        ...
# 103095  [('urlencode', '/news/'), ('www.washington.edu...  url_leaks
# 103162  [('www.docker.com',), ('urlencode', '/products...  url_leaks
# 103232  [('www.docker.com',), ('urlencode', '/products...  url_leaks
# 103235  [('www.docker.com',), ('urlencode', '/products...  url_leaks
# 103292  [('www.andapp.jp',), ('urlencode', 'www.andapp...  url_leaks
#
#                     netloc                     path  \
# 168                                              /s
# 310      www.instagram.com   /accounts/emailsignup/
# 311                 ui.com
# 319                 ui.com             /us/identity
# 326                 ui.com             /us/identity
# ...                    ...                      ...
# 103095  www.washington.edu                   /news/
# 103162      www.docker.com  /products/docker-scout/
# 103232      www.docker.com  /products/docker-scout/
# 103235      www.docker.com  /products/docker-scout/
# 103292       www.andapp.jp           /apps/12016007
#
#                                                     query params fragments  \
# 168
# 310
# 311
# 319
# 326
# ...                                                   ...    ...       ...
# 103095  utm_source=whitebar&utm_medium=click&utm_campa...
# 103162
# 103232
# 103235
# 103292
#
#         violation
# 168     Violation
# 310     Violation
# 311     Violation
# 319     Violation
# 326     Violation
# ...           ...
# 103095  Violation
# 103162  Violation
# 103232  Violation
# 103235  Violation
# 103292  Violation
#
# [1577 rows x 13 columns]

# %% [markdown]
# ### Tiktok

# %%
url_leaks_vioilation_df[
    url_leaks_vioilation_df['req_url']
        .str.contains('tiktok').fillna(False)]
# Out:
#                                                 init_url  \
# 3896   https://time.com/6342806/person-of-the-year-20...
# 3916   https://www.adjust.com/resources/ebooks/skadne...
# 4715   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4727   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4785   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4807   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4993            https://www.nike.com/w/member-sale-9t7gt
# 7577                  https://www.healthline.com/fitness
# 9069    https://www.nike.com/w/classics-collection-aj8oq
# 19449              https://www.nike.com/w/jordan-1-4foky
# 28478  https://www.medicalnewstoday.com/articles/in-c...
# 32295  https://www.medicalnewstoday.com/articles/redu...
# 34151  https://www.medicalnewstoday.com/articles/how-...
# 34740  https://www.medicalnewstoday.com/articles/psor...
# 38521                        https://www.mgid.com/events
# 57089  https://www.healthline.com/health/viral-vs-ver...
# 57135  https://www.healthline.com/health/viral-vs-ver...
# 63819  https://www.nike.com/w/air-force-1-shoes-5sj3y...
# 69274           https://www.nike.com/w/daily-deals-5ks9w
# 77877  https://www.medicalnewstoday.com/articles/prob...
# 82256                   https://www.healthline.com/sleep
# 85046           https://www.healthline.com/mental-health
# 94672  https://www.healthline.com/health-news/safe-tr...
#
#                                                final_url  \
# 3896   https://time.com/6342806/person-of-the-year-20...
# 3916   https://www.adjust.com/resources/ebooks/skadne...
# 4715   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4727   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4785   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4807   https://www.huffpost.com/entry/comfy-shoes-tik...
# 4993            https://www.nike.com/w/member-sale-9t7gt
# 7577                  https://www.healthline.com/fitness
# 9069    https://www.nike.com/w/classics-collection-aj8oq
# 19449              https://www.nike.com/w/jordan-1-4foky
# 28478  https://www.medicalnewstoday.com/articles/in-c...
# 32295  https://www.medicalnewstoday.com/articles/redu...
# 34151  https://www.medicalnewstoday.com/articles/how-...
# 34740  https://www.medicalnewstoday.com/articles/psor...
# 38521                        https://www.mgid.com/events
# 57089  https://www.healthline.com/health/viral-vs-ver...
# 57135  https://www.healthline.com/health/viral-vs-ver...
# 63819  https://www.nike.com/w/air-force-1-shoes-5sj3y...
# 69274           https://www.nike.com/w/daily-deals-5ks9w
# 77877  https://www.medicalnewstoday.com/articles/prob...
# 82256                   https://www.healthline.com/sleep
# 85046           https://www.healthline.com/mental-health
# 94672  https://www.healthline.com/health-news/safe-tr...
#
#                                                  req_url req_method  \
# 3896   https://securepubads.g.doubleclick.net/gampad/...        GET
# 3916   https://pi.pardot.com/analytics?ver=3&pi_form=...        GET
# 4715   https://widgetmonitor.outbrain.com/WidgetError...        GET
# 4727   https://widgets.outbrain.com/widgetMonitor/mon...        GET
# 4785   https://widgetmonitor.outbrain.com/WidgetError...        GET
# 4807   https://ssum-sec.casalemedia.com/usermatch?us_...        GET
# 4993   https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 7577   https://www.google-analytics.com/j/collect?v=1...       POST
# 9069   https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 19449  https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 28478  https://www.google-analytics.com/j/collect?v=1...       POST
# 32295  https://www.google-analytics.com/j/collect?v=1...       POST
# 34151  https://www.google-analytics.com/j/collect?v=1...       POST
# 34740  https://www.google-analytics.com/j/collect?v=1...       POST
# 38521  https://analytics.tiktok.com/i18n/pixel/events...        GET
# 57089  https://www.google-analytics.com/j/collect?v=1...       POST
# 57135  https://www.google-analytics.com/collect?v=1&_...        GET
# 63819  https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 69274  https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 77877  https://www.google-analytics.com/j/collect?v=1...       POST
# 82256  https://www.google-analytics.com/j/collect?v=1...       POST
# 85046  https://www.google-analytics.com/j/collect?v=1...       POST
# 94672  https://www.google-analytics.com/j/collect?v=1...       POST
#
#                           ref_pol_data  \
# 3896   strict-origin-when-cross-origin
# 3916   strict-origin-when-cross-origin
# 4715   strict-origin-when-cross-origin
# 4727   strict-origin-when-cross-origin
# 4785   strict-origin-when-cross-origin
# 4807   strict-origin-when-cross-origin
# 4993   strict-origin-when-cross-origin
# 7577   strict-origin-when-cross-origin
# 9069   strict-origin-when-cross-origin
# 19449  strict-origin-when-cross-origin
# 28478  strict-origin-when-cross-origin
# 32295  strict-origin-when-cross-origin
# 34151  strict-origin-when-cross-origin
# 34740  strict-origin-when-cross-origin
# 38521  strict-origin-when-cross-origin
# 57089  strict-origin-when-cross-origin
# 57135  strict-origin-when-cross-origin
# 63819  strict-origin-when-cross-origin
# 69274  strict-origin-when-cross-origin
# 77877  strict-origin-when-cross-origin
# 82256  strict-origin-when-cross-origin
# 85046  strict-origin-when-cross-origin
# 94672  strict-origin-when-cross-origin
#
#                                                url_leaks      leaks  \
# 3896   [('urlencode', 'time.com'), ('urlencode', '/63...  url_leaks
# 3916   [('urlencode', 'www.adjust.com'), ('www.adjust...  url_leaks
# 4715   [('www.huffpost.com',), ('urlencode', '/entry/...  url_leaks
# 4727   [('urlencode', 'www.huffpost.com'), ('urlencod...  url_leaks
# 4785   [('urlencode', 'www.huffpost.com'), ('urlencod...  url_leaks
# 4807   [('www.huffpost.com',), ('urlencode', '/entry/...  url_leaks
# 4993   [('urlencode', 'www.nike.com'), ('/w/member-sa...  url_leaks
# 7577   [('www.healthline.com',), ('urlencode', '/fitn...  url_leaks
# 9069   [('www.nike.com',), ('urlencode', 'www.nike.co...  url_leaks
# 19449  [('www.nike.com',), ('/w/jordan-1-4foky',), ('...  url_leaks
# 28478  [('urlencode', 'www.medicalnewstoday.com'), ('...  url_leaks
# 32295  [('urlencode', 'www.medicalnewstoday.com'), ('...  url_leaks
# 34151  [('urlencode', 'www.medicalnewstoday.com'), ('...  url_leaks
# 34740  [('urlencode', 'www.medicalnewstoday.com'), ('...  url_leaks
# 38521                                     [('/events',)]  url_leaks
# 57089  [('www.healthline.com',), ('urlencode', '/heal...  url_leaks
# 57135  [('www.healthline.com',), ('urlencode', '/heal...  url_leaks
# 63819  [('urlencode', '/w/air-force-1-shoes-5sj3yzy7o...  url_leaks
# 69274  [('www.nike.com',), ('urlencode', '/w/daily-de...  url_leaks
# 77877  [('urlencode', '/articles/probiotic-bacteria-l...  url_leaks
# 82256  [('urlencode', '/sleep'), ('www.healthline.com...  url_leaks
# 85046  [('www.healthline.com',), ('urlencode', '/ment...  url_leaks
# 94672  [('urlencode', '/health-news/safe-travel-tips-...  url_leaks
#
#                          netloc  \
# 3896                   time.com
# 3916             www.adjust.com
# 4715           www.huffpost.com
# 4727           www.huffpost.com
# 4785           www.huffpost.com
# 4807           www.huffpost.com
# 4993               www.nike.com
# 7577         www.healthline.com
# 9069               www.nike.com
# 19449              www.nike.com
# 28478  www.medicalnewstoday.com
# 32295  www.medicalnewstoday.com
# 34151  www.medicalnewstoday.com
# 34740  www.medicalnewstoday.com
# 38521
# 57089        www.healthline.com
# 57135        www.healthline.com
# 63819              www.nike.com
# 69274              www.nike.com
# 77877  www.medicalnewstoday.com
# 82256        www.healthline.com
# 85046        www.healthline.com
# 94672        www.healthline.com
#
#                                                     path query params  \
# 3896      /6342806/person-of-the-year-2023-taylor-swift/
# 3916                /resources/ebooks/skadnetwork-4-ios/
# 4715   /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 4727   /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 4785   /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 4807   /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 4993                                /w/member-sale-9t7gt
# 7577                                            /fitness
# 9069                        /w/classics-collection-aj8oq
# 19449                                  /w/jordan-1-4foky
# 28478  /articles/in-conversation-why-exercise-is-key-...
# 32295  /articles/reduction-in-hippocampus-in-brain-li...
# 34151  /articles/how-accurate-are-the-claims-about-as...
# 34740       /articles/psoriasis-and-chronic-inflammation
# 38521                                            /events
# 57089  /health/viral-vs-verified-quiz-debunking-cold-...
# 57135  /health/viral-vs-verified-quiz-debunking-cold-...
# 63819                    /w/air-force-1-shoes-5sj3yzy7ok
# 69274                               /w/daily-deals-5ks9w
# 77877  /articles/probiotic-bacteria-lactobacillus-yog...
# 82256                                             /sleep
# 85046                                     /mental-health
# 94672  /health-news/safe-travel-tips-people-with-medi...
#
#       fragments  violation
# 3896             Violation
# 3916             Violation
# 4715             Violation
# 4727             Violation
# 4785             Violation
# 4807             Violation
# 4993             Violation
# 7577             Violation
# 9069             Violation
# 19449            Violation
# 28478            Violation
# 32295            Violation
# 34151            Violation
# 34740            Violation
# 38521            Violation
# 57089            Violation
# 57135            Violation
# 63819            Violation
# 69274            Violation
# 77877            Violation
# 82256            Violation
# 85046            Violation
# 94672            Violation

# %% [markdown]
# ## Leaks on Post Data

# %%
# create a new dataframe with non-empty 'post_leaks' column
post_leaks_df = drop_non_leak(extracted_df, 'post_leaks')
post_leaks_df
# Out:
#                                                 init_url  \
# 9                          https://www.ox.ac.uk/research
# 10                         https://www.ox.ac.uk/research
# 11                         https://www.ox.ac.uk/research
# 13                         https://www.ox.ac.uk/research
# 15                         https://www.ox.ac.uk/research
# ...                                                  ...
# 103249                           https://shop.wired.com/
# 103251                           https://shop.wired.com/
# 103275                           https://shop.wired.com/
# 103299  https://www.mbga.jp/_game_intro?game_id=12016007
# 103300  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 9                           https://www.ox.ac.uk/research
# 10                          https://www.ox.ac.uk/research
# 11                          https://www.ox.ac.uk/research
# 13                          https://www.ox.ac.uk/research
# 15                          https://www.ox.ac.uk/research
# ...                                                   ...
# 103249                            https://shop.wired.com/
# 103251                            https://shop.wired.com/
# 103275                            https://shop.wired.com/
# 103299  https://www.andapp.jp/apps/12016007?from=www_m...
# 103300  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 9       https://www.youtube.com/youtubei/v1/player?key...       POST
# 10      https://www.youtube.com/youtubei/v1/player?key...       POST
# 11                        https://px.ads.linkedin.com/wa/       POST
# 13      https://www.youtube.com/youtubei/v1/log_event?...       POST
# 15      https://www.youtube.com/youtubei/v1/log_event?...       POST
# ...                                                   ...        ...
# 103249                https://events.privy.com/v2/collect       POST
# 103251                     https://a.ad.gt/api/v1/collect       POST
# 103275             https://l.evidon.com/site/v3/userPref/       POST
# 103299  https://www.youtube.com/youtubei/v1/log_event?...       POST
# 103300                https://id5-sync.com/g/v2/1270.json       POST
#
#                            ref_pol_data  \
# 9       strict-origin-when-cross-origin
# 10      strict-origin-when-cross-origin
# 11      strict-origin-when-cross-origin
# 13      strict-origin-when-cross-origin
# 15      strict-origin-when-cross-origin
# ...                                 ...
# 103249  strict-origin-when-cross-origin
# 103251  strict-origin-when-cross-origin
# 103275  strict-origin-when-cross-origin
# 103299  strict-origin-when-cross-origin
# 103300  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 9       {"videoId":"ogkc1FmfiuI","context":{"client":{...
# 10      {"videoId":"MJNz9_M3kFg","context":{"client":{...
# 11      {"pids":[9293],"scriptVersion":1029,"time":170...
# 13      {"context":{"client":{"hl":"en","gl":"US","cli...
# 15      {"context":{"client":{"hl":"en","gl":"US","cli...
# ...                                                   ...
# 103249  {"event":"new-session","properties":{"referrin...
# 103251  eyJjYXRlZ29yeSI6InBhZ2VWaWV3IiwidmVyc2lvbiI6In...
# 103275  {"d":{"noticeId":98141,"companyId":5116,"actio...
# 103299  {"context":{"client":{"hl":"en","gl":"US","cli...
# 103300  {"partner":1270,"v":"1.0.36","o":"api","tml":"...
#
#                                                post_leaks  \
# 9       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 10      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 11                                       [('/research',)]
# 13                                    [('www.ox.ac.uk',)]
# 15                                    [('www.ox.ac.uk',)]
# ...                                                   ...
# 103249                              [('shop.wired.com',)]
# 103251                     [('base64', 'shop.wired.com')]
# 103275                              [('shop.wired.com',)]
# 103299                               [('www.andapp.jp',)]
# 103300                               [('www.andapp.jp',)]
#
#                              leaks
# 9                       post_leaks
# 10                      post_leaks
# 11                      post_leaks
# 13                      post_leaks
# 15                      post_leaks
# ...                            ...
# 103249                  post_leaks
# 103251                  post_leaks
# 103275                  post_leaks
# 103299  post_leaks - referer_leaks
# 103300                  post_leaks
#
# [14665 rows x 8 columns]

# %%
# expand the datarame with the result from check_urlparse function and create a new colomn with the result from check_violation function
post_leaks_df[['netloc', 'path', 'query', 'params', 'fragments']] = post_leaks_df.apply(check_urlparse, axis=1, result_type='expand')

post_leaks_df['violation'] = post_leaks_df.apply(check_violation, axis=1, result_type='expand')

post_leaks_df
# Out:
#                                                 init_url  \
# 9                          https://www.ox.ac.uk/research
# 10                         https://www.ox.ac.uk/research
# 11                         https://www.ox.ac.uk/research
# 13                         https://www.ox.ac.uk/research
# 15                         https://www.ox.ac.uk/research
# ...                                                  ...
# 103249                           https://shop.wired.com/
# 103251                           https://shop.wired.com/
# 103275                           https://shop.wired.com/
# 103299  https://www.mbga.jp/_game_intro?game_id=12016007
# 103300  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 9                           https://www.ox.ac.uk/research
# 10                          https://www.ox.ac.uk/research
# 11                          https://www.ox.ac.uk/research
# 13                          https://www.ox.ac.uk/research
# 15                          https://www.ox.ac.uk/research
# ...                                                   ...
# 103249                            https://shop.wired.com/
# 103251                            https://shop.wired.com/
# 103275                            https://shop.wired.com/
# 103299  https://www.andapp.jp/apps/12016007?from=www_m...
# 103300  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 9       https://www.youtube.com/youtubei/v1/player?key...       POST
# 10      https://www.youtube.com/youtubei/v1/player?key...       POST
# 11                        https://px.ads.linkedin.com/wa/       POST
# 13      https://www.youtube.com/youtubei/v1/log_event?...       POST
# 15      https://www.youtube.com/youtubei/v1/log_event?...       POST
# ...                                                   ...        ...
# 103249                https://events.privy.com/v2/collect       POST
# 103251                     https://a.ad.gt/api/v1/collect       POST
# 103275             https://l.evidon.com/site/v3/userPref/       POST
# 103299  https://www.youtube.com/youtubei/v1/log_event?...       POST
# 103300                https://id5-sync.com/g/v2/1270.json       POST
#
#                            ref_pol_data  \
# 9       strict-origin-when-cross-origin
# 10      strict-origin-when-cross-origin
# 11      strict-origin-when-cross-origin
# 13      strict-origin-when-cross-origin
# 15      strict-origin-when-cross-origin
# ...                                 ...
# 103249  strict-origin-when-cross-origin
# 103251  strict-origin-when-cross-origin
# 103275  strict-origin-when-cross-origin
# 103299  strict-origin-when-cross-origin
# 103300  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 9       {"videoId":"ogkc1FmfiuI","context":{"client":{...
# 10      {"videoId":"MJNz9_M3kFg","context":{"client":{...
# 11      {"pids":[9293],"scriptVersion":1029,"time":170...
# 13      {"context":{"client":{"hl":"en","gl":"US","cli...
# 15      {"context":{"client":{"hl":"en","gl":"US","cli...
# ...                                                   ...
# 103249  {"event":"new-session","properties":{"referrin...
# 103251  eyJjYXRlZ29yeSI6InBhZ2VWaWV3IiwidmVyc2lvbiI6In...
# 103275  {"d":{"noticeId":98141,"companyId":5116,"actio...
# 103299  {"context":{"client":{"hl":"en","gl":"US","cli...
# 103300  {"partner":1270,"v":"1.0.36","o":"api","tml":"...
#
#                                                post_leaks  \
# 9       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 10      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 11                                       [('/research',)]
# 13                                    [('www.ox.ac.uk',)]
# 15                                    [('www.ox.ac.uk',)]
# ...                                                   ...
# 103249                              [('shop.wired.com',)]
# 103251                     [('base64', 'shop.wired.com')]
# 103275                              [('shop.wired.com',)]
# 103299                               [('www.andapp.jp',)]
# 103300                               [('www.andapp.jp',)]
#
#                              leaks          netloc       path query params  \
# 9                       post_leaks    www.ox.ac.uk
# 10                      post_leaks    www.ox.ac.uk
# 11                      post_leaks                  /research
# 13                      post_leaks    www.ox.ac.uk
# 15                      post_leaks    www.ox.ac.uk
# ...                            ...             ...        ...   ...    ...
# 103249                  post_leaks  shop.wired.com
# 103251                  post_leaks  shop.wired.com
# 103275                  post_leaks  shop.wired.com
# 103299  post_leaks - referer_leaks   www.andapp.jp
# 103300                  post_leaks   www.andapp.jp
#
#        fragments  violation
# 9                      Safe
# 10                     Safe
# 11                Violation
# 13                     Safe
# 15                     Safe
# ...          ...        ...
# 103249                 Safe
# 103251                 Safe
# 103275                 Safe
# 103299                 Safe
# 103300                 Safe
#
# [14665 rows x 14 columns]

# %%
# Check wheter the params or fragments leak on post
post_leaks_df[post_leaks_df['violation'] == "Warning"]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, post_data, post_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
post_leaks_vioilation_df = post_leaks_df[post_leaks_df['violation'] == "Violation"]
post_leaks_vioilation_df
# Out:
#                                                  init_url  \
# 11                          https://www.ox.ac.uk/research
# 61      https://ameblo.jp/borderfreecosmetics/entry-12...
# 77        https://www.marktplaats.nl/cp/621/kleding-dames
# 78        https://www.marktplaats.nl/cp/621/kleding-dames
# 79        https://www.marktplaats.nl/cp/621/kleding-dames
# ...                                                   ...
# 103220       https://www.docker.com/products/docker-scout
# 103222       https://www.docker.com/products/docker-scout
# 103224       https://www.docker.com/products/docker-scout
# 103225       https://www.docker.com/products/docker-scout
# 103227       https://www.docker.com/products/docker-scout
#
#                                                 final_url  \
# 11                          https://www.ox.ac.uk/research
# 61      https://ameblo.jp/borderfreecosmetics/entry-12...
# 77       https://www.marktplaats.nl/cp/621/kleding-dames/
# 78       https://www.marktplaats.nl/cp/621/kleding-dames/
# 79       https://www.marktplaats.nl/cp/621/kleding-dames/
# ...                                                   ...
# 103220      https://www.docker.com/products/docker-scout/
# 103222      https://www.docker.com/products/docker-scout/
# 103224      https://www.docker.com/products/docker-scout/
# 103225      https://www.docker.com/products/docker-scout/
# 103227      https://www.docker.com/products/docker-scout/
#
#                                                   req_url req_method  \
# 11                        https://px.ads.linkedin.com/wa/       POST
# 61                             https://id5-sync.com/gm/v3       POST
# 77               https://ib.adnxs-simple.com/ut/v3/prebid       POST
# 78               https://ib.adnxs-simple.com/ut/v3/prebid       POST
# 79      https://htlb.casalemedia.com/openrtb/pbjs?s=23...       POST
# ...                                                   ...        ...
# 103220  https://bootstrap.api.drift.com/widget_bootstr...       POST
# 103222   https://bootstrap.api.drift.com/widget_bootstrap       POST
# 103224                  https://event.api.drift.com/track       POST
# 103225  https://targeting.api.drift.com/targeting/eval...       POST
# 103227  https://flow.api.drift.com/flows/render_initia...       POST
#
#                            ref_pol_data  \
# 11      strict-origin-when-cross-origin
# 61                               origin
# 77      strict-origin-when-cross-origin
# 78      strict-origin-when-cross-origin
# 79      strict-origin-when-cross-origin
# ...                                 ...
# 103220  strict-origin-when-cross-origin
# 103222  strict-origin-when-cross-origin
# 103224  strict-origin-when-cross-origin
# 103225  strict-origin-when-cross-origin
# 103227  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 11      {"pids":[9293],"scriptVersion":1029,"time":170...
# 61      {"requests":[{"requestId":"323ae658-e2df-4d62-...
# 77      {"tags":[{"sizes":[{"width":728,"height":90},{...
# 78      {"tags":[{"sizes":[{"width":728,"height":90},{...
# 79      {"id":"9a6fb5caf8609a","site":{"page":"https:/...
# ...                                                   ...
# 103220  ping_context=%7B%22embedId%22%3A%22p4d2wxp9n4g...
# 103222  embed_id=p4d2wxp9n4gk&client_id=f6zuizdyhxrm7r...
# 103224  {"orgId":5090900,"inboxId":732344,"userId":nul...
# 103225  {"conditionGroups":[{"status":"EVALUATED","mat...
# 103227  {"playbookId":2710693,"campaignId":2807427,"in...
#
#                                                post_leaks       leaks  \
# 11                                       [('/research',)]  post_leaks
# 61      [('/borderfreecosmetics/entry-12761950217.html...  post_leaks
# 77      [('/cp/621/kleding-dames/',), ('www.marktplaat...  post_leaks
# 78      [('/cp/621/kleding-dames/',), ('www.marktplaat...  post_leaks
# 79      [('/cp/621/kleding-dames/',), ('www.marktplaat...  post_leaks
# ...                                                   ...         ...
# 103220  [('www.docker.com',), ('urlencode', '/products...  post_leaks
# 103222  [('www.docker.com',), ('urlencode', '/products...  post_leaks
# 103224  [('www.docker.com',), ('/products/docker-scout...  post_leaks
# 103225  [('www.docker.com',), ('/products/docker-scout...  post_leaks
# 103227  [('www.docker.com',), ('/products/docker-scout...  post_leaks
#
#                     netloc                                         path query  \
# 11                                                            /research
# 61               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 77      www.marktplaats.nl                       /cp/621/kleding-dames/
# 78      www.marktplaats.nl                       /cp/621/kleding-dames/
# 79      www.marktplaats.nl                       /cp/621/kleding-dames/
# ...                    ...                                          ...   ...
# 103220      www.docker.com                      /products/docker-scout/
# 103222      www.docker.com                      /products/docker-scout/
# 103224      www.docker.com                      /products/docker-scout/
# 103225      www.docker.com                      /products/docker-scout/
# 103227      www.docker.com                      /products/docker-scout/
#
#        params fragments  violation
# 11                       Violation
# 61                       Violation
# 77                       Violation
# 78                       Violation
# 79                       Violation
# ...       ...       ...        ...
# 103220                   Violation
# 103222                   Violation
# 103224                   Violation
# 103225                   Violation
# 103227                   Violation
#
# [8670 rows x 14 columns]

# %%
# print to csv

post_leaks_vioilation_df['post_data'] = [str(x)[:2048] for x in post_leaks_vioilation_df['post_data']] # convert to string and truncate post_data to 2048 characters
print_leak_to_csv(post_leaks_vioilation_df)
# Out:
# /var/folders/yp/0zbrv4s17t13rbr4qvh6rz1h0000gn/T/ipykernel_15154/1834663399.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post_leaks_vioilation_df['post_data'] = [str(x)[:2048] for x in post_leaks_vioilation_df['post_data']] # convert to string and truncate post_data to 2048 characters

# %%
post_leaks_vioilation_df.count()
# Out:
# init_url        8670
# final_url       8670
# req_url         8670
# req_method      8670
# ref_pol_data    8670
# post_data       8670
# post_leaks      8670
# leaks           8670
# netloc          8670
# path            8670
# query           8670
# params          8670
# fragments       8670
# violation       8670
# dtype: int64

# %%
post_leaks_vioilation_df.req_method.value_counts()
# Out:
# POST    8668
# PUT        2
# Name: req_method, dtype: int64

# %% [markdown]
# ### Leaks to Google, facebook, and Meta

# %%
# list of post data leaks to google
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)]
# Out:
#                                                  init_url  \
# 84        https://www.marktplaats.nl/cp/621/kleding-dames
# 85        https://www.marktplaats.nl/cp/621/kleding-dames
# 86        https://www.marktplaats.nl/cp/621/kleding-dames
# 88        https://www.marktplaats.nl/cp/621/kleding-dames
# 89        https://www.marktplaats.nl/cp/621/kleding-dames
# ...                                                   ...
# 101512  https://www.gismeteo.ru/weather-hayward-execut...
# 102143  https://wordpress.com/start/?ref=logged-out-ho...
# 102619                    https://www.weebly.com/websites
# 102620                    https://www.weebly.com/websites
# 102621                    https://www.weebly.com/websites
#
#                                                 final_url  \
# 84       https://www.marktplaats.nl/cp/621/kleding-dames/
# 85       https://www.marktplaats.nl/cp/621/kleding-dames/
# 86       https://www.marktplaats.nl/cp/621/kleding-dames/
# 88       https://www.marktplaats.nl/cp/621/kleding-dames/
# 89       https://www.marktplaats.nl/cp/621/kleding-dames/
# ...                                                   ...
# 101512  https://www.gismeteo.ru/weather-hayward-execut...
# 102143  https://wordpress.com/start/user-social?ref=lo...
# 102619                    https://www.weebly.com/websites
# 102620                    https://www.weebly.com/websites
# 102621                    https://www.weebly.com/websites
#
#                                          req_url req_method  \
# 84      https://www.google-analytics.com/collect       POST
# 85      https://www.google-analytics.com/collect       POST
# 86      https://www.google-analytics.com/collect       POST
# 88      https://www.google-analytics.com/collect       POST
# 89      https://www.google-analytics.com/collect       POST
# ...                                          ...        ...
# 101512  https://www.google-analytics.com/collect       POST
# 102143  https://www.google-analytics.com/collect       POST
# 102619  https://www.google-analytics.com/collect       POST
# 102620  https://www.google-analytics.com/collect       POST
# 102621  https://www.google-analytics.com/collect       POST
#
#                            ref_pol_data  \
# 84      strict-origin-when-cross-origin
# 85      strict-origin-when-cross-origin
# 86      strict-origin-when-cross-origin
# 88      strict-origin-when-cross-origin
# 89      strict-origin-when-cross-origin
# ...                                 ...
# 101512  strict-origin-when-cross-origin
# 102143                           origin
# 102619  strict-origin-when-cross-origin
# 102620  strict-origin-when-cross-origin
# 102621  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 84      v=1&_v=j101&a=1693760922&t=event&_s=2&dl=https...
# 85      v=1&_v=j101&a=1693760922&t=event&_s=3&dl=https...
# 86      v=1&_v=j101&a=1693760922&t=event&_s=4&dl=https...
# 88      v=1&_v=j101&a=1693760922&t=event&_s=5&dl=https...
# 89      v=1&_v=j101&a=1693760922&t=event&_s=6&dl=https...
# ...                                                   ...
# 101512  v=1&_v=j101&aip=0&a=2001831229&t=timing&ds=des...
# 102143  v=1&_v=j101&aip=1&a=2015635416&t=pageview&_s=2...
# 102619  v=1&_v=j101&a=1926208616&t=pageview&_s=1&dl=ht...
# 102620  v=1&_v=j101&a=1926208616&t=event&ni=0&_s=1&dl=...
# 102621  v=1&_v=j101&a=1926208616&t=timing&_s=2&dl=http...
#
#                                                post_leaks       leaks  \
# 84      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 85      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 86      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 88      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 89      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# ...                                                   ...         ...
# 101512  [('www.gismeteo.ru',), ('urlencode', '/weather...  post_leaks
# 102143  [('urlencode', '/start/user-social'), ('urlenc...  post_leaks
# 102619  [('www.weebly.com',), ('urlencode', '/websites')]  post_leaks
# 102620  [('www.weebly.com',), ('urlencode', '/websites')]  post_leaks
# 102621  [('www.weebly.com',), ('urlencode', '/websites')]  post_leaks
#
#                     netloc                               path  \
# 84      www.marktplaats.nl             /cp/621/kleding-dames/
# 85      www.marktplaats.nl             /cp/621/kleding-dames/
# 86      www.marktplaats.nl             /cp/621/kleding-dames/
# 88      www.marktplaats.nl             /cp/621/kleding-dames/
# 89      www.marktplaats.nl             /cp/621/kleding-dames/
# ...                    ...                                ...
# 101512     www.gismeteo.ru  /weather-hayward-executive-28925/
# 102143       wordpress.com                 /start/user-social
# 102619      www.weebly.com                          /websites
# 102620      www.weebly.com                          /websites
# 102621      www.weebly.com                          /websites
#
#                              query params fragments  violation
# 84                                                   Violation
# 85                                                   Violation
# 86                                                   Violation
# 88                                                   Violation
# 89                                                   Violation
# ...                            ...    ...       ...        ...
# 101512                                               Violation
# 102143  ref=logged-out-homepage-lp                   Violation
# 102619                                               Violation
# 102620                                               Violation
# 102621                                               Violation
#
# [520 rows x 14 columns]

# %%
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)].count()
# Out:
# init_url        520
# final_url       520
# req_url         520
# req_method      520
# ref_pol_data    520
# post_data       520
# post_leaks      520
# leaks           520
# netloc          520
# path            520
# query           520
# params          520
# fragments       520
# violation       520
# dtype: int64

# %%
# list of post data leaks to Meta or Facebook
post_leaks_vioilation_df[
    post_leaks_vioilation_df['req_url']
    .str
    .contains('meta') 
    | post_leaks_vioilation_df['req_url']
        .str.contains('facebook')]
# Out:
#                                                 init_url  \
# 1674    https://www.samsung.com/us/watches/galaxy-watch6
# 2613   https://www.oracle.com/cx/advertising/measurem...
# 8358   https://www.samsung.com/us/mobile/audio/headph...
# 18725  https://www.appsflyer.com/solutions/entertainm...
# 22922                       https://www.pendo.io/pricing
# 22923                       https://www.pendo.io/pricing
# 24760            https://explore.zoom.us/en/ai-assistant
# 25695  https://www.nikkei.com/article/dgxzqoua067j10w...
# 25864  https://www.pendo.io/ai-for-product-management...
# 25865  https://www.pendo.io/ai-for-product-management...
# 26941         https://www.appsflyer.com/solutions/travel
# 27461  https://www.nikkei.com/article/dgxzqogn061ye0w...
# 32172               https://www.aliexpress.us/?a11y=true
# 32986  https://consumer.huawei.com/en/wearables/watch...
# 33392  https://www.appsflyer.com/solutions/health-fit...
# 39432  https://www.index.hr/vijesti/rubrika/komentari...
# 39906  https://www.aliexpress.us/?gatewayadapt=glo2us...
# 42575                  https://www.upwork.com/enterprise
# 45935                            https://zoom.us/pricing
# 46572  https://www.nikkei.com/article/dgxzqouc282yd0y...
# 50015        https://www.netgear.com/home/wifi/mesh/orbi
# 54474  https://www.nikkei.com/article/dgxzqogn0688e0w...
# 55459                         https://www.netgear.com/av
# 61603            https://www.pendo.io/legal/cookiepolicy
# 61604            https://www.pendo.io/legal/cookiepolicy
# 64940                      https://www.pendo.io/startups
# 64941                      https://www.pendo.io/startups
# 68481       https://www.appsflyer.com/products/audiences
# 72669  https://www.index.hr/vijesti/rubrika/crna-kron...
#
#                                                final_url  \
# 1674   https://www.samsung.com/us/watches/galaxy-watch6/
# 2613   https://www.oracle.com/cx/advertising/measurem...
# 8358   https://www.samsung.com/us/mobile/audio/headph...
# 18725  https://www.appsflyer.com/solutions/entertainm...
# 22922                      https://www.pendo.io/pricing/
# 22923                      https://www.pendo.io/pricing/
# 24760              https://www.zoom.com/en/ai-assistant/
# 25695  https://www.nikkei.com/article/dgxzqoua067j10w...
# 25864  https://www.pendo.io/ai-for-product-management...
# 25865  https://www.pendo.io/ai-for-product-management...
# 26941        https://www.appsflyer.com/solutions/travel/
# 27461  https://www.nikkei.com/article/dgxzqogn061ye0w...
# 32172               https://www.aliexpress.us/?a11y=true
# 32986  https://consumer.huawei.com/en/wearables/watch...
# 33392  https://www.appsflyer.com/solutions/health-fit...
# 39432  https://www.index.hr/vijesti/rubrika/komentari...
# 39906  https://www.aliexpress.us/?gatewayadapt=glo2us...
# 42575                  https://www.upwork.com/enterprise
# 45935                            https://zoom.us/pricing
# 46572  https://www.nikkei.com/article/dgxzqouc282yd0y...
# 50015       https://www.netgear.com/home/wifi/mesh/orbi/
# 54474  https://www.nikkei.com/article/dgxzqogn0688e0w...
# 55459                        https://www.netgear.com/av/
# 61603           https://www.pendo.io/legal/cookiepolicy/
# 61604           https://www.pendo.io/legal/cookiepolicy/
# 64940                     https://www.pendo.io/startups/
# 64941                     https://www.pendo.io/startups/
# 68481      https://www.appsflyer.com/products/audiences/
# 72669  https://www.index.hr/vijesti/rubrika/crna-kron...
#
#                                                  req_url req_method  \
# 1674                        https://www.facebook.com/tr/       POST
# 2613                        https://www.facebook.com/tr/       POST
# 8358                        https://www.facebook.com/tr/       POST
# 18725                 https://api-gw.metadata.io/traffic       POST
# 22922                 https://api-gw.metadata.io/traffic       POST
# 22923                 https://api-gw.metadata.io/traffic       POST
# 24760                 https://api-gw.metadata.io/traffic       POST
# 25695                       https://www.facebook.com/tr/       POST
# 25864                 https://api-gw.metadata.io/traffic       POST
# 25865                 https://api-gw.metadata.io/traffic       POST
# 26941                 https://api-gw.metadata.io/traffic       POST
# 27461                       https://www.facebook.com/tr/       POST
# 32172                       https://www.facebook.com/tr/       POST
# 32986                       https://www.facebook.com/tr/       POST
# 33392                 https://api-gw.metadata.io/traffic       POST
# 39432  https://www.facebook.com/platform/plugin/page/...       POST
# 39906                       https://www.facebook.com/tr/       POST
# 42575                       https://www.facebook.com/tr/       POST
# 45935                 https://api-gw.metadata.io/traffic       POST
# 46572                       https://www.facebook.com/tr/       POST
# 50015                       https://www.facebook.com/tr/       POST
# 54474                       https://www.facebook.com/tr/       POST
# 55459                       https://www.facebook.com/tr/       POST
# 61603                 https://api-gw.metadata.io/traffic       POST
# 61604                 https://api-gw.metadata.io/traffic       POST
# 64940                 https://api-gw.metadata.io/traffic       POST
# 64941                 https://api-gw.metadata.io/traffic       POST
# 68481                 https://api-gw.metadata.io/traffic       POST
# 72669  https://www.facebook.com/platform/plugin/page/...       POST
#
#                           ref_pol_data  \
# 1674   strict-origin-when-cross-origin
# 2613   strict-origin-when-cross-origin
# 8358   strict-origin-when-cross-origin
# 18725  strict-origin-when-cross-origin
# 22922  strict-origin-when-cross-origin
# 22923  strict-origin-when-cross-origin
# 24760         origin-when-cross-origin
# 25695  strict-origin-when-cross-origin
# 25864  strict-origin-when-cross-origin
# 25865  strict-origin-when-cross-origin
# 26941  strict-origin-when-cross-origin
# 27461  strict-origin-when-cross-origin
# 32172  strict-origin-when-cross-origin
# 32986  strict-origin-when-cross-origin
# 33392  strict-origin-when-cross-origin
# 39432         origin-when-cross-origin
# 39906  strict-origin-when-cross-origin
# 42575  strict-origin-when-cross-origin
# 45935         origin-when-cross-origin
# 46572  strict-origin-when-cross-origin
# 50015  strict-origin-when-cross-origin
# 54474  strict-origin-when-cross-origin
# 55459  strict-origin-when-cross-origin
# 61603  strict-origin-when-cross-origin
# 61604  strict-origin-when-cross-origin
# 64940  strict-origin-when-cross-origin
# 64941  strict-origin-when-cross-origin
# 68481  strict-origin-when-cross-origin
# 72669         origin-when-cross-origin
#
#                                                post_data  \
# 1674   id=1049256285582240&ev=Microdata&dl=https%3A%2...
# 2613   id=704367189971874&ev=PageView&dl=https%3A%2F%...
# 8358   id=1049256285582240&ev=Microdata&dl=https%3A%2...
# 18725  {"url":"https://www.appsflyer.com/solutions/en...
# 22922  {"url":"https://www.pendo.io/pricing/","url_re...
# 22923  {"url":"https://www.pendo.io/pricing/","url_re...
# 24760  {"url":"https://www.zoom.com/en/ai-assistant/"...
# 25695  id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 25864  {"url":"https://www.pendo.io/ai-for-product-ma...
# 25865  {"url":"https://www.pendo.io/ai-for-product-ma...
# 26941  {"url":"https://www.appsflyer.com/solutions/tr...
# 27461  id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 32172  id=1650958108523345&ev=Microdata&dl=https%3A%2...
# 32986  id=594019051559898&ev=Microdata&dl=https%3A%2F...
# 33392  {"url":"https://www.appsflyer.com/solutions/he...
# 39432  event_name=page_plugin.tab.configured&page_id=...
# 39906  id=1650958108523345&ev=Microdata&dl=https%3A%2...
# 42575  id=816554411748126&ev=Microdata&dl=https%3A%2F...
# 45935  {"url":"https://zoom.us/pricing","url_referrer...
# 46572  id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 50015  id=431542533712561&ev=Microdata&dl=https%3A%2F...
# 54474  id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 55459  id=431542533712561&ev=Microdata&dl=https%3A%2F...
# 61603  {"url":"https://www.pendo.io/legal/cookiepolic...
# 61604  {"url":"https://www.pendo.io/legal/cookiepolic...
# 64940  {"url":"https://www.pendo.io/startups/","url_r...
# 64941  {"url":"https://www.pendo.io/startups/","url_r...
# 68481  {"url":"https://www.appsflyer.com/products/aud...
# 72669  event_name=page_plugin.tab.configured&page_id=...
#
#                                               post_leaks  \
# 1674   [('www.samsung.com',), ('urlencode', '/us/watc...
# 2613   [('urlencode', 'urlencode', '/cx/advertising/m...
# 8358   [('urlencode', '/us/mobile/audio/headphones/ga...
# 18725  [('/solutions/entertainment-music/',), ('www.a...
# 22922                [('/pricing/',), ('www.pendo.io',)]
# 22923                [('/pricing/',), ('www.pendo.io',)]
# 24760        [('www.zoom.com',), ('/en/ai-assistant/',)]
# 25695  [('www.nikkei.com',), ('urlencode', '/article/...
# 25864  [('/ai-for-product-management-course/',), ('ww...
# 25865  [('/ai-for-product-management-course/',), ('ww...
# 26941  [('www.appsflyer.com',), ('/solutions/travel/',)]
# 27461  [('www.nikkei.com',), ('urlencode', '/article/...
# 32172  [('www.aliexpress.us',), ('urlencode', 'a11y=t...
# 32986  [('urlencode', 'ic_medium=hwdc&ic_source=corp_...
# 33392  [('/solutions/health-fitness/',), ('www.appsfl...
# 39432  [('urlencode', '/vijesti/rubrika/komentari/141...
# 39906  [('www.aliexpress.us',), ('urlencode', 'gatewa...
# 42575  [('www.upwork.com',), ('urlencode', '/enterpri...
# 45935                      [('/pricing',), ('zoom.us',)]
# 46572  [('www.nikkei.com',), ('urlencode', '/article/...
# 50015  [('www.netgear.com',), ('urlencode', '/home/wi...
# 54474  [('www.nikkei.com',), ('urlencode', '/article/...
# 55459      [('www.netgear.com',), ('urlencode', '/av/')]
# 61603     [('/legal/cookiepolicy/',), ('www.pendo.io',)]
# 61604     [('/legal/cookiepolicy/',), ('www.pendo.io',)]
# 64940               [('/startups/',), ('www.pendo.io',)]
# 64941               [('/startups/',), ('www.pendo.io',)]
# 68481  [('www.appsflyer.com',), ('/products/audiences...
# 72669  [('www.index.hr',), ('urlencode', '/vijesti/ru...
#
#                             leaks               netloc  \
# 1674                   post_leaks      www.samsung.com
# 2613                   post_leaks       www.oracle.com
# 8358                   post_leaks      www.samsung.com
# 18725                  post_leaks    www.appsflyer.com
# 22922                  post_leaks         www.pendo.io
# 22923                  post_leaks         www.pendo.io
# 24760                  post_leaks         www.zoom.com
# 25695                  post_leaks       www.nikkei.com
# 25864                  post_leaks         www.pendo.io
# 25865                  post_leaks         www.pendo.io
# 26941                  post_leaks    www.appsflyer.com
# 27461                  post_leaks       www.nikkei.com
# 32172                  post_leaks    www.aliexpress.us
# 32986                  post_leaks  consumer.huawei.com
# 33392                  post_leaks    www.appsflyer.com
# 39432  post_leaks - referer_leaks         www.index.hr
# 39906                  post_leaks    www.aliexpress.us
# 42575                  post_leaks       www.upwork.com
# 45935                  post_leaks              zoom.us
# 46572                  post_leaks       www.nikkei.com
# 50015                  post_leaks      www.netgear.com
# 54474                  post_leaks       www.nikkei.com
# 55459                  post_leaks      www.netgear.com
# 61603                  post_leaks         www.pendo.io
# 61604                  post_leaks         www.pendo.io
# 64940                  post_leaks         www.pendo.io
# 64941                  post_leaks         www.pendo.io
# 68481                  post_leaks    www.appsflyer.com
# 72669  post_leaks - referer_leaks         www.index.hr
#
#                                                     path  \
# 1674                          /us/watches/galaxy-watch6/
# 2613   /cx/advertising/measurement/publishers-platforms/
# 8358   /us/mobile/audio/headphones/galaxy-buds2-pro-b...
# 18725                    /solutions/entertainment-music/
# 22922                                          /pricing/
# 22923                                          /pricing/
# 24760                                  /en/ai-assistant/
# 25695             /article/dgxzqoua067j10w3a201c2000000/
# 25864                 /ai-for-product-management-course/
# 25865                 /ai-for-product-management-course/
# 26941                                 /solutions/travel/
# 27461             /article/dgxzqogn061ye0w3a201c2000000/
# 32172
# 32986                           /en/wearables/watch-gt4/
# 33392                         /solutions/health-fitness/
# 39432               /vijesti/rubrika/komentari/1413.aspx
# 39906
# 42575                                        /enterprise
# 45935                                           /pricing
# 46572             /article/dgxzqouc282yd0y3a121c2000000/
# 50015                              /home/wifi/mesh/orbi/
# 54474             /article/dgxzqogn0688e0w3a201c2000000/
# 55459                                               /av/
# 61603                               /legal/cookiepolicy/
# 61604                               /legal/cookiepolicy/
# 64940                                         /startups/
# 64941                                         /startups/
# 68481                               /products/audiences/
# 72669              /vijesti/rubrika/crna-kronika/46.aspx
#
#                                                 query params fragments  \
# 1674
# 2613
# 8358
# 18725
# 22922
# 22923
# 24760
# 25695
# 25864
# 25865
# 26941
# 27461
# 32172                                       a11y=true
# 32986  ic_medium=hwdc&ic_source=corp_banner1_watchgt4
# 33392
# 39432
# 39906                            gatewayadapt=glo2usa
# 42575
# 45935
# 46572
# 50015
# 54474
# 55459
# 61603
# 61604
# 64940
# 64941
# 68481
# 72669
#
#        violation
# 1674   Violation
# 2613   Violation
# 8358   Violation
# 18725  Violation
# 22922  Violation
# 22923  Violation
# 24760  Violation
# 25695  Violation
# 25864  Violation
# 25865  Violation
# 26941  Violation
# 27461  Violation
# 32172  Violation
# 32986  Violation
# 33392  Violation
# 39432  Violation
# 39906  Violation
# 42575  Violation
# 45935  Violation
# 46572  Violation
# 50015  Violation
# 54474  Violation
# 55459  Violation
# 61603  Violation
# 61604  Violation
# 64940  Violation
# 64941  Violation
# 68481  Violation
# 72669  Violation

# %%
post_leaks_vioilation_df[
    post_leaks_vioilation_df['req_url']
    .str
    .contains('meta') 
    | post_leaks_vioilation_df['req_url']
        .str.contains('facebook')].count()
# Out:
# init_url        29
# final_url       29
# req_url         29
# req_method      29
# ref_pol_data    29
# post_data       29
# post_leaks      29
# leaks           29
# netloc          29
# path            29
# query           29
# params          29
# fragments       29
# violation       29
# dtype: int64

# %%
# list of post data leaks to tiktok
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('tiktok').fillna(False)]
# Out:
#                                                  init_url  \
# 358                https://www.life360.com/driving-safety
# 362                https://www.life360.com/driving-safety
# 376     https://www.change.org/member?source_location=...
# 377     https://www.change.org/member?source_location=...
# 479                         https://app.life360.com/login
# ...                                                   ...
# 101426          https://www.eventbrite.com/b/local/health
# 101433          https://www.eventbrite.com/b/local/health
# 101435          https://www.eventbrite.com/b/local/health
# 102127  https://www.discogs.com/group/thread/963554?ev...
# 102128  https://www.discogs.com/group/thread/963554?ev...
#
#                                                 final_url  \
# 358               https://www.life360.com/driving-safety/
# 362               https://www.life360.com/driving-safety/
# 376     https://www.change.org/s/member?source_locatio...
# 377     https://www.change.org/s/member?source_locatio...
# 479           https://app.life360.com/login?web_loc=login
# ...                                                   ...
# 101426  https://www.eventbrite.com/d/ca--santa-clara/e...
# 101433  https://www.eventbrite.com/d/ca--santa-clara/e...
# 101435  https://www.eventbrite.com/d/ca--santa-clara/e...
# 102127  https://www.discogs.com/group/thread/963554?ev...
# 102128  https://www.discogs.com/group/thread/963554?ev...
#
#                                               req_url req_method  \
# 358         https://analytics.tiktok.com/api/v2/pixel       POST
# 362     https://analytics.tiktok.com/api/v2/pixel/act       POST
# 376         https://analytics.tiktok.com/api/v2/pixel       POST
# 377     https://analytics.tiktok.com/api/v2/pixel/act       POST
# 479         https://analytics.tiktok.com/api/v2/pixel       POST
# ...                                               ...        ...
# 101426      https://analytics.tiktok.com/api/v2/pixel       POST
# 101433  https://analytics.tiktok.com/api/v2/pixel/act       POST
# 101435  https://analytics.tiktok.com/api/v2/pixel/act       POST
# 102127      https://analytics.tiktok.com/api/v2/pixel       POST
# 102128  https://analytics.tiktok.com/api/v2/pixel/act       POST
#
#                            ref_pol_data  \
# 358     strict-origin-when-cross-origin
# 362     strict-origin-when-cross-origin
# 376     strict-origin-when-cross-origin
# 377     strict-origin-when-cross-origin
# 479                       strict-origin
# ...                                 ...
# 101426  strict-origin-when-cross-origin
# 101433  strict-origin-when-cross-origin
# 101435  strict-origin-when-cross-origin
# 102127  strict-origin-when-cross-origin
# 102128  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 358     {"event":"Pageview","message_id":"messageId-17...
# 362     {"message_id":"messageId-1702065622324-6156731...
# 376     {"event":"Pageview","message_id":"messageId-17...
# 377     {"message_id":"messageId-1702023765049-6504334...
# 479     {"event":"Pageview","message_id":"messageId-17...
# ...                                                   ...
# 101426  {"event":"Pageview","message_id":"messageId-17...
# 101433  {"message_id":"messageId-1701992460419-9518802...
# 101435  {"message_id":"messageId-1701992460419-9518802...
# 102127  {"event":"Pageview","message_id":"messageId-17...
# 102128  {"message_id":"messageId-1702066328121-9816964...
#
#                                                post_leaks       leaks  \
# 358         [('/driving-safety/',), ('www.life360.com',)]  post_leaks
# 362         [('/driving-safety/',), ('www.life360.com',)]  post_leaks
# 376     [('www.change.org',), ('source_location=member...  post_leaks
# 377     [('www.change.org',), ('source_location=member...  post_leaks
# 479                   [('app.life360.com',), ('/login',)]  post_leaks
# ...                                                   ...         ...
# 101426  [('/d/ca--santa-clara/events/',), ('www.eventb...  post_leaks
# 101433  [('/d/ca--santa-clara/events/',), ('urlencode'...  post_leaks
# 101435  [('/d/ca--santa-clara/events/',), ('urlencode'...  post_leaks
# 102127  [('ev=em_bt',), ('/group/thread/963554',), ('w...  post_leaks
# 102128  [('ev=em_bt',), ('/group/thread/963554',), ('w...  post_leaks
#
#                     netloc                        path  \
# 358        www.life360.com            /driving-safety/
# 362        www.life360.com            /driving-safety/
# 376         www.change.org                   /s/member
# 377         www.change.org                   /s/member
# 479        app.life360.com                      /login
# ...                    ...                         ...
# 101426  www.eventbrite.com  /d/ca--santa-clara/events/
# 101433  www.eventbrite.com  /d/ca--santa-clara/events/
# 101435  www.eventbrite.com  /d/ca--santa-clara/events/
# 102127     www.discogs.com        /group/thread/963554
# 102128     www.discogs.com        /group/thread/963554
#
#                                      query params fragments  violation
# 358                                                          Violation
# 362                                                          Violation
# 376     source_location=member_link_header                   Violation
# 377     source_location=member_link_header                   Violation
# 479                                                          Violation
# ...                                    ...    ...       ...        ...
# 101426                                                       Violation
# 101433                                                       Violation
# 101435                                                       Violation
# 102127                            ev=em_bt                   Violation
# 102128                            ev=em_bt                   Violation
#
# [407 rows x 14 columns]

# %%
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('tiktok').fillna(False)].count()
# Out:
# init_url        407
# final_url       407
# req_url         407
# req_method      407
# ref_pol_data    407
# post_data       407
# post_leaks      407
# leaks           407
# netloc          407
# path            407
# query           407
# params          407
# fragments       407
# violation       407
# dtype: int64
