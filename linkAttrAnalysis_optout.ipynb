# %%
# Re-importing the necessary libraries
import json
import pandas as pd
import os
import glob
from os.path import basename
import numpy as np
from utils import  get_initiators, get_ps1_or_host, get_referrer,check_third_party, match_entity, get_visit_metadata, is_failed_visit

# %%
def get_response_referrer_policy(request):
    try:
        return request['responseHeaders'].get('referrer-policy', '')
    except KeyError:
        return ""
    
def get_req_referrer_policy(request):
    try:
        return request['reqReferrerPolicy']
    except KeyError:
        return ""

# %%
def get_all_reqs(path, saved_req_file_path):
    """
    Extracts request information from the JSON files in the given path.
    
    Args:
    path (str): The path to the JSON files containing the request data.
    
    Returns:
    reqDF (pd.DataFrame): A DataFrame containing the request information.
    """
    rows_list = []
    to_drop = []
    attr_list = []
    meta_list = []
    # dir_path = os.path.dirname(path)

    for json_path in glob.glob(path):
        json_name = basename(json_path)

        try:
            with open(json_path) as file:
                results = json.load(file)
        except Exception as e:
            print("ERROR: Cannot load the json", json_name, e)
            continue

        # Get visit metadata and check whether it should be processed
        init_url, final_url, site_domain, should_process = get_visit_metadata(results, json_name)
        if not should_process or is_failed_visit(results):
            to_drop.append(json_path)
            continue

        try:
            requests = results["data"]["requests"]
            for request in requests:
                request_url = request['url']
                status = request.get("status")
                size = request.get("size")
                request_url_domain = get_ps1_or_host(request_url)
                site_fld = get_ps1_or_host(site_domain)
                referrer = get_referrer(request)
                post_data = request.get('postData', '')
                request_type = (request['type']).lower()
                req_initiators = get_initiators(request['initiators'])
                third_party_req = site_fld != request_url_domain
                response_ref_policy = (get_response_referrer_policy(request))
                req_ref_policy = (get_req_referrer_policy(request))
                req_details = (site_domain, request_url, request_url_domain, referrer, request_type, req_initiators, third_party_req, post_data, final_url, init_url, status, size, response_ref_policy, req_ref_policy)
                rows_list.append(req_details)
        except Exception as err:
            print('Error get_all_reqs', site_domain, err)
        try:
            linkAttributes = results["data"]["elementAttributes"]
            for link in linkAttributes["elmAttrs"]:
                # print("--site_domain--", site_domain)
                href = link['href']
                src = link['src']
                rel = link['rel']
                referrerpolicy = link['linkReferrerPolicy']
                title = link['title']
                text = link['text']
                frameUrl = link['frameUrl']
                tagName = link['tagName']
                isFrame = link['inFrame']
                type = link['type']
                crossorigin = link['crossorigin']
                as_attr = link['as']
                integrity = link['integrity']
                link_details = (init_url, href, src, rel, referrerpolicy, title, text, frameUrl, tagName, isFrame, type, crossorigin, as_attr, integrity)
                attr_list.append(link_details)
            for meta in linkAttributes["metaRP"]:
                referrer_policy = meta["metaReferrerContent"]
                # print(referrer_policy)
                frameUrl = meta['frameUrl']
                inFrame = meta['inFrame']
                pageURL = meta['pageUrl']
                # print (pageURL)
                metadata_details = (init_url, referrer_policy, frameUrl, inFrame, pageURL)
                meta_list.append(metadata_details)
        except Exception as err:
            print('Error linkAttributes', site_domain, err)
            

    # Save excluded JSON files
    file_name = '_'.join(path.split("/")[-2].split("_")) + '_to_drop.txt'
    with open(f'to_drop_JSONs/{file_name}', 'w') as file:
        file.write('\n'.join(to_drop))

    reqDF = pd.DataFrame(rows_list, columns=['site_domain', 'request_url', 'request_url_domain', 'referrer', 
                                             'request_type', 'req_initiators', 'third_party_req', 'post_data', 'final_url', 'init_url', 'status', 'size', 'response_ref_policy', 'req_ref_policy'])
    reqDF.to_csv(saved_req_file_path, index=False)
    attrDF = pd.DataFrame(attr_list, columns=['init_url', 'href', 'src', 'rel', 'referrerpolicy', 'title', 'text', 'frameUrl', 'tagName', 'isFrame', 'type', 'crossorigin', 'as_attr', 'integrity'])
    # attrDF.to_json(saved_req_file_path.replace('requests', 'linkAttrs'), orient='records')
    attrDF.to_csv(saved_req_file_path.replace('requests', 'linkAttrs'), index=False)
    metaDF = pd.DataFrame(meta_list, columns=['init_url', 'referrer_policy', 'frameUrl', 'inFrame', 'pageURL'])
    metaDF.to_csv(saved_req_file_path.replace('requests', 'metadata'), index=False)


    return reqDF, attrDF, metaDF

# %%
# path = '../2023-10-11_inner_collector/*.json'
# path = '../2023-11-06_inner_collector/*.json'
path = './2023-12-07_inner_collector_optout/*.json'

def create_directory(directory_name):
    if not os.path.exists(directory_name):
        os.makedirs(directory_name)
        # return path of the created directory
    return os.path.join(os.getcwd(), directory_name)

saved_requests_dir_path = create_directory('saved_requests')
saved_linkAttrs_dir_path = create_directory('saved_linkAttrs')
saved_meta_dir_path = create_directory('saved_metadata')
drop_dir_path = create_directory('to_drop_JSONs')

file_name_reqs = '_'.join(path.split("/")[-2].split("_")) + '_requests.csv'
saved_req_file_path = os.path.join(saved_requests_dir_path, file_name_reqs)

# %%
df_req, df_attr, df_meta = get_all_reqs(path, saved_req_file_path)
# Out:
# Error linkAttributes yandex.com 'text'
# Error linkAttributes detik.com 'text'
# ERROR: error page   metadata.json
# ERROR: NO FINAL or INIT URL:  metadata.json
# ERROR: No data  metadata.json
# Error linkAttributes onet.pl 'text'
# Error linkAttributes umn.edu 'text'
# Error linkAttributes umn.edu 'text'
# Error linkAttributes umn.edu 'text'
# Error linkAttributes umn.edu 'text'

# %%
df_req
# Out:
#        site_domain                                        request_url  \
# 0         ox.ac.uk                      https://www.ox.ac.uk/research
# 1         ox.ac.uk  https://www.ox.ac.uk/sites/files/oxford/advagg...
# 2         ox.ac.uk  https://www.ox.ac.uk/sites/files/oxford/advagg...
# 3         ox.ac.uk  https://www.ox.ac.uk/sites/files/oxford/advagg...
# 4         ox.ac.uk  https://fonts.googleapis.com/css?family=PT+San...
# ...            ...                                                ...
# 493665     mbga.jp  https://aw.dw.impact-ad.jp/c/u/?gdpr=0&oid=207...
# 493666     mbga.jp  https://aw.dw.impact-ad.jp/c/map/?sp=cro&oid=2...
# 493667     mbga.jp                https://id5-sync.com/g/v2/1270.json
# 493668     mbga.jp  https://aw.dw.impact-ad.jp/c/map/?sp=ttd&oid=2...
# 493669     mbga.jp  https://yjtag.yahoo.co.jp/cs?btt=XZhi2oyJZHoi6...
#
#           request_url_domain                              referrer  \
# 0                   ox.ac.uk
# 1                   ox.ac.uk         https://www.ox.ac.uk/research
# 2                   ox.ac.uk         https://www.ox.ac.uk/research
# 3                   ox.ac.uk         https://www.ox.ac.uk/research
# 4       fonts.googleapis.com                 https://www.ox.ac.uk/
# ...                      ...                                   ...
# 493665          impact-ad.jp
# 493666          impact-ad.jp
# 493667          id5-sync.com  https://6015542.fls.doubleclick.net/
# 493668          impact-ad.jp
# 493669           yahoo.co.jp
#
#        request_type  req_initiators  third_party_req  \
# 0          document              {}            False
# 1        stylesheet      {ox.ac.uk}            False
# 2        stylesheet      {ox.ac.uk}            False
# 3        stylesheet      {ox.ac.uk}            False
# 4        stylesheet      {ox.ac.uk}             True
# ...             ...             ...              ...
# 493665        image  {impact-ad.jp}             True
# 493666        image  {impact-ad.jp}             True
# 493667          xhr  {impact-ad.jp}             True
# 493668        image  {impact-ad.jp}             True
# 493669        image  {impact-ad.jp}             True
#
#                                                 post_data  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 493665
# 493666
# 493667  {"partner":1270,"v":"1.0.36","o":"api","tml":"...
# 493668
# 493669
#
#                                                 final_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 493665  https://www.andapp.jp/apps/12016007?from=www_m...
# 493666  https://www.andapp.jp/apps/12016007?from=www_m...
# 493667  https://www.andapp.jp/apps/12016007?from=www_m...
# 493668  https://www.andapp.jp/apps/12016007?from=www_m...
# 493669  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                 init_url  status      size  \
# 0                          https://www.ox.ac.uk/research   200.0  110448.0
# 1                          https://www.ox.ac.uk/research   200.0    7799.0
# 2                          https://www.ox.ac.uk/research   200.0    5005.0
# 3                          https://www.ox.ac.uk/research   200.0    6155.0
# 4                          https://www.ox.ac.uk/research   200.0    1367.0
# ...                                                  ...     ...       ...
# 493665  https://www.mbga.jp/_game_intro?game_id=12016007   302.0       NaN
# 493666  https://www.mbga.jp/_game_intro?game_id=12016007   200.0     195.0
# 493667  https://www.mbga.jp/_game_intro?game_id=12016007   200.0    1113.0
# 493668  https://www.mbga.jp/_game_intro?game_id=12016007   200.0      58.0
# 493669  https://www.mbga.jp/_game_intro?game_id=12016007   200.0     559.0
#
#        response_ref_policy                   req_ref_policy
# 0                           strict-origin-when-cross-origin
# 1                           strict-origin-when-cross-origin
# 2                           strict-origin-when-cross-origin
# 3                           strict-origin-when-cross-origin
# 4                           strict-origin-when-cross-origin
# ...                    ...                              ...
# 493665                      strict-origin-when-cross-origin
# 493666                      strict-origin-when-cross-origin
# 493667                      strict-origin-when-cross-origin
# 493668                      strict-origin-when-cross-origin
# 493669                      strict-origin-when-cross-origin
#
# [493670 rows x 14 columns]

# %%
df_attr
# Out:
#                                                  init_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 1026308  https://www.mbga.jp/_game_intro?game_id=12016007
# 1026309  https://www.mbga.jp/_game_intro?game_id=12016007
# 1026310  https://www.mbga.jp/_game_intro?game_id=12016007
# 1026311  https://www.mbga.jp/_game_intro?game_id=12016007
# 1026312  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                       href  \
# 0        https://www.ox.ac.uk/sites/default/themes/cust...
# 1        https://www.ox.ac.uk/sites/default/themes/cust...
# 2        https://www.ox.ac.uk/sites/default/themes/cust...
# 3                            https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/node/2297
# ...                                                    ...
# 1026308                                               None
# 1026309                                               None
# 1026310                                               None
# 1026311                                      //twitter.com
# 1026312  https://twitter.com/intent/tweet?original_refe...
#
#                                                        src  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 1026308  https://gum.criteo.com/sync?c=333&r=1&u=https%...
# 1026309           https://yjtag.yahoo.co.jp/csx?tp=khADDtf
# 1026310  https://analytics.twitter.com/i/adsct?p_user_i...
# 1026311                                               None
# 1026312                                               None
#
#                                   rel referrerpolicy title  text  \
# 0                       shortcut icon           None  None
# 1                    apple-touch-icon           None  None
# 2        apple-touch-icon-precomposed           None  None
# 3                           canonical           None  None
# 4                           shortlink           None  None
# ...                               ...            ...   ...   ...
# 1026308                          None           None  None
# 1026309                          None           None  None
# 1026310                          None           None  None
# 1026311                  dns-prefetch           None  None
# 1026312                          None           None  None  ツイート
#
#                                                   frameUrl tagName  isFrame  \
# 0                            https://www.ox.ac.uk/research    link    False
# 1                            https://www.ox.ac.uk/research    link    False
# 2                            https://www.ox.ac.uk/research    link    False
# 3                            https://www.ox.ac.uk/research    link    False
# 4                            https://www.ox.ac.uk/research    link    False
# ...                                                    ...     ...      ...
# 1026308                                        about:blank     img     True
# 1026309                                        about:blank     img     True
# 1026310                                        about:blank     img     True
# 1026311  https://platform.twitter.com/widgets/tweet_but...    link     True
# 1026312  https://platform.twitter.com/widgets/tweet_but...       a     True
#
#          type crossorigin as_attr integrity
# 0        None        None    None      None
# 1        None        None    None      None
# 2        None        None    None      None
# 3        None        None    None      None
# 4        None        None    None      None
# ...       ...         ...     ...       ...
# 1026308  None        None    None      None
# 1026309  None        None    None      None
# 1026310  None        None    None      None
# 1026311  None        None    None      None
# 1026312  None        None    None      None
#
# [1026313 rows x 14 columns]

# %%
df_attr.tagName.value_counts()
# Out:
# a         644849
# img       166799
# script    112834
# link       84575
# iframe     16959
# area         297
# Name: tagName, dtype: int64

# %%
# Response Referrer Policy
df_req[(df_req.third_party_req == True) & (df_req.response_ref_policy != '')].drop_duplicates(subset=['init_url', 'response_ref_policy']).response_ref_policy.value_counts()
# Out:
# strict-origin-when-cross-origin                                     818
# unsafe-url                                                          203
# no-referrer-when-downgrade                                          191
# origin                                                              171
# same-origin                                                         114
# origin-when-cross-origin                                            111
# no-referrer                                                          94
# strict-origin-when-cross-origin\nstrict-origin-when-cross-origin     23
# origin-when-cross-origin, strict-origin-when-cross-origin            22
# same-origin\nstrict-origin-when-cross-origin                          7
# strict-origin                                                         6
# nosniff                                                               4
# Name: response_ref_policy, dtype: int64

# %%
df_req[df_req.response_ref_policy == 'strict-origin-when-cross-origin']
# Out:
#         site_domain                                        request_url  \
# 92         ox.ac.uk  https://cc.cdn.civiccomputing.com/9/cookieCont...
# 112        ox.ac.uk  https://apikeys.civiccomputing.com/c/v?d=www.o...
# 792     mamastar.jp          https://code.piano.io/api/tinypass.min.js
# 2316    cookpad.com            https://news.cookpad.com/articles/53482
# 2535    life360.com             https://www.life360.com/driving-safety
# ...             ...                                                ...
# 493383    wired.com  https://shopify.privy.com/widget.js?shop=wired...
# 493404    wired.com  https://api.privy.com/businesses/AE895E13560FD...
# 493455    wired.com                https://events.privy.com/v2/collect
# 493472    wired.com  https://promotions.lpage.co/campaigns/3972448/...
# 493530    wired.com  https://events.privy.com/collect?campaign_id=3...
#
#         request_url_domain                      referrer request_type  \
# 92      civiccomputing.com         https://www.ox.ac.uk/       script
# 112     civiccomputing.com         https://www.ox.ac.uk/          xhr
# 792               piano.io  https://hokatsu.mamastar.jp/       script
# 2316           cookpad.com                                   document
# 2535           life360.com                                   document
# ...                    ...                           ...          ...
# 493383           privy.com       https://shop.wired.com/       script
# 493404           privy.com       https://shop.wired.com/          xhr
# 493455           privy.com       https://shop.wired.com/          xhr
# 493472            lpage.co       https://shop.wired.com/     document
# 493530           privy.com  https://promotions.lpage.co/        image
#
#                                     req_initiators  third_party_req  \
# 92                          {googletagmanager.com}             True
# 112     {civiccomputing.com, googletagmanager.com}             True
# 792                                     {piano.io}             True
# 2316                                            {}            False
# 2535                                            {}            False
# ...                                            ...              ...
# 493383                                 {wired.com}             True
# 493404                      {privy.com, wired.com}             True
# 493455                      {privy.com, wired.com}             True
# 493472                                 {privy.com}             True
# 493530                       {privy.com, lpage.co}             True
#
#                                                 post_data  \
# 92
# 112
# 792
# 2316
# 2535
# ...                                                   ...
# 493383
# 493404
# 493455  {"event":"new-session","properties":{"referrin...
# 493472
# 493530
#
#                                       final_url  \
# 92                https://www.ox.ac.uk/research
# 112               https://www.ox.ac.uk/research
# 792                https://hokatsu.mamastar.jp/
# 2316    https://news.cookpad.com/articles/53482
# 2535    https://www.life360.com/driving-safety/
# ...                                         ...
# 493383                  https://shop.wired.com/
# 493404                  https://shop.wired.com/
# 493455                  https://shop.wired.com/
# 493472                  https://shop.wired.com/
# 493530                  https://shop.wired.com/
#
#                                        init_url  status      size  \
# 92                https://www.ox.ac.uk/research   200.0   94887.0
# 112               https://www.ox.ac.uk/research   200.0     697.0
# 792                https://hokatsu.mamastar.jp/   200.0  108148.0
# 2316    https://news.cookpad.com/articles/53482   200.0   34944.0
# 2535     https://www.life360.com/driving-safety   301.0       NaN
# ...                                         ...     ...       ...
# 493383                  https://shop.wired.com/   200.0    1131.0
# 493404                  https://shop.wired.com/   200.0    6163.0
# 493455                  https://shop.wired.com/   200.0     422.0
# 493472                  https://shop.wired.com/   200.0    5395.0
# 493530                  https://shop.wired.com/   200.0       0.0
#
#                     response_ref_policy                   req_ref_policy
# 92      strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 112     strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 792     strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 2316    strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 2535    strict-origin-when-cross-origin  strict-origin-when-cross-origin
# ...                                 ...                              ...
# 493383  strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 493404  strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 493455  strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 493472  strict-origin-when-cross-origin  strict-origin-when-cross-origin
# 493530  strict-origin-when-cross-origin  strict-origin-when-cross-origin
#
# [10166 rows x 14 columns]

# %%
df_req[(df_req.response_ref_policy=="no-referrer") & (df_req.third_party_req == True) & (df_req.response_ref_policy != '')]
# Out:
#          site_domain                                        request_url  \
# 4614    thesun.co.uk  https://commercial-analytics-collector.news.co...
# 4623    thesun.co.uk  https://commercial-analytics-collector.news.co...
# 4649    thesun.co.uk  https://commercial-analytics-collector.news.co...
# 4662    thesun.co.uk  https://commercial-analytics-collector.news.co...
# 4663    thesun.co.uk  https://commercial-analytics-collector.news.co...
# ...              ...                                                ...
# 477843      avito.ru  https://kimberlite.io/rtb/sync/mts?u=d65f7b7b-...
# 482639  huffpost.com  https://sync.inmobi.com/TAM?redirect=https%3A%...
# 487183      tenki.jp  https://sync.inmobi.com/gob?google_push=AXcoOm...
# 487256      tenki.jp  https://sync.inmobi.com/gobRedirectFromId5?id=...
# 490477     hitomi.la  https://wnt-some-push.net/icn/PV1z1Pn6sZVZu6FX...
#
#        request_url_domain                                referrer  \
# 4614           news.co.uk               https://www.thesun.co.uk/
# 4623           news.co.uk               https://www.thesun.co.uk/
# 4649           news.co.uk               https://www.thesun.co.uk/
# 4662           news.co.uk               https://www.thesun.co.uk/
# 4663           news.co.uk               https://www.thesun.co.uk/
# ...                   ...                                     ...
# 477843      kimberlite.io
# 482639         inmobi.com
# 487183         inmobi.com  https://pagead2.googlesyndication.com/
# 487256         inmobi.com
# 490477  wnt-some-push.net
#
#        request_type                       req_initiators  third_party_req  \
# 4614           ping                       {thesun.co.uk}             True
# 4623           ping  {amazon-adsystem.com, thesun.co.uk}             True
# 4649           ping      {doubleclick.net, thesun.co.uk}             True
# 4662           ping      {doubleclick.net, thesun.co.uk}             True
# 4663           ping      {doubleclick.net, thesun.co.uk}             True
# ...             ...                                  ...              ...
# 477843        image             {buzzoola.com, avito.ru}             True
# 482639     document                {amazon-adsystem.com}             True
# 487183        image              {googlesyndication.com}             True
# 487256        image              {googlesyndication.com}             True
# 490477        image                                   {}             True
#
#                                                 post_data  \
# 4614    {"prebid":[{"wrapper":"prebid","ad_unit_code":...
# 4623    {"amazon":[{"wrapper":"amazon","auction_id":"7...
# 4649    {"slotRender":{"wrapper":"slotRender","name":"...
# 4662    {"slotRender":{"wrapper":"slotRender","prebid_...
# 4663    {"slotRender":{"wrapper":"slotRender","prebid_...
# ...                                                   ...
# 477843
# 482639
# 487183
# 487256
# 490477
#
#                                                 final_url  \
# 4614                   https://www.thesun.co.uk/shopping/
# 4623                   https://www.thesun.co.uk/shopping/
# 4649                   https://www.thesun.co.uk/shopping/
# 4662                   https://www.thesun.co.uk/shopping/
# 4663                   https://www.thesun.co.uk/shopping/
# ...                                                   ...
# 477843                 https://www.avito.ru/all/zhivotnye
# 482639                   https://www.huffpost.com/voices/
# 487183     https://earthquake.tenki.jp/bousai/earthquake/
# 487256     https://earthquake.tenki.jp/bousai/earthquake/
# 490477  https://hitomi.la/imageset/%e5%8d%87%e5%a4%a9-...
#
#                                                  init_url  status  size  \
# 4614                    https://www.thesun.co.uk/shopping   202.0   0.0
# 4623                    https://www.thesun.co.uk/shopping   202.0   0.0
# 4649                    https://www.thesun.co.uk/shopping   202.0   0.0
# 4662                    https://www.thesun.co.uk/shopping   202.0   0.0
# 4663                    https://www.thesun.co.uk/shopping   202.0   0.0
# ...                                                   ...     ...   ...
# 477843                 https://www.avito.ru/all/zhivotnye   307.0   NaN
# 482639                    https://www.huffpost.com/voices   302.0   NaN
# 487183                 https://tenki.jp/bousai/earthquake   302.0   NaN
# 487256                 https://tenki.jp/bousai/earthquake   302.0   NaN
# 490477  https://hitomi.la/imageset/%e5%8d%87%e5%a4%a9-...   307.0   NaN
#
#        response_ref_policy                   req_ref_policy
# 4614           no-referrer  strict-origin-when-cross-origin
# 4623           no-referrer  strict-origin-when-cross-origin
# 4649           no-referrer  strict-origin-when-cross-origin
# 4662           no-referrer  strict-origin-when-cross-origin
# 4663           no-referrer  strict-origin-when-cross-origin
# ...                    ...                              ...
# 477843         no-referrer                      no-referrer
# 482639         no-referrer                      no-referrer
# 487183         no-referrer  strict-origin-when-cross-origin
# 487256         no-referrer                      no-referrer
# 490477         no-referrer  strict-origin-when-cross-origin
#
# [242 rows x 14 columns]

# %%
req_ref_policy = df_req[(df_req.third_party_req == True) & (df_req.req_ref_policy != '')].drop_duplicates(subset=['init_url', 'req_ref_policy'])
req_ref_policy.req_ref_policy.value_counts()
# Out:
# strict-origin-when-cross-origin    2905
# no-referrer-when-downgrade          586
# unsafe-url                          370
# origin                              354
# no-referrer                         285
# origin-when-cross-origin            168
# same-origin                          67
# strict-origin                        18
# Name: req_ref_policy, dtype: int64

# %%
req_ref_policy[req_ref_policy.req_ref_policy == 'no-referrer']
# Out:
#              site_domain                                        request_url  \
# 1475       amazon.com.mx  https://ib.adnxs.com/setuid/a9?entity=188&code...
# 3075          change.org  https://play.google.com/log?format=json&hasfas...
# 4686        thesun.co.uk  https://csync.loopme.me/?pubid=11405&redirect=...
# 6073    launchdarkly.com  https://play.google.com/log?format=json&hasfas...
# 6567         nytimes.com  https://cs.media.net/cksync?cs=31&type=tam&red...
# ...                  ...                                                ...
# 488252     acesso.gov.br  https://cdn.dsgovserprodesign.estaleiro.serpro...
# 489301       foxnews.com  https://sync.1rx.io/usersync2/rmpssp?sub=amazo...
# 490351         hitomi.la  https://accounts.google.com/ServiceLogin?passi...
# 491518       zemanta.com  https://www.googletagmanager.com/gtm.js?id=GTM...
# 491926      mashable.com  https://sync.1rx.io/usersync2/rmpssp?sub=amazo...
#
#           request_url_domain referrer request_type  \
# 1475               adnxs.com                 image
# 3075              google.com             preflight
# 4686               loopme.me                 image
# 6073              google.com                   xhr
# 6567               media.net                 image
# ...                      ...      ...          ...
# 488252         serpro.gov.br            stylesheet
# 489301                1rx.io                 image
# 490351            google.com                 image
# 491518  googletagmanager.com                script
# 491926                1rx.io                 image
#
#                                            req_initiators  third_party_req  \
# 1475                                {amazon-adsystem.com}             True
# 3075                                         {google.com}             True
# 4686                                {amazon-adsystem.com}             True
# 6073    {google.com, /_/gsi/_/js/k=gsi.gsi.en_US.l0gW8...             True
# 6567                                {amazon-adsystem.com}             True
# ...                                                   ...              ...
# 488252                                    {acesso.gov.br}             True
# 489301                              {amazon-adsystem.com}             True
# 490351                       {wpadmngr.com, wpushsdk.com}             True
# 491518                                      {zemanta.com}             True
# 491926                              {amazon-adsystem.com}             True
#
#                                                 post_data  \
# 1475
# 3075
# 4686
# 6073    [[1,null,null,null,null,null,null,null,null,nu...
# 6567
# ...                                                   ...
# 488252
# 489301
# 490351
# 491518
# 491926
#
#                                                 final_url  \
# 1475    https://www.amazon.com.mx/s?k=carteras&i=fashi...
# 3075    https://www.change.org/s/member?source_locatio...
# 4686                   https://www.thesun.co.uk/shopping/
# 6073      https://app.launchdarkly.com/login?redirect=%2F
# 6567           https://www.nytimes.com/spotlight/podcasts
# ...                                                   ...
# 488252        https://cadastro.acesso.gov.br/termo-de-uso
# 489301                      https://www.foxnews.com/video
# 490351  https://hitomi.la/imageset/%e5%8d%87%e5%a4%a9-...
# 491518                   https://www.zemanta.com/privacy/
# 491926                 https://mashable.com/entertainment
#
#                                                  init_url  status     size  \
# 1475    https://www.amazon.com.mx/s/?_encoding=utf8&k=...   307.0      NaN
# 3075    https://www.change.org/member?source_location=...   200.0      0.0
# 4686                    https://www.thesun.co.uk/shopping   307.0      NaN
# 6073                        https://app.launchdarkly.com/   200.0    155.0
# 6567           https://www.nytimes.com/spotlight/podcasts   302.0      NaN
# ...                                                   ...     ...      ...
# 488252        https://cadastro.acesso.gov.br/termo-de-uso     NaN      NaN
# 489301                      https://www.foxnews.com/video   302.0      NaN
# 490351  https://hitomi.la/imageset/%e5%8d%87%e5%a4%a9-...   302.0      NaN
# 491518                    https://www.zemanta.com/privacy   200.0  92044.0
# 491926                 https://mashable.com/entertainment   302.0      NaN
#
#        response_ref_policy req_ref_policy
# 1475                          no-referrer
# 3075                          no-referrer
# 4686                          no-referrer
# 6073                          no-referrer
# 6567                          no-referrer
# ...                    ...            ...
# 488252                        no-referrer
# 489301                        no-referrer
# 490351                        no-referrer
# 491518                        no-referrer
# 491926                        no-referrer
#
# [285 rows x 14 columns]

# %%
# Link Referrer Policy
df_attr.drop_duplicates(subset=['init_url','referrerpolicy']).referrerpolicy.value_counts()
# Out:
# no-referrer-when-downgrade         126
# unsafe-url                         100
# no-referrer                         46
# origin                              40
# strict-origin-when-cross-origin     36
# strict-origin                        8
# origin-when-cross-origin             5
# Name: referrerpolicy, dtype: int64

# %%
df_attr[df_attr["referrerpolicy"] == "no-referrer-when-downgrade"]
# Out:
#                                                   init_url  href  \
# 13423        https://www.rakuten-sec.co.jp/web/foreign/etf  None
# 13431        https://www.rakuten-sec.co.jp/web/foreign/etf  None
# 25421    https://gall.dcinside.com/board/view/?id=dcbes...  None
# 36532    https://www.epsilon.com/us/about-us/pressroom/...  None
# 38194                    https://www.appier.com/?hslang=en  None
# ...                                                    ...   ...
# 985478                        https://www.olx.ua/uk/rabota  None
# 1010550  https://www.epsilon.com/us/client-success/case...  None
# 1012817                 https://tenki.jp/bousai/earthquake  None
# 1012820                 https://tenki.jp/bousai/earthquake  None
# 1016396                      https://www.foxnews.com/video  None
#
#                                                        src   rel  \
# 13423    https://asia.creativecdn.com/tags?type=iframe&...  None
# 13431    https://b6.im-apps.net/3929/rt/11980/?vid=01HH...  None
# 25421    https://ad.xc.netinsight.co.kr/xc/j/ccDkYbfd/x...  None
# 36532    https://app.hubspot.com/content-tools-menu/api...  None
# 38194    https://app.hubspot.com/content-tools-menu/api...  None
# ...                                                    ...   ...
# 985478   https://creativecdn.com/tags?type=iframe&id=pr...  None
# 1010550  https://app.hubspot.com/content-tools-menu/api...  None
# 1012817  https://www.googletagmanager.com/gtm.js?id=GTM...  None
# 1012820  https://sync.im-apps.net/imid/segment?callback...  None
# 1016396  //tl.foxnews.com/jssdk/34c3ab59aa2e43688b7e002...  None
#
#                      referrerpolicy title text  \
# 13423    no-referrer-when-downgrade  None
# 13431    no-referrer-when-downgrade  None
# 25421    no-referrer-when-downgrade  None
# 36532    no-referrer-when-downgrade  None
# 38194    no-referrer-when-downgrade  None
# ...                             ...   ...  ...
# 985478   no-referrer-when-downgrade  None
# 1010550  no-referrer-when-downgrade  None
# 1012817  no-referrer-when-downgrade  None
# 1012820  no-referrer-when-downgrade  None
# 1016396  no-referrer-when-downgrade  None
#
#                                                   frameUrl tagName  isFrame  \
# 13423       https://www.rakuten-sec.co.jp/web/foreign/etf/  iframe    False
# 13431       https://www.rakuten-sec.co.jp/web/foreign/etf/     img    False
# 25421    https://gall.dcinside.com/board/view/?id=dcbes...  script    False
# 36532    https://www.epsilon.com/us/about-us/pressroom/...  script    False
# 38194                 https://www.appier.com/en/?hslang=en  script    False
# ...                                                    ...     ...      ...
# 985478                       https://www.olx.ua/uk/rabota/  iframe    False
# 1010550  https://www.epsilon.com/us/client-success/case...  script    False
# 1012817     https://earthquake.tenki.jp/bousai/earthquake/  script    False
# 1012820     https://earthquake.tenki.jp/bousai/earthquake/  script    False
# 1016396                      https://www.foxnews.com/video  script    False
#
#                     type crossorigin as_attr integrity
# 13423               None        None    None      None
# 13431               None        None    None      None
# 25421    text/javascript        None    None      None
# 36532    text/javascript        None    None      None
# 38194    text/javascript        None    None      None
# ...                  ...         ...     ...       ...
# 985478              None        None    None      None
# 1010550  text/javascript        None    None      None
# 1012817  text/javascript        None    None      None
# 1012820  text/javascript        None    None      None
# 1016396             None        None    None      None
#
# [267 rows x 14 columns]

# %%
# Get rel link attribute
df_attr[(df_attr.rel == "noreferrer" )].drop_duplicates(subset=['init_url', 'rel']).rel.value_counts()
# Out:
# noreferrer    231
# Name: rel, dtype: int64

# %%
df_attr.drop_duplicates(subset=['init_url', 'isFrame']).isFrame.value_counts()
# Out:
# False    3132
# True     1755
# Name: isFrame, dtype: int64

# %%
df_attr.tagName.value_counts()
# Out:
# a         644849
# img       166799
# script    112834
# link       84575
# iframe     16959
# area         297
# Name: tagName, dtype: int64

# %%
df_attr.as_attr.value_counts()
# Out:
# script        8534
# font          2949
# style         2505
# image          601
# fetch          413
# undefined       36
# div             31
# fonts           25
# document        11
#                  9
# stylesheet       2
# a                2
# worker           2
# Name: as_attr, dtype: int64

# %%
df_attr.crossorigin.value_counts()
# Out:
# anonymous          14668
#                     5385
# true                1168
# use-credentials      280
# crossorigin           69
# *                     35
# crossOrigin            4
# same-origin            2
# Name: crossorigin, dtype: int64

# %%
df_attr.integrity.value_counts()
# Out:
# sha384-JtvhFQlPQ6LL/+I5aABhkbXo/hmh5M6IvL9vK+ecFqveRPvf7P6cGzs1DEyU5A3c                            224
# sha512-euoFGowhlaLqXsPWQ48qSkBSCFs3DPRyiwVu3FjR96cMPx+Fr+gpWRhIafcHwqwCqWS42RZhIudOvEI+Ckf6MA==    173
# sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=                                                 46
# sha384-oyOrIfu0dTVXgJDnDwTkpAOw6OQnC6D4wN0pmPLvl75dXBhYohgWHMyv3Y05PPLU                             37
# sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=                                                 31
#                                                                                                   ...
# sha384-IYkqoIXkdl+WJcoBj1LZTExMvaRVpoG/9c7oVDUMyNxFPDbKlE7/+pG0dgVttvWl                              1
# sha384-LyHGXhTbjDIkuP7AbL+VErN4jX9XAQsTJV2XTVXu9zm/7Z8MedCR3ElBpOd+0v7J                              1
# sha384-gxy0R8gznzoSM0vSba4c6civwB+qWm1KZZvMX4T/rq5y06I07ucXW9wWtuTz3nv6                              1
# sha384-IOd+jF7FUSVClxjkEmZL3TnW8URsklhPBZA8pAbjUEGI9FrfcjNeL2JxCTNDNMrU                              1
# sha256-Ls0pXSlb7AYs7evhd+VLnWsZ/AqEHcXBeMZUycz/CcA=                                                  1
# Name: integrity, Length: 430, dtype: int64

# %%
df_meta
# Out:
#                                               init_url  \
# 0    https://ameblo.jp/borderfreecosmetics/entry-12...
# 1    https://www.amazon.com.mx/s/?_encoding=utf8&k=...
# 2         https://www.google.ca/preferences?hl=en&fg=1
# 3    https://www.change.org/member?source_location=...
# 4    https://www.change.org/member?source_location=...
# ..                                                 ...
# 827         https://www.google.com.mx/imghp?hl=en&ogbl
# 828         https://www.google.com.mx/imghp?hl=en&ogbl
# 829  https://www.ebay.com/e/_electronics/certified-...
# 830                 https://mashable.com/entertainment
# 831   https://www.mbga.jp/_game_intro?game_id=12016007
#
#              referrer_policy  \
# 0                     origin
# 1                no-referrer
# 2                     origin
# 3                no-referrer
# 4                     origin
# ..                       ...
# 827                   origin
# 828                   origin
# 829               unsafe-url
# 830              no-referrer
# 831  origin-when-crossorigin
#
#                                               frameUrl  inFrame  \
# 0    https://ameblo.jp/borderfreecosmetics/entry-12...    False
# 1    https://s.amazon-adsystem.com/v3/pr?exlist=n-x...     True
# 2    https://ogs.google.ca/widget/callout?prid=1903...     True
# 3    https://accounts.google.com/gsi/button?size=la...     True
# 4    https://pay.google.com/gp/p/ui/payframe?origin...     True
# ..                                                 ...      ...
# 827         https://www.google.com.mx/imghp?hl=en&ogbl    False
# 828  https://ogs.google.com.mx/widget/callout?prid=...     True
# 829  https://www.ebay.com/e/_electronics/certified-...    False
# 830  https://aax-eu.amazon-adsystem.com/s/v3/pr?exl...     True
# 831  https://www.facebook.com/v10.0/plugins/like.ph...     True
#
#                                                pageURL
# 0    https://ameblo.jp/borderfreecosmetics/entry-12...
# 1    https://www.amazon.com.mx/s?k=carteras&i=fashi...
# 2         https://www.google.ca/preferences?hl=en&fg=1
# 3    https://www.change.org/s/member?source_locatio...
# 4    https://www.change.org/s/member?source_locatio...
# ..                                                 ...
# 827         https://www.google.com.mx/imghp?hl=en&ogbl
# 828         https://www.google.com.mx/imghp?hl=en&ogbl
# 829  https://www.ebay.com/e/_electronics/certified-...
# 830                 https://mashable.com/entertainment
# 831  https://www.andapp.jp/apps/12016007?from=www_m...
#
# [832 rows x 5 columns]

# %%
df_meta.drop_duplicates(subset=['init_url', 'referrer_policy']).referrer_policy.value_counts()
# Out:
# no-referrer                        211
# no-referrer-when-downgrade         140
# origin                             126
# unsafe-url                          67
# origin-when-crossorigin             56
# origin-when-cross-origin            48
# always                              32
# strict-origin-when-cross-origin     17
# same-origin                          6
# never                                1
# strict-origin                        1
# Name: referrer_policy, dtype: int64
