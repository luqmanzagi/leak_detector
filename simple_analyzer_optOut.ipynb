# %% [markdown]
# # Simple Analyzer for Leak Detector
# ## OptIn Version

# %%
import pandas as pd
import re
import os
from urllib.parse import urlparse

# %%
def print_leak_to_csv(df):
    """
    Check dataframe if there are colomn with name: url_leaks, referer_leaks,
    and post_leaks. If there are, then print the dataframe to csv file.

    :param df: dataframe

    :return: csv file with specific name
    """
  


    # if 'url_leaks' in df and 'referer_leaks' in df and 'post_leaks' in df:
    #     return df.to_csv(extract_date + '_print_raw_leaks.csv')
    if 'url_leaks' in df:
        return df.to_csv("data_seg/"+ extract_date + '_' + extract_type +'_print_url_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optin_url_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optout_url_leaks.csv')
    elif 'referer_leaks' in df:
        return df.to_csv("data_seg/"+ extract_date + '_' + extract_type + '_print_referer_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optin_referer_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optout_referer_leaks.csv')
    elif 'post_leaks' in df:
        return df.to_csv("data_seg/"+ extract_date + '_' + extract_type + '_print_post_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_optin_post_leaks.csv')
        # return df.to_csv("data_seg/"+ extract_date + '_print_opt_out_post_leaks.csv')

# %%
def extract_leak(data, leak):
    """
    extract data with when 'leak' row is not empty

    :param dataframe data: input dataframe
    :param str leak: column name

    :return: dataframe with non-empty 'leak' column
    """
 
    return data[(data['leaks'].str.contains(leak, na=False))]

# %%
def drop_non_leak(data, leak):
    """
    drop data that not related to the leak

    :param data: dataframe
    :param leak: column name

    :return: dataframe with non-empty 'leak' column
    """
    data_seed = extract_leak(data, leak)
    if leak == 'url_leaks':
        return data_seed.drop(['post_leaks', 'ref_data', 'referer_leaks', 'post_data'], axis=1)
    elif leak == 'referer_leaks':
        return data_seed.drop(['url_leaks', 'post_leaks', 'post_data'], axis=1)
    elif leak == 'post_leaks':
        return data_seed.drop(['url_leaks', 'referer_leaks', 'ref_data'], axis=1)

# %%
def check_urlparse(row):
    """check if the referer_leaks contain the netloc, path, params, query, and fragment from the final_url

    :param row: row of dataframe

    :return: dictionary of the referer_leaks
    """
    parsed_url = urlparse(row['final_url'])
    parsed_url_list = [parsed_url.netloc, parsed_url.path, parsed_url.params, parsed_url.query, parsed_url.fragment]
    # print(parsed_url_list)
    if 'referer_leaks' in row:    
        desired_list = row['referer_leaks'].split("'") 
    elif 'url_leaks' in row:
        desired_list = row['url_leaks'].split("'")
    elif 'post_leaks' in row:
        desired_list = row['post_leaks'].split("'")
    # print (desired_list)
    undesired_list = ['[', 
                    ']', 
                    ',', 
                    'None', 
                    '', 
                    '[(',
                    ')]', 
                    ',)]',
                    '), (',
                    ', ']
    result = {}
    netloc, path, query ,params, fragments = '', '', '', '', ''
    for item in desired_list:
        if item not in undesired_list:
            if item in parsed_url_list:
                if item == parsed_url.netloc:
                    netloc = parsed_url.netloc
                if item == parsed_url.path:
                    path = parsed_url.path
                if item == parsed_url.query:
                    query = parsed_url.query
                # it should be not include in referer 
                if item == parsed_url.params:
                    params = parsed_url.params
                if item == parsed_url.fragment:
                    fragments = parsed_url.fragment

    return netloc, path, query, params, fragments

# %%
def check_violation(row):
    """
    Check if the referer_leaks violate the policy or not

    :param dataframe row: a dataframe row that contain "ref_pol_data" colomn as
    the referer policy and check if the referer_leaks violate the policy or not

    :return str: Send "Violation" if the referer_leaks violate the policy,
    send "Safe" if the referer_leaks is safe, send "Warning" if the referer_leaks
    """
    ref_pol = row['ref_pol_data']
    if ((row ['params']) or (row ['fragments'])):
        return "Warning"
    match ref_pol:
        case 'no-referrer':
            if ((row ['netloc']) or (row ['path']) or (row ['query'])):
                return "Violation"
            else:
                return "Safe"
        case 'same-origin':
            if ((row ['netloc']) or (row ['path']) or (row ['query'])):
                return "Violation"
            else:  
                return "Safe"
        case 'no-referrer-when-downgrade':
            return "Safe"
        case 'unsafe-url':
            return "Safe"
        case 'origin':
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:
                return "Safe"
        case 'origin-when-cross-origin':
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:   
                return "Safe"
        case 'strict-origin' :
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:   
                return "Safe"
        case 'strict-origin-when-cross-origin':
            if (row ['path']) or (row ['query']):
                return "Violation"
            else:
                return "Safe"
        case _:
            return "Blank"

# %% [markdown]
# ## Convert CSV to Dataframe

# %%
csv_file = './data_raw/2023-12-08_optIn_leaks_raw.csv'
# csv_file = './data_raw/2023-11-29_optIn_leaks_raw.csv'
# csv_file = './data_raw/test.csv'
extract_type = csv_file.split("_")[2]

extract_date = re.findall(r'20(.*?)_', csv_file)
extract_date = ''.join(extract_date)  # Convert the list to a string

os.makedirs("data_seg", exist_ok=True)

extracted_df = pd.read_csv(csv_file)
extracted_df
# Out:
#                                                 init_url  \
# 0                          https://www.ox.ac.uk/research
# 1                          https://www.ox.ac.uk/research
# 2                          https://www.ox.ac.uk/research
# 3                          https://www.ox.ac.uk/research
# 4                          https://www.ox.ac.uk/research
# ...                                                  ...
# 110883  https://www.mbga.jp/_game_intro?game_id=12016007
# 110884  https://www.mbga.jp/_game_intro?game_id=12016007
# 110885  https://www.mbga.jp/_game_intro?game_id=12016007
# 110886  https://www.mbga.jp/_game_intro?game_id=12016007
# 110887  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 110883  https://www.andapp.jp/apps/12016007?from=www_m...
# 110884  https://www.andapp.jp/apps/12016007?from=www_m...
# 110885  https://www.andapp.jp/apps/12016007?from=www_m...
# 110886  https://www.andapp.jp/apps/12016007?from=www_m...
# 110887  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 0       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...        GET
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 3       https://apikeys.civiccomputing.com/c/v?d=www.o...        GET
# 4       https://www.linkedin.com/px/li_sync?redirect=h...        GET
# ...                                                   ...        ...
# 110883  https://syndication.twitter.com/i/jot/embeds?l...        GET
# 110884  https://www.google.com/pagead/1p-user-list/878...        GET
# 110885  https://www.youtube.com/youtubei/v1/log_event?...       POST
# 110886  https://aw.dw.impact-ad.jp/ut/rep?u=2714&v=2&r...        GET
# 110887                https://id5-sync.com/g/v2/1270.json       POST
#
#                            ref_pol_data  \
# 0       strict-origin-when-cross-origin
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 3       strict-origin-when-cross-origin
# 4       strict-origin-when-cross-origin
# ...                                 ...
# 110883  strict-origin-when-cross-origin
# 110884  strict-origin-when-cross-origin
# 110885  strict-origin-when-cross-origin
# 110886  strict-origin-when-cross-origin
# 110887  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 0                                   https://www.ox.ac.uk/
# 1                                   https://www.ox.ac.uk/
# 2                                   https://www.ox.ac.uk/
# 3                                   https://www.ox.ac.uk/
# 4                                   https://www.ox.ac.uk/
# ...                                                   ...
# 110883                             https://www.andapp.jp/
# 110884                             https://www.andapp.jp/
# 110885  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110886               https://6015542.fls.doubleclick.net/
# 110887               https://6015542.fls.doubleclick.net/
#
#                                                 post_data  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 110883                                                NaN
# 110884                                                NaN
# 110885  {"context":{"client":{"hl":"en","gl":"US","cli...
# 110886                                                NaN
# 110887  {"partner":1270,"v":"1.0.36","o":"api","tml":"...
#
#                                                 url_leaks  \
# 0       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 1       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...
# 2       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...
# 3       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 4       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 110883  [('urlencode', 'www.andapp.jp'), ('urlencode',...
# 110884  [('urlencode', 'www.andapp.jp'), ('urlencode',...
# 110885                                                 []
# 110886  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110887                                                 []
#
#                   post_leaks  \
# 0                         []
# 1                         []
# 2                         []
# 3                         []
# 4                         []
# ...                      ...
# 110883                    []
# 110884                    []
# 110885  [('www.andapp.jp',)]
# 110886                    []
# 110887  [('www.andapp.jp',)]
#
#                                             referer_leaks  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 110883                                                 []
# 110884                                                 []
# 110885  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110886                                                 []
# 110887                                                 []
#
#                              leaks
# 0                        url_leaks
# 1                        url_leaks
# 2                        url_leaks
# 3                        url_leaks
# 4                        url_leaks
# ...                            ...
# 110883                   url_leaks
# 110884                   url_leaks
# 110885  post_leaks - referer_leaks
# 110886                   url_leaks
# 110887                  post_leaks
#
# [110888 rows x 11 columns]

# %% [markdown]
# ## Leaks on Referer
#
# We still need to compare with the referrer policy to make it accurate

# %%
# create a new dataframe with non-empty 'referer_leaks' column
referer_leaks_df = drop_non_leak(extracted_df, 'referer_leaks')
referer_leaks_df
# Out:
#                                                 init_url  \
# 9                          https://www.ox.ac.uk/research
# 10                         https://www.ox.ac.uk/research
# 11                         https://www.ox.ac.uk/research
# 17                         https://www.ox.ac.uk/research
# 18                         https://www.ox.ac.uk/research
# ...                                                  ...
# 110873  https://www.mbga.jp/_game_intro?game_id=12016007
# 110874  https://www.mbga.jp/_game_intro?game_id=12016007
# 110876  https://www.mbga.jp/_game_intro?game_id=12016007
# 110878  https://www.mbga.jp/_game_intro?game_id=12016007
# 110885  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 9                           https://www.ox.ac.uk/research
# 10                          https://www.ox.ac.uk/research
# 11                          https://www.ox.ac.uk/research
# 17                          https://www.ox.ac.uk/research
# 18                          https://www.ox.ac.uk/research
# ...                                                   ...
# 110873  https://www.andapp.jp/apps/12016007?from=www_m...
# 110874  https://www.andapp.jp/apps/12016007?from=www_m...
# 110876  https://www.andapp.jp/apps/12016007?from=www_m...
# 110878  https://www.andapp.jp/apps/12016007?from=www_m...
# 110885  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 9       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 10      https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 11      https://www.youtube.com/s/player/dee96cfa/play...        GET
# 17      https://www.youtube.com/youtubei/v1/player?key...       POST
# 18      https://www.youtube.com/s/player/dee96cfa/play...        GET
# ...                                                   ...        ...
# 110873  https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 110874  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 110876  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 110878        https://www.youtube.com/generate_204?FeixEA        GET
# 110885  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 9       strict-origin-when-cross-origin
# 10      strict-origin-when-cross-origin
# 11      strict-origin-when-cross-origin
# 17      strict-origin-when-cross-origin
# 18      strict-origin-when-cross-origin
# ...                                 ...
# 110873  strict-origin-when-cross-origin
# 110874  strict-origin-when-cross-origin
# 110876  strict-origin-when-cross-origin
# 110878  strict-origin-when-cross-origin
# 110885  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 9       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 10      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 11      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 17      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 18      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# ...                                                   ...
# 110873  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110874  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110876  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110878  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110885  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 9       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 10      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 11      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 17      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 18      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 110873  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110874  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110876  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110878  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110885  [('urlencode', 'www.andapp.jp'), ('www.andapp....
#
#                              leaks
# 9                    referer_leaks
# 10                   referer_leaks
# 11                   referer_leaks
# 17      post_leaks - referer_leaks
# 18                   referer_leaks
# ...                            ...
# 110873               referer_leaks
# 110874               referer_leaks
# 110876               referer_leaks
# 110878               referer_leaks
# 110885  post_leaks - referer_leaks
#
# [58981 rows x 8 columns]

# %%
# show the dataframe with more than one leaks in "leaks" colomn
referer_leaks_df[referer_leaks_df['leaks'] != "referer_leaks"]
# Out:
#                                                  init_url  \
# 17                          https://www.ox.ac.uk/research
# 28                          https://www.ox.ac.uk/research
# 31                          https://www.ox.ac.uk/research
# 32                          https://www.ox.ac.uk/research
# 33                          https://www.ox.ac.uk/research
# ...                                                   ...
# 110556                 https://mashable.com/entertainment
# 110562                 https://mashable.com/entertainment
# 110684  https://www.mcafee.com/en-us/consumer-corporat...
# 110742                          https://actu.fr/politique
# 110885   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 17                          https://www.ox.ac.uk/research
# 28                          https://www.ox.ac.uk/research
# 31                          https://www.ox.ac.uk/research
# 32                          https://www.ox.ac.uk/research
# 33                          https://www.ox.ac.uk/research
# ...                                                   ...
# 110556                 https://mashable.com/entertainment
# 110562                 https://mashable.com/entertainment
# 110684  https://www.mcafee.com/en-us/consumer-corporat...
# 110742                          https://actu.fr/politique
# 110885  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 17      https://www.youtube.com/youtubei/v1/player?key...       POST
# 28      https://www.youtube.com/api/stats/qoe?fmt=247&...       POST
# 31      https://www.youtube.com/youtubei/v1/next?key=A...       POST
# 32      https://www.youtube.com/youtubei/v1/log_event?...       POST
# 33      https://www.youtube.com/youtubei/v1/player?key...       POST
# ...                                                   ...        ...
# 110556  https://ping.chartbeat.net/ping?h=mashable.com...        GET
# 110562  https://ping.chartbeat.net/ping?h=mashable.com...        GET
# 110684  https://adobedc.demdex.net/ee/v1/interact?conf...       POST
# 110742  https://gum.criteo.com/sid/json?origin=publish...        GET
# 110885  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 17      strict-origin-when-cross-origin
# 28      strict-origin-when-cross-origin
# 31      strict-origin-when-cross-origin
# 32      strict-origin-when-cross-origin
# 33      strict-origin-when-cross-origin
# ...                                 ...
# 110556       no-referrer-when-downgrade
# 110562       no-referrer-when-downgrade
# 110684       no-referrer-when-downgrade
# 110742  strict-origin-when-cross-origin
# 110885  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 17      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 28      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 31      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 32      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 33      https://www.youtube.com/embed/ogkc1FmfiuI?wmod...
# ...                                                   ...
# 110556                 https://mashable.com/entertainment
# 110562                 https://mashable.com/entertainment
# 110684  https://www.mcafee.com/en-us/consumer-corporat...
# 110742  https://gum.criteo.com/syncframe?origin=publis...
# 110885  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 17      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 28      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 31      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 32      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 33      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 110556                              [('/entertainment',)]
# 110562                              [('/entertainment',)]
# 110684    [('/en-us/consumer-corporate/investors.html',)]
# 110742           [('actu.fr',), ('urlencode', 'actu.fr')]
# 110885  [('urlencode', 'www.andapp.jp'), ('www.andapp....
#
#                              leaks
# 17      post_leaks - referer_leaks
# 28       url_leaks - referer_leaks
# 31      post_leaks - referer_leaks
# 32      post_leaks - referer_leaks
# 33      post_leaks - referer_leaks
# ...                            ...
# 110556   url_leaks - referer_leaks
# 110562   url_leaks - referer_leaks
# 110684  post_leaks - referer_leaks
# 110742   url_leaks - referer_leaks
# 110885  post_leaks - referer_leaks
#
# [15470 rows x 8 columns]

# %%
#expand the dataframe with the result from check_urlparse function
referer_leaks_df[['netloc', 'path', 'query', 'params', 'fragments']] = referer_leaks_df.apply(check_urlparse, axis=1, result_type='expand')
referer_leaks_df
# Out:
#                                                 init_url  \
# 9                          https://www.ox.ac.uk/research
# 10                         https://www.ox.ac.uk/research
# 11                         https://www.ox.ac.uk/research
# 17                         https://www.ox.ac.uk/research
# 18                         https://www.ox.ac.uk/research
# ...                                                  ...
# 110873  https://www.mbga.jp/_game_intro?game_id=12016007
# 110874  https://www.mbga.jp/_game_intro?game_id=12016007
# 110876  https://www.mbga.jp/_game_intro?game_id=12016007
# 110878  https://www.mbga.jp/_game_intro?game_id=12016007
# 110885  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 9                           https://www.ox.ac.uk/research
# 10                          https://www.ox.ac.uk/research
# 11                          https://www.ox.ac.uk/research
# 17                          https://www.ox.ac.uk/research
# 18                          https://www.ox.ac.uk/research
# ...                                                   ...
# 110873  https://www.andapp.jp/apps/12016007?from=www_m...
# 110874  https://www.andapp.jp/apps/12016007?from=www_m...
# 110876  https://www.andapp.jp/apps/12016007?from=www_m...
# 110878  https://www.andapp.jp/apps/12016007?from=www_m...
# 110885  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 9       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 10      https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 11      https://www.youtube.com/s/player/dee96cfa/play...        GET
# 17      https://www.youtube.com/youtubei/v1/player?key...       POST
# 18      https://www.youtube.com/s/player/dee96cfa/play...        GET
# ...                                                   ...        ...
# 110873  https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 110874  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 110876  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 110878        https://www.youtube.com/generate_204?FeixEA        GET
# 110885  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 9       strict-origin-when-cross-origin
# 10      strict-origin-when-cross-origin
# 11      strict-origin-when-cross-origin
# 17      strict-origin-when-cross-origin
# 18      strict-origin-when-cross-origin
# ...                                 ...
# 110873  strict-origin-when-cross-origin
# 110874  strict-origin-when-cross-origin
# 110876  strict-origin-when-cross-origin
# 110878  strict-origin-when-cross-origin
# 110885  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 9       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 10      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 11      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 17      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 18      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# ...                                                   ...
# 110873  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110874  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110876  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110878  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110885  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 9       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 10      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 11      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 17      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 18      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 110873  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110874  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110876  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110878  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110885  [('urlencode', 'www.andapp.jp'), ('www.andapp....
#
#                              leaks         netloc path query params fragments
# 9                    referer_leaks   www.ox.ac.uk
# 10                   referer_leaks   www.ox.ac.uk
# 11                   referer_leaks   www.ox.ac.uk
# 17      post_leaks - referer_leaks   www.ox.ac.uk
# 18                   referer_leaks   www.ox.ac.uk
# ...                            ...            ...  ...   ...    ...       ...
# 110873               referer_leaks  www.andapp.jp
# 110874               referer_leaks  www.andapp.jp
# 110876               referer_leaks  www.andapp.jp
# 110878               referer_leaks  www.andapp.jp
# 110885  post_leaks - referer_leaks  www.andapp.jp
#
# [58981 rows x 13 columns]

# %%
# create a new colomn with the result from check_violation function
referer_leaks_df['violation'] = referer_leaks_df.apply(check_violation, axis=1, result_type='expand')
referer_leaks_df
# Out:
#                                                 init_url  \
# 9                          https://www.ox.ac.uk/research
# 10                         https://www.ox.ac.uk/research
# 11                         https://www.ox.ac.uk/research
# 17                         https://www.ox.ac.uk/research
# 18                         https://www.ox.ac.uk/research
# ...                                                  ...
# 110873  https://www.mbga.jp/_game_intro?game_id=12016007
# 110874  https://www.mbga.jp/_game_intro?game_id=12016007
# 110876  https://www.mbga.jp/_game_intro?game_id=12016007
# 110878  https://www.mbga.jp/_game_intro?game_id=12016007
# 110885  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 9                           https://www.ox.ac.uk/research
# 10                          https://www.ox.ac.uk/research
# 11                          https://www.ox.ac.uk/research
# 17                          https://www.ox.ac.uk/research
# 18                          https://www.ox.ac.uk/research
# ...                                                   ...
# 110873  https://www.andapp.jp/apps/12016007?from=www_m...
# 110874  https://www.andapp.jp/apps/12016007?from=www_m...
# 110876  https://www.andapp.jp/apps/12016007?from=www_m...
# 110878  https://www.andapp.jp/apps/12016007?from=www_m...
# 110885  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 9       https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 10      https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 11      https://www.youtube.com/s/player/dee96cfa/play...        GET
# 17      https://www.youtube.com/youtubei/v1/player?key...       POST
# 18      https://www.youtube.com/s/player/dee96cfa/play...        GET
# ...                                                   ...        ...
# 110873  https://www.youtube.com/s/player/dee96cfa/www-...        GET
# 110874  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 110876  https://www.youtube.com/s/player/dee96cfa/play...        GET
# 110878        https://www.youtube.com/generate_204?FeixEA        GET
# 110885  https://www.youtube.com/youtubei/v1/log_event?...       POST
#
#                            ref_pol_data  \
# 9       strict-origin-when-cross-origin
# 10      strict-origin-when-cross-origin
# 11      strict-origin-when-cross-origin
# 17      strict-origin-when-cross-origin
# 18      strict-origin-when-cross-origin
# ...                                 ...
# 110873  strict-origin-when-cross-origin
# 110874  strict-origin-when-cross-origin
# 110876  strict-origin-when-cross-origin
# 110878  strict-origin-when-cross-origin
# 110885  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 9       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 10      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 11      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 17      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# 18      https://www.youtube.com/embed/VQwYwDqHA7I?wmod...
# ...                                                   ...
# 110873  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110874  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110876  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110878  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
# 110885  https://www.youtube.com/embed/19s0G5lLc0g?rel=...
#
#                                             referer_leaks  \
# 9       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 10      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 11      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 17      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 18      [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# ...                                                   ...
# 110873  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110874  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110876  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110878  [('urlencode', 'www.andapp.jp'), ('www.andapp....
# 110885  [('urlencode', 'www.andapp.jp'), ('www.andapp....
#
#                              leaks         netloc path query params fragments  \
# 9                    referer_leaks   www.ox.ac.uk
# 10                   referer_leaks   www.ox.ac.uk
# 11                   referer_leaks   www.ox.ac.uk
# 17      post_leaks - referer_leaks   www.ox.ac.uk
# 18                   referer_leaks   www.ox.ac.uk
# ...                            ...            ...  ...   ...    ...       ...
# 110873               referer_leaks  www.andapp.jp
# 110874               referer_leaks  www.andapp.jp
# 110876               referer_leaks  www.andapp.jp
# 110878               referer_leaks  www.andapp.jp
# 110885  post_leaks - referer_leaks  www.andapp.jp
#
#        violation
# 9           Safe
# 10          Safe
# 11          Safe
# 17          Safe
# 18          Safe
# ...          ...
# 110873      Safe
# 110874      Safe
# 110876      Safe
# 110878      Safe
# 110885      Safe
#
# [58981 rows x 14 columns]

# %%
# Check wheter the params or fragments leak on referrer 
referer_leaks_df[referer_leaks_df['violation'] == "Warning"]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, ref_data, referer_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %% [markdown]
# ### Referer Leaks that did not follow referer policy
#
# This case is similar with the youtube case. Maybe, it's an TRC error.
# But it's also possible that there is a problem from Chrome

# %%
referer_leaks_vioilation_df = referer_leaks_df[referer_leaks_df['violation'] == "Violation"]
referer_leaks_vioilation_df.to_csv("data_seg/"+ extract_date + '_' + extract_type + '_print_referer_leaks_violation.csv')
referer_leaks_vioilation_df
# Out:
#                                             init_url  \
# 1028     https://wpengine.com/agency-partner-program
# 1029     https://wpengine.com/agency-partner-program
# 1030     https://wpengine.com/agency-partner-program
# 1038     https://wpengine.com/agency-partner-program
# 1039     https://wpengine.com/agency-partner-program
# ...                                              ...
# 110813  https://www.docker.com/products/docker-scout
# 110814  https://www.docker.com/products/docker-scout
# 110823  https://www.docker.com/products/docker-scout
# 110824  https://www.docker.com/products/docker-scout
# 110825  https://www.docker.com/products/docker-scout
#
#                                             final_url  \
# 1028     https://wpengine.com/agency-partner-program/
# 1029     https://wpengine.com/agency-partner-program/
# 1030     https://wpengine.com/agency-partner-program/
# 1038     https://wpengine.com/agency-partner-program/
# 1039     https://wpengine.com/agency-partner-program/
# ...                                               ...
# 110813  https://www.docker.com/products/docker-scout/
# 110814  https://www.docker.com/products/docker-scout/
# 110823  https://www.docker.com/products/docker-scout/
# 110824  https://www.docker.com/products/docker-scout/
# 110825  https://www.docker.com/products/docker-scout/
#
#                                                   req_url req_method  \
# 1028    https://js.driftt.com/core/assets/js/runtime~m...        GET
# 1029    https://js.driftt.com/core/assets/js/9.4a3e980...        GET
# 1030    https://js.driftt.com/core/assets/js/main~493d...        GET
# 1038    https://js.driftt.com/core/assets/js/51.558be3...        GET
# 1039    https://js.driftt.com/core/assets/js/35.d0f1cc...        GET
# ...                                                   ...        ...
# 110813  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 110814  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 110823  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 110824  https://rc-widget-frame.js.driftt.com/core/ass...        GET
# 110825  https://rc-widget-frame.js.driftt.com/core/ass...        GET
#
#                            ref_pol_data  \
# 1028    strict-origin-when-cross-origin
# 1029    strict-origin-when-cross-origin
# 1030    strict-origin-when-cross-origin
# 1038    strict-origin-when-cross-origin
# 1039    strict-origin-when-cross-origin
# ...                                 ...
# 110813  strict-origin-when-cross-origin
# 110814  strict-origin-when-cross-origin
# 110823  strict-origin-when-cross-origin
# 110824  strict-origin-when-cross-origin
# 110825  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 1028    https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 1029    https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 1030    https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 1038    https://js.driftt.com/core?d=1&embedId=5hrxis5...
# 1039    https://js.driftt.com/core?d=1&embedId=5hrxis5...
# ...                                                   ...
# 110813  https://rc-widget-frame.js.driftt.com/core?d=1...
# 110814  https://rc-widget-frame.js.driftt.com/core?d=1...
# 110823  https://rc-widget-frame.js.driftt.com/core?d=1...
# 110824  https://rc-widget-frame.js.driftt.com/core?d=1...
# 110825  https://rc-widget-frame.js.driftt.com/core?d=1...
#
#                                             referer_leaks          leaks  \
# 1028    [('wpengine.com',), ('urlencode', 'wpengine.co...  referer_leaks
# 1029    [('wpengine.com',), ('urlencode', 'wpengine.co...  referer_leaks
# 1030    [('wpengine.com',), ('urlencode', 'wpengine.co...  referer_leaks
# 1038    [('wpengine.com',), ('urlencode', 'wpengine.co...  referer_leaks
# 1039    [('wpengine.com',), ('urlencode', 'wpengine.co...  referer_leaks
# ...                                                   ...            ...
# 110813  [('urlencode', '/products/docker-scout/'), ('w...  referer_leaks
# 110814  [('urlencode', '/products/docker-scout/'), ('w...  referer_leaks
# 110823  [('urlencode', '/products/docker-scout/'), ('w...  referer_leaks
# 110824  [('urlencode', '/products/docker-scout/'), ('w...  referer_leaks
# 110825  [('urlencode', '/products/docker-scout/'), ('w...  referer_leaks
#
#                 netloc                      path query params fragments  \
# 1028      wpengine.com  /agency-partner-program/
# 1029      wpengine.com  /agency-partner-program/
# 1030      wpengine.com  /agency-partner-program/
# 1038      wpengine.com  /agency-partner-program/
# 1039      wpengine.com  /agency-partner-program/
# ...                ...                       ...   ...    ...       ...
# 110813  www.docker.com   /products/docker-scout/
# 110814  www.docker.com   /products/docker-scout/
# 110823  www.docker.com   /products/docker-scout/
# 110824  www.docker.com   /products/docker-scout/
# 110825  www.docker.com   /products/docker-scout/
#
#         violation
# 1028    Violation
# 1029    Violation
# 1030    Violation
# 1038    Violation
# 1039    Violation
# ...           ...
# 110813  Violation
# 110814  Violation
# 110823  Violation
# 110824  Violation
# 110825  Violation
#
# [2827 rows x 14 columns]

# %%
print_leak_to_csv(referer_leaks_vioilation_df)

# %%
referer_leaks_vioilation_df.count()
# Out:
# init_url         2827
# final_url        2827
# req_url          2827
# req_method       2827
# ref_pol_data     2827
# ref_data         2827
# referer_leaks    2827
# leaks            2827
# netloc           2827
# path             2827
# query            2827
# params           2827
# fragments        2827
# violation        2827
# dtype: int64

# %%
referer_leaks_vioilation_df.drop_duplicates(subset=['final_url']).count()
# Out:
# init_url         226
# final_url        226
# req_url          226
# req_method       226
# ref_pol_data     226
# ref_data         226
# referer_leaks    226
# leaks            226
# netloc           226
# path             226
# query            226
# params           226
# fragments        226
# violation        226
# dtype: int64

# %%
referer_leaks_vioilation_df.final_url.value_counts()
# Out:
# https://www.parse.ly/getdemo/                                                                                            88
# https://www.docker.com/products/docker-scout/                                                                            41
# https://www.fastly.com/cookies/                                                                                          41
# https://www.docker.com/resources/what-container/                                                                         41
# https://www.docker.com/careers/                                                                                          41
#                                                                                                                          ..
# https://www.olx.com.br/esportes-e-lazer                                                                                   1
# https://dantri.com.vn/lao-dong-viec-lam/chuyen-nghe.htm                                                                   1
# https://www.rakuten-sec.co.jp/web/market/ranking/indexes.html                                                             1
# https://disqus.com/support/                                                                                               1
# https://www.repubblica.it/politica/2023/12/06/news/giorgia_meloni_rambo_vita_privata_in_piazza_senza_pieta-421584656/     1
# Name: final_url, Length: 226, dtype: int64

# %%
referer_leaks_vioilation_df.req_url.value_counts()
# Out:
# https://s.yimg.jp/images/advertising/common/js/iicon.min.js                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            57
# https://js.driftt.com/core/assets/js/runtime~main.95493482.js                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          53
# https://js.driftt.com/core/assets/js/21.b8c41db9.chunk.js                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              53
# https://js.driftt.com/core/assets/js/9.4a3e9801.chunk.js                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               53
# https://js.driftt.com/core/assets/js/25.c23e5ac7.chunk.js                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              53
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ..
# https://platform.twitter.com/embed/embed.ondemand.i18n.fr-js.5f978eb0eb74beba794d.js                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# https://platform.twitter.com/embed/embed.ondemand.horizon-web.i18n.fr-js.9d35cf0ad9d16371806d.js                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# https://googleads.g.doubleclick.net/pagead/adview?ai=CkqEo7MFzZfrqJpbK998Pr7WO-AuG-pXcdMWcrvWAEsfTxrDFKhABINvOsCRgydb6hoCAoBmgAeXC1qIDyAECqAMByAPJBKoE2gFP0IvR2bUJ_QQPb686Ev3nieCe7SmQY7TyEdTMPmwXzmOKOtpinLCuIHQUx0zwcRSRjnPKbyuOdyPSOyWdtTjvmMrzSEBnLX4hOLKZtW7pPhrI24drKjP2SuxsmWYcYnHUJmq4VqZ41_QQxizAw2JngK_ikN-tPwN5Tz1_H97npYDX2gP1v1s9k7mzEn559Or_2kNdBoAWSBFh6z4Grz1oG0KxwUXrPu0qIT1hhsxSG552sPLNhWzs4ozObIhZhhHMw7k9ywRowdot8G6BGUDN3LGkggVPBwr_8cAEnKur4-MDiAWOo_CgOJIFBAgEGAGSBQQIBRgEkgUECAUYGJIFBQgFGKgBoAYCgAeDvaldqAeOzhuoB5PYG6gH7paxAqgH_p6xAqgH1ckbqAemvhvYBwHyBwQQ7bAI0ggdCIBhEAEYHzICigI6AoBASL39wTpY4dezjpmBgwOaCRtodHRwczovL3d3dy5taW50bW9iaWxlLmNvbS-ACgHICwGiDBwqGgoY5LSxAu61sQK1uLECrLqxAuS0sQLutbEC2gwRCgsQwJHc1_qFte_iARICAQPYEw7QFQGYFgGAFwGyFxwKGggAEhRwdWItMjQzMDc2NDAwNjk5MzMxMBgA&sigh=Zjh41ngaxlo&uach_m=%5BUACH%5D&ase=2&nis=4&cid=CAQSTgDICaaNgGnnaMErJbErG3eGu_WC82UmXISsSOjzSQ89N9efY_sdUIYhorMPcO3QWMGZZWbgsoPGWTngTQI-T-w117JrkyeuDHsw8W-TuhgB&cbvp=2&vis=1     1
# https://googleads.g.doubleclick.net/pagead/adview?ai=CWz5boK50ZcipKN31uvQPks-woAm835z0XK6C25dSwI23ARABIABgydb6hoCAoBmCARdjYS1wdWItODcxODYwNTczMzMwNzM0NcgBCagDAcgDAqoEygJP0KoIKM-6p-WFWlIwUuA1M3c_AGddK2308sSD_4dsrqbHbO_y9K-kDopAa4Gj6RBkeV3G3xzh-mAbVaPNSSeTZPKIzVTKuJnx8Lx-tPy4D7J6BHVw6V5qjjcmbqQUdHY3Et24BVWmHUY7NrrlWAtN9SMou4fg8pqprz5PWc-tj6CzDU_xIXwmat8Dpbd8gHM9ZB1AbuPbPooZ4IYMTaS4538iSM_O2DWddrN5Xe3O9wFQesuimXR2qVNRY8IMvQTfJxVQSp8DXsNjljOMiRCNI0iy_nyl8vJjh6InA4xPGTBo_gTxpHfHWOOq47ExNgYuV54NkGrEHAMgofpM5tKOY8-y2GoEX4RjOAFQeEEsIMRqsqmgekTVlaUnJQy1VtQ6014EaOqGteCmS6E9XczLo5IldYTRg3e8RVqEGdfuEr8YbyU01dFZbEqABtjb6ZGBy_yOiwGgBiGoB6a-G6gHltgbqAeqm7ECqAeDrbECqAf_nrECqAffn7EC2AcA0ggbCIBhEAEyAooCOgKAQEi9_cE6WMfh6-z6goMDgAoD-gsCCAGADAHQFQGAFwGyFxwKGhIUcHViLTg3MTg2MDU3MzMzMDczNDUYwPcF&sigh=QJ4B9_bIlvE&uach_m=%5BUACH%5D&cid=CAQSGwDICaaNkHAbNGureGZWbAsnK_T7EZgezPxiZhgB&cbvp=2&vis=1                                                                                         1
# https://ups.analytics.yahoo.com/ups/56465/sync?uid=y-TT3o2KFE2p7rLG2IdNRA5YQQSoGMgFJ5JbxT~A&_origin=0&nsync=0&gpp=DBABLA~BVQqAAAACgA.QA&gpp_sid=7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Name: req_url, Length: 353, dtype: int64

# %%
referer_leaks_vioilation_df.req_method.value_counts()
# Out:
# GET     2805
# POST      22
# Name: req_method, dtype: int64

# %% [markdown]
# ### Google

# %%
# list of referer leaks to google
referer_leaks_vioilation_df[referer_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)]
# Out:
#                                                  init_url  \
# 1935     https://www.samsung.com/us/watches/galaxy-watch6
# 17188   https://dantri.com.vn/lao-dong-viec-lam/chuyen...
# 17723   https://www.wikihow.com/make-christmas-come-fa...
# 18767   https://weathernews.jp/onebox/radar/?fm=dotop&...
# 20454                               https://pets.udn.com/
# 23550   https://www.investopedia.com/the-american-drea...
# 23564   https://www.investopedia.com/the-american-drea...
# 23565   https://www.investopedia.com/the-american-drea...
# 23566   https://www.investopedia.com/the-american-drea...
# 23572   https://www.investopedia.com/the-american-drea...
# 23573   https://www.investopedia.com/the-american-drea...
# 27216   https://www.haberler.com/politika/cumhurbaskan...
# 27217   https://www.haberler.com/politika/cumhurbaskan...
# 29846                 https://www.fmkorea.com/fm24players
# 40281                    https://www.fmkorea.com/fm23tips
# 40283                    https://www.fmkorea.com/fm23tips
# 40284                    https://www.fmkorea.com/fm23tips
# 42559                    https://www.fmkorea.com/fm24tips
# 42560                    https://www.fmkorea.com/fm24tips
# 42598                      https://www.dafont.com/new.php
# 43392   https://www.haberler.com/3-sayfa/adana-da-lise...
# 48379     https://www.youtube.com/@cozycoffeeshopofficial
# 52182             https://www.olx.com.br/esportes-e-lazer
# 52777                 https://www.fmkorea.com/fm23players
# 52778                 https://www.fmkorea.com/fm23players
# 67717   https://www.samsung.com/us/mobile/tablets/all-...
# 78926   https://www.haberler.com/ekonomi/nas-gerekcesi...
# 78930   https://www.haberler.com/ekonomi/nas-gerekcesi...
# 82038   https://apkpure.com/garena-free-fire-android-i...
# 82050   https://apkpure.com/garena-free-fire-android-i...
# 83881         https://www.wikihow.com/how-big-is-your-ego
# 83884         https://www.wikihow.com/how-big-is-your-ego
# 85114   https://apkpure.com/call-of-duty-mobile/com.ac...
# 85117   https://apkpure.com/call-of-duty-mobile/com.ac...
# 85125   https://apkpure.com/call-of-duty-mobile/com.ac...
# 85127   https://apkpure.com/call-of-duty-mobile/com.ac...
# 90808               https://www.wikihow.com/future-faking
# 90824               https://www.wikihow.com/future-faking
# 99986   https://www.haberler.com/3-sayfa/oktay-derelio...
# 100291  https://dantri.com.vn/lao-dong-viec-lam/lam-gi...
# 102546  https://v.daum.net/v/20231206231123680?x_imp=d...
# 103779                   https://www.fmkorea.com/fm23tqna
# 107935  https://apkpure.com/loklok-dramas-movies/com.a...
# 109330                 https://tenki.jp/bousai/earthquake
# 109332                 https://tenki.jp/bousai/earthquake
#
#                                                 final_url  \
# 1935    https://www.samsung.com/us/watches/galaxy-watch6/
# 17188   https://dantri.com.vn/lao-dong-viec-lam/chuyen...
# 17723   https://www.wikihow.com/Make-Christmas-Come-Fa...
# 18767   https://weathernews.jp/onebox/radar/?fm=dotop&...
# 20454                     https://pets.udn.com/pets/index
# 23550   https://www.investopedia.com/the-american-drea...
# 23564   https://www.investopedia.com/the-american-drea...
# 23565   https://www.investopedia.com/the-american-drea...
# 23566   https://www.investopedia.com/the-american-drea...
# 23572   https://www.investopedia.com/the-american-drea...
# 23573   https://www.investopedia.com/the-american-drea...
# 27216   https://www.haberler.com/politika/cumhurbaskan...
# 27217   https://www.haberler.com/politika/cumhurbaskan...
# 29846                 https://www.fmkorea.com/fm24players
# 40281                    https://www.fmkorea.com/fm23tips
# 40283                    https://www.fmkorea.com/fm23tips
# 40284                    https://www.fmkorea.com/fm23tips
# 42559                    https://www.fmkorea.com/fm24tips
# 42560                    https://www.fmkorea.com/fm24tips
# 42598                      https://www.dafont.com/new.php
# 43392   https://www.haberler.com/3-sayfa/adana-da-lise...
# 48379     https://www.youtube.com/@cozycoffeeshopofficial
# 52182             https://www.olx.com.br/esportes-e-lazer
# 52777                 https://www.fmkorea.com/fm23players
# 52778                 https://www.fmkorea.com/fm23players
# 67717   https://www.samsung.com/us/mobile/tablets/all-...
# 78926   https://www.haberler.com/ekonomi/nas-gerekcesi...
# 78930   https://www.haberler.com/ekonomi/nas-gerekcesi...
# 82038   https://apkpure.com/garena-free-fire-android-i...
# 82050   https://apkpure.com/garena-free-fire-android-i...
# 83881         https://www.wikihow.com/How-Big-Is-Your-Ego
# 83884         https://www.wikihow.com/How-Big-Is-Your-Ego
# 85114   https://apkpure.com/call-of-duty-mobile/com.ac...
# 85117   https://apkpure.com/call-of-duty-mobile/com.ac...
# 85125   https://apkpure.com/call-of-duty-mobile/com.ac...
# 85127   https://apkpure.com/call-of-duty-mobile/com.ac...
# 90808               https://www.wikihow.com/Future-Faking
# 90824               https://www.wikihow.com/Future-Faking
# 99986   https://www.haberler.com/3-sayfa/oktay-derelio...
# 100291  https://dantri.com.vn/lao-dong-viec-lam/lam-gi...
# 102546             https://v.daum.net/v/20231206231123680
# 103779                   https://www.fmkorea.com/fm23tqna
# 107935  https://apkpure.com/loklok-dramas-movies/com.a...
# 109330     https://earthquake.tenki.jp/bousai/earthquake/
# 109332     https://earthquake.tenki.jp/bousai/earthquake/
#
#                                                   req_url req_method  \
# 1935    https://cm.g.doubleclick.net/pixel?google_nid=...        GET
# 17188   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 17723   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 18767   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 20454   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 23550   https://live-tag.creatopy.net/designs/x6j13gk/...        GET
# 23564   https://live-tag.creatopy.net/designs/x6j13gk/...        GET
# 23565   https://live-tag.creatopy.net/designs/x6j13gk/...        GET
# 23566   https://live-tag.creatopy.net/designs/x6j13gk/...        GET
# 23572   https://live-tag.creatopy.net/designs/x6j13gk/...        GET
# 23573   https://live-tag.creatopy.net/designs/x6j13gk/...        GET
# 27216   https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 27217   https://googleads.g.doubleclick.net/dbm/ad?dbm...        GET
# 29846   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 40281   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 40283   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 40284   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 42559   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 42560   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 42598   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 43392   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 48379   https://googleads.g.doubleclick.net/pagead/vie...        GET
# 52182   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 52777   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 52778   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 67717   https://cm.g.doubleclick.net/pixel?google_nid=...        GET
# 78926   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 78930   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 82038   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 82050   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 83881   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 83884   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 85114   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 85117   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 85125   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 85127   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 90808   https://googleads.g.doubleclick.net/pagead/drt...        GET
# 90824   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 99986   https://googleads.g.doubleclick.net/pagead/adv...        GET
# 100291  https://googleads.g.doubleclick.net/pagead/adv...        GET
# 102546  https://googleads.g.doubleclick.net/pagead/adv...        GET
# 103779  https://googleads.g.doubleclick.net/pagead/adv...        GET
# 107935  https://googleads.g.doubleclick.net/pagead/adv...        GET
# 109330  https://googleads.g.doubleclick.net/xbbe/pixel...        GET
# 109332  https://googleads.g.doubleclick.net/dbm/ad?dbm...        GET
#
#                            ref_pol_data  \
# 1935                        same-origin
# 17188   strict-origin-when-cross-origin
# 17723   strict-origin-when-cross-origin
# 18767   strict-origin-when-cross-origin
# 20454   strict-origin-when-cross-origin
# 23550   strict-origin-when-cross-origin
# 23564   strict-origin-when-cross-origin
# 23565   strict-origin-when-cross-origin
# 23566   strict-origin-when-cross-origin
# 23572   strict-origin-when-cross-origin
# 23573   strict-origin-when-cross-origin
# 27216   strict-origin-when-cross-origin
# 27217   strict-origin-when-cross-origin
# 29846   strict-origin-when-cross-origin
# 40281   strict-origin-when-cross-origin
# 40283   strict-origin-when-cross-origin
# 40284   strict-origin-when-cross-origin
# 42559   strict-origin-when-cross-origin
# 42560   strict-origin-when-cross-origin
# 42598   strict-origin-when-cross-origin
# 43392   strict-origin-when-cross-origin
# 48379   strict-origin-when-cross-origin
# 52182   strict-origin-when-cross-origin
# 52777   strict-origin-when-cross-origin
# 52778   strict-origin-when-cross-origin
# 67717                       same-origin
# 78926   strict-origin-when-cross-origin
# 78930   strict-origin-when-cross-origin
# 82038   strict-origin-when-cross-origin
# 82050   strict-origin-when-cross-origin
# 83881   strict-origin-when-cross-origin
# 83884   strict-origin-when-cross-origin
# 85114   strict-origin-when-cross-origin
# 85117   strict-origin-when-cross-origin
# 85125   strict-origin-when-cross-origin
# 85127   strict-origin-when-cross-origin
# 90808   strict-origin-when-cross-origin
# 90824   strict-origin-when-cross-origin
# 99986   strict-origin-when-cross-origin
# 100291  strict-origin-when-cross-origin
# 102546  strict-origin-when-cross-origin
# 103779  strict-origin-when-cross-origin
# 107935  strict-origin-when-cross-origin
# 109330  strict-origin-when-cross-origin
# 109332  strict-origin-when-cross-origin
#
#                                                  ref_data  \
# 1935    https://login.dotomi.com/ucm/visit/iframe?cli_...
# 17188   https://googleads.g.doubleclick.net/pagead/ads...
# 17723   https://googleads.g.doubleclick.net/pagead/ads...
# 18767   https://googleads.g.doubleclick.net/pagead/ads...
# 20454   https://googleads.g.doubleclick.net/pagead/ads...
# 23550   https://live-tag.creatopy.net/designs/x6j13gk/...
# 23564   https://live-tag.creatopy.net/designs/x6j13gk/...
# 23565   https://live-tag.creatopy.net/designs/x6j13gk/...
# 23566   https://live-tag.creatopy.net/designs/x6j13gk/...
# 23572   https://live-tag.creatopy.net/designs/x6j13gk/...
# 23573   https://live-tag.creatopy.net/designs/x6j13gk/...
# 27216   https://googleads.g.doubleclick.net/pagead/ads...
# 27217   https://googleads.g.doubleclick.net/pagead/ads...
# 29846   https://googleads.g.doubleclick.net/pagead/ads...
# 40281   https://googleads.g.doubleclick.net/pagead/ads...
# 40283   https://googleads.g.doubleclick.net/pagead/ads...
# 40284   https://googleads.g.doubleclick.net/pagead/ads...
# 42559   https://googleads.g.doubleclick.net/pagead/ads...
# 42560   https://googleads.g.doubleclick.net/pagead/ads...
# 42598   https://googleads.g.doubleclick.net/pagead/ads...
# 43392   https://googleads.g.doubleclick.net/pagead/ads...
# 48379     https://www.youtube.com/@cozycoffeeshopofficial
# 52182   https://googleads.g.doubleclick.net/pagead/ads...
# 52777   https://googleads.g.doubleclick.net/pagead/ads...
# 52778   https://googleads.g.doubleclick.net/pagead/ads...
# 67717   https://login.dotomi.com/ucm/visit/iframe?cli_...
# 78926   https://googleads.g.doubleclick.net/pagead/ads...
# 78930   https://googleads.g.doubleclick.net/pagead/ads...
# 82038   https://googleads.g.doubleclick.net/pagead/ads...
# 82050   https://googleads.g.doubleclick.net/pagead/ads...
# 83881   https://googleads.g.doubleclick.net/pagead/ads...
# 83884   https://googleads.g.doubleclick.net/pagead/ads...
# 85114   https://googleads.g.doubleclick.net/pagead/ads...
# 85117   https://googleads.g.doubleclick.net/pagead/ads...
# 85125   https://googleads.g.doubleclick.net/pagead/ads...
# 85127   https://googleads.g.doubleclick.net/pagead/ads...
# 90808   https://googleads.g.doubleclick.net/pagead/ads...
# 90824   https://googleads.g.doubleclick.net/pagead/ads...
# 99986   https://googleads.g.doubleclick.net/pagead/ads...
# 100291  https://googleads.g.doubleclick.net/pagead/ads...
# 102546  https://googleads.g.doubleclick.net/pagead/ads...
# 103779  https://googleads.g.doubleclick.net/pagead/ads...
# 107935  https://googleads.g.doubleclick.net/pagead/ads...
# 109330  https://googleads.g.doubleclick.net/pagead/ads...
# 109332  https://googleads.g.doubleclick.net/pagead/ads...
#
#                                             referer_leaks  \
# 1935    [('www.samsung.com',), ('urlencode', 'www.sams...
# 17188   [('urlencode', '/lao-dong-viec-lam/chuyen-nghe...
# 17723   [('www.wikihow.com',), ('urlencode', 'www.wiki...
# 18767   [('weathernews.jp',), ('urlencode', 'weatherne...
# 20454   [('urlencode', '/pets/index'), ('pets.udn.com'...
# 23550   [('www.investopedia.com',), ('urlencode', 'www...
# 23564   [('www.investopedia.com',), ('urlencode', 'www...
# 23565   [('www.investopedia.com',), ('urlencode', 'www...
# 23566   [('www.investopedia.com',), ('urlencode', 'www...
# 23572   [('www.investopedia.com',), ('urlencode', 'www...
# 23573   [('www.investopedia.com',), ('urlencode', 'www...
# 27216   [('urlencode', '/politika/cumhurbaskani-erdoga...
# 27217   [('urlencode', '/politika/cumhurbaskani-erdoga...
# 29846   [('urlencode', '/fm24players'), ('www.fmkorea....
# 40281   [('urlencode', '/fm23tips'), ('www.fmkorea.com...
# 40283   [('urlencode', '/fm23tips'), ('www.fmkorea.com...
# 40284   [('urlencode', '/fm23tips'), ('www.fmkorea.com...
# 42559   [('www.fmkorea.com',), ('urlencode', '/fm24tip...
# 42560   [('www.fmkorea.com',), ('urlencode', '/fm24tip...
# 42598   [('urlencode', '/new.php'), ('www.dafont.com',...
# 43392   [('urlencode', '/3-sayfa/adana-da-liseli-kiza-...
# 48379                     [('/@cozycoffeeshopofficial',)]
# 52182   [('urlencode', '/esportes-e-lazer'), ('www.olx...
# 52777   [('urlencode', '/fm23players'), ('www.fmkorea....
# 52778   [('urlencode', '/fm23players'), ('www.fmkorea....
# 67717   [('www.samsung.com',), ('urlencode', 'www.sams...
# 78926   [('urlencode', '/ekonomi/nas-gerekcesiyle-faiz...
# 78930   [('urlencode', '/ekonomi/nas-gerekcesiyle-faiz...
# 82038   [('urlencode', '/garena-free-fire-android-il/c...
# 82050   [('urlencode', '/garena-free-fire-android-il/c...
# 83881   [('www.wikihow.com',), ('urlencode', 'www.wiki...
# 83884   [('www.wikihow.com',), ('urlencode', 'www.wiki...
# 85114   [('apkpure.com',), ('urlencode', 'apkpure.com'...
# 85117   [('apkpure.com',), ('urlencode', 'apkpure.com'...
# 85125   [('apkpure.com',), ('urlencode', 'apkpure.com'...
# 85127   [('apkpure.com',), ('urlencode', 'apkpure.com'...
# 90808   [('www.wikihow.com',), ('urlencode', 'www.wiki...
# 90824   [('www.wikihow.com',), ('urlencode', 'www.wiki...
# 99986   [('www.haberler.com',), ('urlencode', '/3-sayf...
# 100291  [('urlencode', '/lao-dong-viec-lam/lam-giau.ht...
# 102546  [('urlencode', 'v.daum.net'), ('urlencode', '/...
# 103779  [('urlencode', '/fm23tqna'), ('www.fmkorea.com...
# 107935  [('urlencode', '/loklok-dramas-movies/com.arte...
# 109330  [('urlencode', 'earthquake.tenki.jp'), ('urlen...
# 109332  [('urlencode', 'earthquake.tenki.jp'), ('urlen...
#
#                             leaks                netloc  \
# 1935                referer_leaks       www.samsung.com
# 17188               referer_leaks         dantri.com.vn
# 17723               referer_leaks       www.wikihow.com
# 18767               referer_leaks        weathernews.jp
# 20454               referer_leaks          pets.udn.com
# 23550               referer_leaks  www.investopedia.com
# 23564               referer_leaks  www.investopedia.com
# 23565               referer_leaks  www.investopedia.com
# 23566               referer_leaks  www.investopedia.com
# 23572               referer_leaks  www.investopedia.com
# 23573               referer_leaks  www.investopedia.com
# 27216               referer_leaks      www.haberler.com
# 27217   url_leaks - referer_leaks      www.haberler.com
# 29846               referer_leaks       www.fmkorea.com
# 40281               referer_leaks       www.fmkorea.com
# 40283               referer_leaks       www.fmkorea.com
# 40284               referer_leaks       www.fmkorea.com
# 42559               referer_leaks       www.fmkorea.com
# 42560               referer_leaks       www.fmkorea.com
# 42598               referer_leaks        www.dafont.com
# 43392               referer_leaks      www.haberler.com
# 48379               referer_leaks
# 52182               referer_leaks        www.olx.com.br
# 52777               referer_leaks       www.fmkorea.com
# 52778               referer_leaks       www.fmkorea.com
# 67717               referer_leaks       www.samsung.com
# 78926               referer_leaks      www.haberler.com
# 78930               referer_leaks      www.haberler.com
# 82038               referer_leaks           apkpure.com
# 82050               referer_leaks           apkpure.com
# 83881               referer_leaks       www.wikihow.com
# 83884               referer_leaks       www.wikihow.com
# 85114               referer_leaks           apkpure.com
# 85117               referer_leaks           apkpure.com
# 85125               referer_leaks           apkpure.com
# 85127               referer_leaks           apkpure.com
# 90808               referer_leaks       www.wikihow.com
# 90824               referer_leaks       www.wikihow.com
# 99986               referer_leaks      www.haberler.com
# 100291              referer_leaks         dantri.com.vn
# 102546              referer_leaks            v.daum.net
# 103779              referer_leaks       www.fmkorea.com
# 107935              referer_leaks           apkpure.com
# 109330              referer_leaks   earthquake.tenki.jp
# 109332  url_leaks - referer_leaks   earthquake.tenki.jp
#
#                                                      path               query  \
# 1935                           /us/watches/galaxy-watch6/
# 17188                  /lao-dong-viec-lam/chuyen-nghe.htm
# 17723                         /Make-Christmas-Come-Faster
# 18767                                      /onebox/radar/  fm=dotop&fmdotop=1
# 20454                                         /pets/index
# 23550   /the-american-dream-now-costs-over-usd3-millio...
# 23564   /the-american-dream-now-costs-over-usd3-millio...
# 23565   /the-american-dream-now-costs-over-usd3-millio...
# 23566   /the-american-dream-now-costs-over-usd3-millio...
# 23572   /the-american-dream-now-costs-over-usd3-millio...
# 23573   /the-american-dream-now-costs-over-usd3-millio...
# 27216   /politika/cumhurbaskani-erdogan-kabine-toplant...
# 27217   /politika/cumhurbaskani-erdogan-kabine-toplant...
# 29846                                        /fm24players
# 40281                                           /fm23tips
# 40283                                           /fm23tips
# 40284                                           /fm23tips
# 42559                                           /fm24tips
# 42560                                           /fm24tips
# 42598                                            /new.php
# 43392   /3-sayfa/adana-da-liseli-kiza-istismar-davasi-...
# 48379                            /@cozycoffeeshopofficial
# 52182                                   /esportes-e-lazer
# 52777                                        /fm23players
# 52778                                        /fm23players
# 67717                     /us/mobile/tablets/all-tablets/
# 78926   /ekonomi/nas-gerekcesiyle-faizi-indirmeseydik-...
# 78930   /ekonomi/nas-gerekcesiyle-faizi-indirmeseydik-...
# 82038     /garena-free-fire-android-il/com.dts.freefireth
# 82050     /garena-free-fire-android-il/com.dts.freefireth
# 83881                                /How-Big-Is-Your-Ego
# 83884                                /How-Big-Is-Your-Ego
# 85114   /call-of-duty-mobile/com.activision.callofduty...
# 85117   /call-of-duty-mobile/com.activision.callofduty...
# 85125   /call-of-duty-mobile/com.activision.callofduty...
# 85127   /call-of-duty-mobile/com.activision.callofduty...
# 90808                                      /Future-Faking
# 90824                                      /Future-Faking
# 99986   /3-sayfa/oktay-derelioglu-trafikte-darp-edildi...
# 100291                    /lao-dong-viec-lam/lam-giau.htm
# 102546                               /v/20231206231123680
# 103779                                          /fm23tqna
# 107935           /loklok-dramas-movies/com.artem.scotepio
# 109330                                /bousai/earthquake/
# 109332                                /bousai/earthquake/
#
#        params fragments  violation
# 1935                     Violation
# 17188                    Violation
# 17723                    Violation
# 18767                    Violation
# 20454                    Violation
# 23550                    Violation
# 23564                    Violation
# 23565                    Violation
# 23566                    Violation
# 23572                    Violation
# 23573                    Violation
# 27216                    Violation
# 27217                    Violation
# 29846                    Violation
# 40281                    Violation
# 40283                    Violation
# 40284                    Violation
# 42559                    Violation
# 42560                    Violation
# 42598                    Violation
# 43392                    Violation
# 48379                    Violation
# 52182                    Violation
# 52777                    Violation
# 52778                    Violation
# 67717                    Violation
# 78926                    Violation
# 78930                    Violation
# 82038                    Violation
# 82050                    Violation
# 83881                    Violation
# 83884                    Violation
# 85114                    Violation
# 85117                    Violation
# 85125                    Violation
# 85127                    Violation
# 90808                    Violation
# 90824                    Violation
# 99986                    Violation
# 100291                   Violation
# 102546                   Violation
# 103779                   Violation
# 107935                   Violation
# 109330                   Violation
# 109332                   Violation

# %%
# counting on referer leaks to google
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('google')
    .fillna(False)
    ].count()
# Out:
# init_url         45
# final_url        45
# req_url          45
# req_method       45
# ref_pol_data     45
# ref_data         45
# referer_leaks    45
# leaks            45
# netloc           45
# path             45
# query            45
# params           45
# fragments        45
# violation        45
# dtype: int64

# %% [markdown]
# ### META / Facebook

# %%
# list of referer leaks to Meta or Facebook
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('meta')
    | referer_leaks_vioilation_df['req_url']
        .str
        .contains('facebook')]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, ref_data, referer_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
# Counting on referer leaks to Meta or Facebook
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('meta') 
    | referer_leaks_vioilation_df['req_url']
        .str.
        contains('facebook')].count()
# Out:
# init_url         0
# final_url        0
# req_url          0
# req_method       0
# ref_pol_data     0
# ref_data         0
# referer_leaks    0
# leaks            0
# netloc           0
# path             0
# query            0
# params           0
# fragments        0
# violation        0
# dtype: int64

# %% [markdown]
# ### Tiktok

# %%
# list of referer leaks to tiktok
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('tiktok')
    .fillna(False)]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, ref_data, referer_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
referer_leaks_vioilation_df[
    referer_leaks_vioilation_df['req_url']
    .str
    .contains('tiktok')
    .fillna(False)].count()
# Out:
# init_url         0
# final_url        0
# req_url          0
# req_method       0
# ref_pol_data     0
# ref_data         0
# referer_leaks    0
# leaks            0
# netloc           0
# path             0
# query            0
# params           0
# fragments        0
# violation        0
# dtype: int64

# %% [markdown]
# ## Leaks on URL

# %%
# create a new dataframe with non-empty 'referer_leaks' column
url_leaks_df = drop_non_leak(extracted_df, 'url_leaks')
url_leaks_df
# Out:
#                                                 init_url  \
# 0                          https://www.ox.ac.uk/research
# 1                          https://www.ox.ac.uk/research
# 2                          https://www.ox.ac.uk/research
# 3                          https://www.ox.ac.uk/research
# 4                          https://www.ox.ac.uk/research
# ...                                                  ...
# 110881  https://www.mbga.jp/_game_intro?game_id=12016007
# 110882  https://www.mbga.jp/_game_intro?game_id=12016007
# 110883  https://www.mbga.jp/_game_intro?game_id=12016007
# 110884  https://www.mbga.jp/_game_intro?game_id=12016007
# 110886  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 110881  https://www.andapp.jp/apps/12016007?from=www_m...
# 110882  https://www.andapp.jp/apps/12016007?from=www_m...
# 110883  https://www.andapp.jp/apps/12016007?from=www_m...
# 110884  https://www.andapp.jp/apps/12016007?from=www_m...
# 110886  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 0       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...        GET
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 3       https://apikeys.civiccomputing.com/c/v?d=www.o...        GET
# 4       https://www.linkedin.com/px/li_sync?redirect=h...        GET
# ...                                                   ...        ...
# 110881  https://adservice.google.com/ddm/fls/i/dc_pre=...        GET
# 110882  https://6015542.fls.doubleclick.net/ddm/fls/r/...        GET
# 110883  https://syndication.twitter.com/i/jot/embeds?l...        GET
# 110884  https://www.google.com/pagead/1p-user-list/878...        GET
# 110886  https://aw.dw.impact-ad.jp/ut/rep?u=2714&v=2&r...        GET
#
#                            ref_pol_data  \
# 0       strict-origin-when-cross-origin
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 3       strict-origin-when-cross-origin
# 4       strict-origin-when-cross-origin
# ...                                 ...
# 110881  strict-origin-when-cross-origin
# 110882  strict-origin-when-cross-origin
# 110883  strict-origin-when-cross-origin
# 110884  strict-origin-when-cross-origin
# 110886  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks
# 0       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 1       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 2       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 3       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 4       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# ...                                                   ...        ...
# 110881                               [('www.andapp.jp',)]  url_leaks
# 110882                               [('www.andapp.jp',)]  url_leaks
# 110883  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110884  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110886  [('urlencode', 'www.andapp.jp'), ('www.andapp....  url_leaks
#
# [51777 rows x 7 columns]

# %%
# expand the datarame with the result from check_urlparse function and create a new colomn with the result from check_violation function
url_leaks_df[['netloc', 'path', 'query', 'params', 'fragments']] = url_leaks_df.apply(check_urlparse, axis=1, result_type='expand')

url_leaks_df['violation'] = url_leaks_df.apply(check_violation, axis=1, result_type='expand')

url_leaks_df
# Out:
#                                                 init_url  \
# 0                          https://www.ox.ac.uk/research
# 1                          https://www.ox.ac.uk/research
# 2                          https://www.ox.ac.uk/research
# 3                          https://www.ox.ac.uk/research
# 4                          https://www.ox.ac.uk/research
# ...                                                  ...
# 110881  https://www.mbga.jp/_game_intro?game_id=12016007
# 110882  https://www.mbga.jp/_game_intro?game_id=12016007
# 110883  https://www.mbga.jp/_game_intro?game_id=12016007
# 110884  https://www.mbga.jp/_game_intro?game_id=12016007
# 110886  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 0                           https://www.ox.ac.uk/research
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 3                           https://www.ox.ac.uk/research
# 4                           https://www.ox.ac.uk/research
# ...                                                   ...
# 110881  https://www.andapp.jp/apps/12016007?from=www_m...
# 110882  https://www.andapp.jp/apps/12016007?from=www_m...
# 110883  https://www.andapp.jp/apps/12016007?from=www_m...
# 110884  https://www.andapp.jp/apps/12016007?from=www_m...
# 110886  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 0       https://www.youtube.com/embed/VQwYwDqHA7I?wmod...        GET
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 3       https://apikeys.civiccomputing.com/c/v?d=www.o...        GET
# 4       https://www.linkedin.com/px/li_sync?redirect=h...        GET
# ...                                                   ...        ...
# 110881  https://adservice.google.com/ddm/fls/i/dc_pre=...        GET
# 110882  https://6015542.fls.doubleclick.net/ddm/fls/r/...        GET
# 110883  https://syndication.twitter.com/i/jot/embeds?l...        GET
# 110884  https://www.google.com/pagead/1p-user-list/878...        GET
# 110886  https://aw.dw.impact-ad.jp/ut/rep?u=2714&v=2&r...        GET
#
#                            ref_pol_data  \
# 0       strict-origin-when-cross-origin
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 3       strict-origin-when-cross-origin
# 4       strict-origin-when-cross-origin
# ...                                 ...
# 110881  strict-origin-when-cross-origin
# 110882  strict-origin-when-cross-origin
# 110883  strict-origin-when-cross-origin
# 110884  strict-origin-when-cross-origin
# 110886  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 0       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 1       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 2       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 3       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# 4       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...  url_leaks
# ...                                                   ...        ...
# 110881                               [('www.andapp.jp',)]  url_leaks
# 110882                               [('www.andapp.jp',)]  url_leaks
# 110883  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110884  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110886  [('urlencode', 'www.andapp.jp'), ('www.andapp....  url_leaks
#
#                netloc            path                query params fragments  \
# 0        www.ox.ac.uk
# 1        www.ox.ac.uk       /research
# 2        www.ox.ac.uk       /research
# 3        www.ox.ac.uk
# 4        www.ox.ac.uk
# ...               ...             ...                  ...    ...       ...
# 110881  www.andapp.jp
# 110882  www.andapp.jp
# 110883  www.andapp.jp  /apps/12016007  from=www_mbga_intro
# 110884  www.andapp.jp  /apps/12016007  from=www_mbga_intro
# 110886  www.andapp.jp
#
#         violation
# 0            Safe
# 1       Violation
# 2       Violation
# 3            Safe
# 4            Safe
# ...           ...
# 110881       Safe
# 110882       Safe
# 110883  Violation
# 110884  Violation
# 110886       Safe
#
# [51777 rows x 13 columns]

# %%
# Check wheter the params or fragments leak on url
url_leaks_df[url_leaks_df['violation'] == "Warning"]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, url_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
url_leaks_vioilation_df = url_leaks_df[url_leaks_df['violation'] == "Violation"]
url_leaks_vioilation_df
# Out:
#                                                  init_url  \
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 6                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 60      https://ameblo.jp/borderfreecosmetics/entry-12...
# ...                                                   ...
# 110875   https://www.mbga.jp/_game_intro?game_id=12016007
# 110879   https://www.mbga.jp/_game_intro?game_id=12016007
# 110880   https://www.mbga.jp/_game_intro?game_id=12016007
# 110883   https://www.mbga.jp/_game_intro?game_id=12016007
# 110884   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 1                           https://www.ox.ac.uk/research
# 2                           https://www.ox.ac.uk/research
# 6                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 60      https://ameblo.jp/borderfreecosmetics/entry-12...
# ...                                                   ...
# 110875  https://www.andapp.jp/apps/12016007?from=www_m...
# 110879  https://www.andapp.jp/apps/12016007?from=www_m...
# 110880  https://www.andapp.jp/apps/12016007?from=www_m...
# 110883  https://www.andapp.jp/apps/12016007?from=www_m...
# 110884  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 2       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 6       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 56      https://www.google-analytics.com/g/collect?v=2...       POST
# 60      https://ln.ameba.jp/v3/zBymKrvv?rd=7e93fce4-60...        GET
# ...                                                   ...        ...
# 110875  https://yjtag.yahoo.co.jp/tag?site=k36tMgw&ref...        GET
# 110879  https://www.facebook.com/v10.0/plugins/like.ph...        GET
# 110880  https://googleads.g.doubleclick.net/pagead/vie...        GET
# 110883  https://syndication.twitter.com/i/jot/embeds?l...        GET
# 110884  https://www.google.com/pagead/1p-user-list/878...        GET
#
#                            ref_pol_data  \
# 1       strict-origin-when-cross-origin
# 2       strict-origin-when-cross-origin
# 6       strict-origin-when-cross-origin
# 56                               origin
# 60                               origin
# ...                                 ...
# 110875  strict-origin-when-cross-origin
# 110879  strict-origin-when-cross-origin
# 110880  strict-origin-when-cross-origin
# 110883  strict-origin-when-cross-origin
# 110884  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 1       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 2       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 6       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 56      [('ameblo.jp',), ('urlencode', 'ameblo.jp'), (...  url_leaks
# 60      [('ameblo.jp',), ('urlencode', 'ameblo.jp'), (...  url_leaks
# ...                                                   ...        ...
# 110875  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110879  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110880  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110883  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110884  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
#
#                netloc                                         path  \
# 1        www.ox.ac.uk                                    /research
# 2        www.ox.ac.uk                                    /research
# 6        www.ox.ac.uk                                    /research
# 56          ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 60          ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# ...               ...                                          ...
# 110875  www.andapp.jp                               /apps/12016007
# 110879  www.andapp.jp                               /apps/12016007
# 110880  www.andapp.jp                               /apps/12016007
# 110883  www.andapp.jp                               /apps/12016007
# 110884  www.andapp.jp                               /apps/12016007
#
#                       query params fragments  violation
# 1                                             Violation
# 2                                             Violation
# 6                                             Violation
# 56                                            Violation
# 60                                            Violation
# ...                     ...    ...       ...        ...
# 110875  from=www_mbga_intro                   Violation
# 110879                                        Violation
# 110880  from=www_mbga_intro                   Violation
# 110883  from=www_mbga_intro                   Violation
# 110884  from=www_mbga_intro                   Violation
#
# [30658 rows x 13 columns]

# %% [markdown]
# ### Maybe some of them is false alarm
#
# For example is a language setting that can be shown on query. The pattern usually "lang=xx"

# %%
url_leaks_vioilation_df[
    (url_leaks_vioilation_df['query']
    .str
    .contains('lang', na=False))
          ]
# Out:
#                                                  init_url  \
# 7780           https://store.netgear.com/home/?lang=en_us
# 7804           https://store.netgear.com/home/?lang=en_us
# 7806           https://store.netgear.com/home/?lang=en_us
# 7807           https://store.netgear.com/home/?lang=en_us
# 7809           https://store.netgear.com/home/?lang=en_us
# ...                                                   ...
# 88678   https://dzen.ru/news/story/vpodmoskove_nashli_...
# 93422   https://dzen.ru/news/story/vnarodnom_sovete_ln...
# 101085                 https://businesshelp.snapchat.com/
# 102563  https://www.scorecardresearch.com/about.aspx?n...
# 102564  https://www.scorecardresearch.com/about.aspx?n...
#
#                                                 final_url  \
# 7780    https://store.netgear.com/home/?lang=en_us&ref...
# 7804    https://store.netgear.com/home/?lang=en_us&ref...
# 7806    https://store.netgear.com/home/?lang=en_us&ref...
# 7807    https://store.netgear.com/home/?lang=en_us&ref...
# 7809    https://store.netgear.com/home/?lang=en_us&ref...
# ...                                                   ...
# 88678   https://dzen.ru/news/story/vpodmoskove_nashli_...
# 93422   https://dzen.ru/news/story/vnarodnom_sovete_ln...
# 101085  https://businesshelp.snapchat.com/s/?language=...
# 102563  https://www.scorecardresearch.com/about.aspx?n...
# 102564  https://www.scorecardresearch.com/about.aspx?n...
#
#                                                   req_url req_method  \
# 7780    https://reliably-main-silkworm.pgsdemo.com/?la...        GET
# 7804    https://hero.kingpinkton.com/ct?id=26647&url=h...        GET
# 7806    https://ct.pinterest.com/v3/?tid=2613809389803...        GET
# 7807    https://events.attentivemobile.com/e?v=4.25.43...       POST
# 7809    https://www.facebook.com/tr/?id=43154253371256...        GET
# ...                                                   ...        ...
# 88678   https://sso.passport.yandex.ru/push?uuid=f7d40...        GET
# 93422   https://sso.passport.yandex.ru/push?uuid=e9feb...        GET
# 101085  https://www.google-analytics.com/j/collect?v=1...       POST
# 102563  https://www.google-analytics.com/j/collect?v=1...       POST
# 102564  https://www.google-analytics.com/g/collect?v=2...       POST
#
#                            ref_pol_data  \
# 7780    strict-origin-when-cross-origin
# 7804    strict-origin-when-cross-origin
# 7806    strict-origin-when-cross-origin
# 7807    strict-origin-when-cross-origin
# 7809    strict-origin-when-cross-origin
# ...                                 ...
# 88678   strict-origin-when-cross-origin
# 93422   strict-origin-when-cross-origin
# 101085         origin-when-cross-origin
# 102563  strict-origin-when-cross-origin
# 102564  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 7780                   [('lang=en_us&referrerPageUrl=',)]  url_leaks
# 7804    [('urlencode', 'base64', 'store.netgear.com'),...  url_leaks
# 7806    [('urlencode', '/home/'), ('urlencode', 'lang=...  url_leaks
# 7807    [('urlencode', '/home/'), ('urlencode', 'lang=...  url_leaks
# 7809    [('urlencode', '/home/'), ('urlencode', 'lang=...  url_leaks
# ...                                                   ...        ...
# 88678   [('dzen.ru',), ('urlencode', 'dzen.ru'), ('url...  url_leaks
# 93422   [('dzen.ru',), ('urlencode', 'dzen.ru'), ('url...  url_leaks
# 101085  [('businesshelp.snapchat.com',), ('urlencode',...  url_leaks
# 102563  [('www.scorecardresearch.com',), ('urlencode',...  url_leaks
# 102564  [('www.scorecardresearch.com',), ('urlencode',...  url_leaks
#
#                            netloc  \
# 7780
# 7804            store.netgear.com
# 7806            store.netgear.com
# 7807            store.netgear.com
# 7809            store.netgear.com
# ...                           ...
# 88678                     dzen.ru
# 93422                     dzen.ru
# 101085  businesshelp.snapchat.com
# 102563  www.scorecardresearch.com
# 102564  www.scorecardresearch.com
#
#                                                      path  \
# 7780
# 7804                                               /home/
# 7806                                               /home/
# 7807                                               /home/
# 7809                                               /home/
# ...                                                   ...
# 88678   /news/story/vpodmoskove_nashli_telo_ehks-deput...
# 93422   /news/story/vnarodnom_sovete_lnr_podtverdili_g...
# 101085                                                /s/
# 102563                                        /about.aspx
# 102564                                        /about.aspx
#
#                                                     query params fragments  \
# 7780                          lang=en_us&referrerPageUrl=
# 7804                          lang=en_us&referrerPageUrl=
# 7806                          lang=en_us&referrerPageUrl=
# 7807                          lang=en_us&referrerPageUrl=
# 7809                          lang=en_us&referrerPageUrl=
# ...                                                   ...    ...       ...
# 88678   lang=ru&from=main_portal&fan=1&stid=wzlzk1zkik...
# 93422   lang=ru&from=main_portal&fan=1&stid=ppm0ktlu-g...
# 101085                                     language=en_US
# 102563                                      newlanguage=1
# 102564                                      newlanguage=1
#
#         violation
# 7780    Violation
# 7804    Violation
# 7806    Violation
# 7807    Violation
# 7809    Violation
# ...           ...
# 88678   Violation
# 93422   Violation
# 101085  Violation
# 102563  Violation
# 102564  Violation
#
# [149 rows x 13 columns]

# %%
# and print to csv

print_leak_to_csv(url_leaks_vioilation_df)

# %%
url_leaks_vioilation_df.count()
# Out:
# init_url        30658
# final_url       30658
# req_url         30658
# req_method      30658
# ref_pol_data    30658
# url_leaks       30658
# leaks           30658
# netloc          30658
# path            30658
# query           30658
# params          30658
# fragments       30658
# violation       30658
# dtype: int64

# %%
url_leaks_vioilation_df.req_method.value_counts()
# Out:
# GET        25127
# POST        5370
# OPTIONS      140
# HEAD          21
# Name: req_method, dtype: int64

# %%
url_leaks_vioilation_df.drop_duplicates(subset=['final_url'])
# Out:
#                                                  init_url  \
# 1                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 73                            https://xmp.mobvista.com/cn
# 77        https://www.marktplaats.nl/cp/621/kleding-dames
# 94             https://email.nypost.com/israel-war-update
# ...                                                   ...
# 110624  https://www.finn.no/nettbil/velkommen?origin=f...
# 110661  https://www.washington.edu/news/?utm_source=wh...
# 110686  https://www.mcafee.com/en-us/consumer-corporat...
# 110701                          https://actu.fr/politique
# 110745       https://www.docker.com/products/docker-scout
#
#                                                 final_url  \
# 1                           https://www.ox.ac.uk/research
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 73                            https://xmp.mobvista.com/cn
# 77       https://www.marktplaats.nl/cp/621/kleding-dames/
# 94      https://email.nypost.com/israel-war-update/?ut...
# ...                                                   ...
# 110624  https://www.finn.no/nettbil?origin=frontpage_icon
# 110661  https://www.washington.edu/news/?utm_source=wh...
# 110686  https://www.mcafee.com/en-us/consumer-corporat...
# 110701                          https://actu.fr/politique
# 110745      https://www.docker.com/products/docker-scout/
#
#                                                   req_url req_method  \
# 1       https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 56      https://www.google-analytics.com/g/collect?v=2...       POST
# 73      https://magnet.rayjump.com/pixel?campuuid=ss_x...        GET
# 77      https://www.google-analytics.com/j/collect?v=1...       POST
# 94      https://p1.parsely.com/px/?rand=1702099616458&...        GET
# ...                                                   ...        ...
# 110624  https://static.finncdn.no/_c/nettbil-layout/_n...        GET
# 110661  https://www.googletagmanager.com/a?id=GTM-KQ6Q...        GET
# 110686  https://d2v83son8kay5v.cloudfront.net/1x1.gif?...        GET
# 110701  https://trc.taboola.com/actufr-actufr/trc/3/js...        GET
# 110745  https://dev.visualwebsiteoptimizer.com/j.php?a...        GET
#
#                            ref_pol_data  \
# 1       strict-origin-when-cross-origin
# 56                               origin
# 73      strict-origin-when-cross-origin
# 77      strict-origin-when-cross-origin
# 94      strict-origin-when-cross-origin
# ...                                 ...
# 110624  strict-origin-when-cross-origin
# 110661  strict-origin-when-cross-origin
# 110686  strict-origin-when-cross-origin
# 110701  strict-origin-when-cross-origin
# 110745  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 1       [('urlencode', 'www.ox.ac.uk'), ('urlencode', ...  url_leaks
# 56      [('ameblo.jp',), ('urlencode', 'ameblo.jp'), (...  url_leaks
# 73      [('xmp.mobvista.com',), ('urlencode', 'xmp.mob...  url_leaks
# 77      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  url_leaks
# 94      [('urlencode', 'email.nypost.com'), ('urlencod...  url_leaks
# ...                                                   ...        ...
# 110624                                    [('/nettbil',)]  url_leaks
# 110661  [('urlencode', '/news/'), ('www.washington.edu...  url_leaks
# 110686  [('urlencode', 'www.mcafee.com'), ('urlencode'...  url_leaks
# 110701  [('actu.fr',), ('urlencode', 'actu.fr'), ('url...  url_leaks
# 110745  [('urlencode', '/products/docker-scout/'), ('w...  url_leaks
#
#                     netloc                                         path  \
# 1             www.ox.ac.uk                                    /research
# 56               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 73        xmp.mobvista.com                                          /cn
# 77      www.marktplaats.nl                       /cp/621/kleding-dames/
# 94        email.nypost.com                          /israel-war-update/
# ...                    ...                                          ...
# 110624                                                         /nettbil
# 110661  www.washington.edu                                       /news/
# 110686      www.mcafee.com     /en-us/consumer-corporate/investors.html
# 110701             actu.fr                                   /politique
# 110745      www.docker.com                      /products/docker-scout/
#
#                                                     query params fragments  \
# 1
# 56
# 73
# 77
# 94      utm_source=facebook&utm_campaign=nypost&sr_sha...
# ...                                                   ...    ...       ...
# 110624
# 110661
# 110686
# 110701
# 110745
#
#         violation
# 1       Violation
# 56      Violation
# 73      Violation
# 77      Violation
# 94      Violation
# ...           ...
# 110624  Violation
# 110661  Violation
# 110686  Violation
# 110701  Violation
# 110745  Violation
#
# [2093 rows x 13 columns]

# %% [markdown]
# ### GOOGLE

# %%
# count of url leaks to google
url_leaks_vioilation_df[url_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)].count()
# Out:
# init_url        9765
# final_url       9765
# req_url         9765
# req_method      9765
# ref_pol_data    9765
# url_leaks       9765
# leaks           9765
# netloc          9765
# path            9765
# query           9765
# params          9765
# fragments       9765
# violation       9765
# dtype: int64

# %%
# list of url leaks to google
url_leaks_vioilation_df[url_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)]
# Out:
#                                                  init_url  \
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 61      https://ameblo.jp/borderfreecosmetics/entry-12...
# 74                            https://xmp.mobvista.com/cn
# 76                            https://xmp.mobvista.com/cn
# 77        https://www.marktplaats.nl/cp/621/kleding-dames
# ...                                                   ...
# 110828       https://www.docker.com/products/docker-scout
# 110868   https://www.mbga.jp/_game_intro?game_id=12016007
# 110870   https://www.mbga.jp/_game_intro?game_id=12016007
# 110880   https://www.mbga.jp/_game_intro?game_id=12016007
# 110884   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 56      https://ameblo.jp/borderfreecosmetics/entry-12...
# 61      https://ameblo.jp/borderfreecosmetics/entry-12...
# 74                            https://xmp.mobvista.com/cn
# 76                            https://xmp.mobvista.com/cn
# 77       https://www.marktplaats.nl/cp/621/kleding-dames/
# ...                                                   ...
# 110828      https://www.docker.com/products/docker-scout/
# 110868  https://www.andapp.jp/apps/12016007?from=www_m...
# 110870  https://www.andapp.jp/apps/12016007?from=www_m...
# 110880  https://www.andapp.jp/apps/12016007?from=www_m...
# 110884  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 56      https://www.google-analytics.com/g/collect?v=2...       POST
# 61      https://www.google-analytics.com/j/collect?v=1...       POST
# 74      https://www.google-analytics.com/g/collect?v=2...       POST
# 76      https://www.google-analytics.com/g/collect?v=2...       POST
# 77      https://www.google-analytics.com/j/collect?v=1...       POST
# ...                                                   ...        ...
# 110828  https://analytics.google.com/g/collect?v=2&tid...       POST
# 110868  https://www.google-analytics.com/j/collect?v=1...       POST
# 110870  https://www.google-analytics.com/g/collect?v=2...       POST
# 110880  https://googleads.g.doubleclick.net/pagead/vie...        GET
# 110884  https://www.google.com/pagead/1p-user-list/878...        GET
#
#                            ref_pol_data  \
# 56                               origin
# 61                               origin
# 74      strict-origin-when-cross-origin
# 76      strict-origin-when-cross-origin
# 77      strict-origin-when-cross-origin
# ...                                 ...
# 110828  strict-origin-when-cross-origin
# 110868  strict-origin-when-cross-origin
# 110870  strict-origin-when-cross-origin
# 110880  strict-origin-when-cross-origin
# 110884  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 56      [('ameblo.jp',), ('urlencode', 'ameblo.jp'), (...  url_leaks
# 61      [('ameblo.jp',), ('urlencode', 'ameblo.jp'), (...  url_leaks
# 74      [('xmp.mobvista.com',), ('urlencode', 'xmp.mob...  url_leaks
# 76      [('xmp.mobvista.com',), ('urlencode', 'xmp.mob...  url_leaks
# 77      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  url_leaks
# ...                                                   ...        ...
# 110828  [('urlencode', '/products/docker-scout/'), ('w...  url_leaks
# 110868  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110870  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110880  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
# 110884  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
#
#                     netloc                                         path  \
# 56               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 61               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 74        xmp.mobvista.com                                          /cn
# 76        xmp.mobvista.com                                          /cn
# 77      www.marktplaats.nl                       /cp/621/kleding-dames/
# ...                    ...                                          ...
# 110828      www.docker.com                      /products/docker-scout/
# 110868       www.andapp.jp                               /apps/12016007
# 110870       www.andapp.jp                               /apps/12016007
# 110880       www.andapp.jp                               /apps/12016007
# 110884       www.andapp.jp                               /apps/12016007
#
#                       query params fragments  violation
# 56                                            Violation
# 61                                            Violation
# 74                                            Violation
# 76                                            Violation
# 77                                            Violation
# ...                     ...    ...       ...        ...
# 110828                                        Violation
# 110868  from=www_mbga_intro                   Violation
# 110870  from=www_mbga_intro                   Violation
# 110880  from=www_mbga_intro                   Violation
# 110884  from=www_mbga_intro                   Violation
#
# [9765 rows x 13 columns]

# %% [markdown]
# ### Facebook or Meta

# %%
# count of url leaks to Meta or Facebook
url_leaks_vioilation_df[url_leaks_vioilation_df['req_url']
                        .str.contains('meta') 
                        | url_leaks_vioilation_df['req_url']
                            .str.contains('facebook')].count()
# Out:
# init_url        1557
# final_url       1557
# req_url         1557
# req_method      1557
# ref_pol_data    1557
# url_leaks       1557
# leaks           1557
# netloc          1557
# path            1557
# query           1557
# params          1557
# fragments       1557
# violation       1557
# dtype: int64

# %%
# list of url leaks to Meta or Facebook
url_leaks_vioilation_df[
    url_leaks_vioilation_df['req_url']
    .str.contains('meta') 
    | url_leaks_vioilation_df['req_url']
        .str.contains('facebook')]
# Out:
#                                                  init_url  \
# 94             https://email.nypost.com/israel-war-update
# 95             https://email.nypost.com/israel-war-update
# 96             https://email.nypost.com/israel-war-update
# 97             https://email.nypost.com/israel-war-update
# 114     https://stars.udn.com/star/story/10092/7623509...
# ...                                                   ...
# 110703                          https://actu.fr/politique
# 110705                          https://actu.fr/politique
# 110757       https://www.docker.com/products/docker-scout
# 110827       https://www.docker.com/products/docker-scout
# 110879   https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 94      https://email.nypost.com/israel-war-update/?ut...
# 95      https://email.nypost.com/israel-war-update/?ut...
# 96      https://email.nypost.com/israel-war-update/?ut...
# 97      https://email.nypost.com/israel-war-update/?ut...
# 114     https://stars.udn.com/star/story/10092/7623509...
# ...                                                   ...
# 110703                          https://actu.fr/politique
# 110705                          https://actu.fr/politique
# 110757      https://www.docker.com/products/docker-scout/
# 110827      https://www.docker.com/products/docker-scout/
# 110879  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 94      https://p1.parsely.com/px/?rand=1702099616458&...        GET
# 95      https://tr.outbrain.com/unifiedPixel?optOut=fa...       POST
# 96      https://www.google-analytics.com/j/collect?v=1...       POST
# 97      https://www.google-analytics.com/collect?v=1&_...        GET
# 114     https://www.facebook.com/tr/?id=20291620972956...        GET
# ...                                                   ...        ...
# 110703  https://www.facebook.com/tr/?id=18311472367086...        GET
# 110705  https://www.facebook.com/tr/?id=64407153621134...        GET
# 110757  https://www.facebook.com/tr/?id=16466388623210...        GET
# 110827  https://www.facebook.com/tr/?id=16466388623210...        GET
# 110879  https://www.facebook.com/v10.0/plugins/like.ph...        GET
#
#                            ref_pol_data  \
# 94      strict-origin-when-cross-origin
# 95      strict-origin-when-cross-origin
# 96      strict-origin-when-cross-origin
# 97      strict-origin-when-cross-origin
# 114     strict-origin-when-cross-origin
# ...                                 ...
# 110703  strict-origin-when-cross-origin
# 110705  strict-origin-when-cross-origin
# 110757  strict-origin-when-cross-origin
# 110827  strict-origin-when-cross-origin
# 110879  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 94      [('urlencode', 'email.nypost.com'), ('urlencod...  url_leaks
# 95      [('urlencode', 'email.nypost.com'), ('urlencod...  url_leaks
# 96      [('urlencode', 'email.nypost.com'), ('urlencod...  url_leaks
# 97      [('urlencode', 'email.nypost.com'), ('urlencod...  url_leaks
# 114     [('stars.udn.com',), ('urlencode', 'stars.udn....  url_leaks
# ...                                                   ...        ...
# 110703  [('actu.fr',), ('urlencode', 'actu.fr'), ('url...  url_leaks
# 110705  [('actu.fr',), ('urlencode', 'actu.fr'), ('url...  url_leaks
# 110757  [('urlencode', '/products/docker-scout/'), ('w...  url_leaks
# 110827  [('urlencode', '/products/docker-scout/'), ('w...  url_leaks
# 110879  [('urlencode', 'www.andapp.jp'), ('urlencode',...  url_leaks
#
#                   netloc                       path  \
# 94      email.nypost.com        /israel-war-update/
# 95      email.nypost.com        /israel-war-update/
# 96      email.nypost.com        /israel-war-update/
# 97      email.nypost.com        /israel-war-update/
# 114        stars.udn.com  /star/story/10092/7623509
# ...                  ...                        ...
# 110703           actu.fr                 /politique
# 110705           actu.fr                 /politique
# 110757    www.docker.com    /products/docker-scout/
# 110827    www.docker.com    /products/docker-scout/
# 110879     www.andapp.jp             /apps/12016007
#
#                                                     query params fragments  \
# 94      utm_source=facebook&utm_campaign=nypost&sr_sha...
# 95      utm_source=facebook&utm_campaign=nypost&sr_sha...
# 96      utm_source=facebook&utm_campaign=nypost&sr_sha...
# 97      utm_source=facebook&utm_campaign=nypost&sr_sha...
# 114                                          from=redpush
# ...                                                   ...    ...       ...
# 110703
# 110705
# 110757
# 110827
# 110879
#
#         violation
# 94      Violation
# 95      Violation
# 96      Violation
# 97      Violation
# 114     Violation
# ...           ...
# 110703  Violation
# 110705  Violation
# 110757  Violation
# 110827  Violation
# 110879  Violation
#
# [1557 rows x 13 columns]

# %% [markdown]
# ### Tiktok

# %%
url_leaks_vioilation_df[
    url_leaks_vioilation_df['req_url']
        .str.contains('tiktok').fillna(False)]
# Out:
#                                                  init_url  \
# 4272    https://time.com/6342806/person-of-the-year-20...
# 4295    https://www.adjust.com/resources/ebooks/skadne...
# 4298    https://www.adjust.com/resources/ebooks/skadne...
# 5176    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5178    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5199    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5219    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5400             https://www.nike.com/w/member-sale-9t7gt
# 8361                   https://www.healthline.com/fitness
# 9949     https://www.nike.com/w/classics-collection-aj8oq
# 20724               https://www.nike.com/w/jordan-1-4foky
# 30281   https://www.medicalnewstoday.com/articles/in-c...
# 34083   https://www.medicalnewstoday.com/articles/redu...
# 34154   https://www.medicalnewstoday.com/articles/redu...
# 35970   https://www.medicalnewstoday.com/articles/how-...
# 36571   https://www.medicalnewstoday.com/articles/psor...
# 40582                         https://www.mgid.com/events
# 59252   https://www.healthline.com/health/viral-vs-ver...
# 66459         https://www.statista.com/topics/6077/tiktok
# 66460         https://www.statista.com/topics/6077/tiktok
# 66462         https://www.statista.com/topics/6077/tiktok
# 66463         https://www.statista.com/topics/6077/tiktok
# 66465         https://www.statista.com/topics/6077/tiktok
# 66466         https://www.statista.com/topics/6077/tiktok
# 66468         https://www.statista.com/topics/6077/tiktok
# 66469         https://www.statista.com/topics/6077/tiktok
# 66470         https://www.statista.com/topics/6077/tiktok
# 66471         https://www.statista.com/topics/6077/tiktok
# 66655   https://www.nike.com/w/air-force-1-shoes-5sj3y...
# 72269            https://www.nike.com/w/daily-deals-5ks9w
# 82085   https://www.medicalnewstoday.com/articles/prob...
# 87017                    https://www.healthline.com/sleep
# 90004            https://www.healthline.com/mental-health
# 100642  https://www.healthline.com/health-news/safe-tr...
#
#                                                 final_url  \
# 4272    https://time.com/6342806/person-of-the-year-20...
# 4295    https://www.adjust.com/resources/ebooks/skadne...
# 4298    https://www.adjust.com/resources/ebooks/skadne...
# 5176    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5178    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5199    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5219    https://www.huffpost.com/entry/comfy-shoes-tik...
# 5400             https://www.nike.com/w/member-sale-9t7gt
# 8361                   https://www.healthline.com/fitness
# 9949     https://www.nike.com/w/classics-collection-aj8oq
# 20724               https://www.nike.com/w/jordan-1-4foky
# 30281   https://www.medicalnewstoday.com/articles/in-c...
# 34083   https://www.medicalnewstoday.com/articles/redu...
# 34154   https://www.medicalnewstoday.com/articles/redu...
# 35970   https://www.medicalnewstoday.com/articles/how-...
# 36571   https://www.medicalnewstoday.com/articles/psor...
# 40582                         https://www.mgid.com/events
# 59252   https://www.healthline.com/health/viral-vs-ver...
# 66459   https://www.statista.com/topics/6077/tiktok/#t...
# 66460   https://www.statista.com/topics/6077/tiktok/#t...
# 66462   https://www.statista.com/topics/6077/tiktok/#t...
# 66463   https://www.statista.com/topics/6077/tiktok/#t...
# 66465   https://www.statista.com/topics/6077/tiktok/#t...
# 66466   https://www.statista.com/topics/6077/tiktok/#t...
# 66468   https://www.statista.com/topics/6077/tiktok/#t...
# 66469   https://www.statista.com/topics/6077/tiktok/#t...
# 66470   https://www.statista.com/topics/6077/tiktok/#t...
# 66471   https://www.statista.com/topics/6077/tiktok/#t...
# 66655   https://www.nike.com/w/air-force-1-shoes-5sj3y...
# 72269            https://www.nike.com/w/daily-deals-5ks9w
# 82085   https://www.medicalnewstoday.com/articles/prob...
# 87017                    https://www.healthline.com/sleep
# 90004            https://www.healthline.com/mental-health
# 100642  https://www.healthline.com/health-news/safe-tr...
#
#                                                   req_url req_method  \
# 4272    https://securepubads.g.doubleclick.net/gampad/...        GET
# 4295    https://pi.pardot.com/analytics?ver=3&pi_form=...        GET
# 4298    https://pi.pardot.com/analytics?ver=3&pi_form=...        GET
# 5176    https://widgets.outbrain.com/widgetMonitor/mon...        GET
# 5178    https://widgetmonitor.outbrain.com/WidgetError...        GET
# 5199    https://widgetmonitor.outbrain.com/WidgetError...        GET
# 5219    https://ssum-sec.casalemedia.com/usermatch?us_...        GET
# 5400    https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 8361    https://www.google-analytics.com/j/collect?v=1...       POST
# 9949    https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 20724   https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 30281   https://www.google-analytics.com/j/collect?v=1...       POST
# 34083   https://www.google-analytics.com/j/collect?v=1...       POST
# 34154   https://www.google-analytics.com/collect?v=1&_...        GET
# 35970   https://www.google-analytics.com/j/collect?v=1...       POST
# 36571   https://www.google-analytics.com/j/collect?v=1...       POST
# 40582   https://analytics.tiktok.com/i18n/pixel/events...        GET
# 59252   https://www.google-analytics.com/j/collect?v=1...       POST
# 66459   https://t.co/i/adsct?bci=3&eci=2&event_id=6046...        GET
# 66460   https://analytics.twitter.com/i/adsct?bci=3&ec...        GET
# 66462   https://bat.bing.com/action/0?ti=343033979&tm=...        GET
# 66463   https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 66465   https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 66466   https://www.facebook.com/tr/?id=10246364033656...        GET
# 66468   https://securepubads.g.doubleclick.net/gampad/...        GET
# 66469   https://px.ads.linkedin.com/collect?v=2&fmt=js...        GET
# 66470   https://googleads.g.doubleclick.net/pagead/vie...        GET
# 66471   https://www.google.com/pagead/1p-user-list/997...        GET
# 66655   https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 72269   https://newrelicstream.adtech-prod.nikecloud.c...        GET
# 82085   https://www.google-analytics.com/j/collect?v=1...       POST
# 87017   https://www.google-analytics.com/j/collect?v=1...       POST
# 90004   https://www.google-analytics.com/j/collect?v=1...       POST
# 100642  https://www.google-analytics.com/j/collect?v=1...       POST
#
#                            ref_pol_data  \
# 4272    strict-origin-when-cross-origin
# 4295    strict-origin-when-cross-origin
# 4298    strict-origin-when-cross-origin
# 5176    strict-origin-when-cross-origin
# 5178    strict-origin-when-cross-origin
# 5199    strict-origin-when-cross-origin
# 5219    strict-origin-when-cross-origin
# 5400    strict-origin-when-cross-origin
# 8361    strict-origin-when-cross-origin
# 9949    strict-origin-when-cross-origin
# 20724   strict-origin-when-cross-origin
# 30281   strict-origin-when-cross-origin
# 34083   strict-origin-when-cross-origin
# 34154   strict-origin-when-cross-origin
# 35970   strict-origin-when-cross-origin
# 36571   strict-origin-when-cross-origin
# 40582   strict-origin-when-cross-origin
# 59252   strict-origin-when-cross-origin
# 66459   strict-origin-when-cross-origin
# 66460   strict-origin-when-cross-origin
# 66462   strict-origin-when-cross-origin
# 66463   strict-origin-when-cross-origin
# 66465   strict-origin-when-cross-origin
# 66466   strict-origin-when-cross-origin
# 66468   strict-origin-when-cross-origin
# 66469   strict-origin-when-cross-origin
# 66470   strict-origin-when-cross-origin
# 66471   strict-origin-when-cross-origin
# 66655   strict-origin-when-cross-origin
# 72269   strict-origin-when-cross-origin
# 82085   strict-origin-when-cross-origin
# 87017   strict-origin-when-cross-origin
# 90004   strict-origin-when-cross-origin
# 100642  strict-origin-when-cross-origin
#
#                                                 url_leaks      leaks  \
# 4272    [('urlencode', '/6342806/person-of-the-year-20...  url_leaks
# 4295    [('urlencode', '/resources/ebooks/skadnetwork-...  url_leaks
# 4298    [('urlencode', '/resources/ebooks/skadnetwork-...  url_leaks
# 5176    [('www.huffpost.com',), ('urlencode', 'www.huf...  url_leaks
# 5178    [('www.huffpost.com',), ('urlencode', 'www.huf...  url_leaks
# 5199    [('www.huffpost.com',), ('urlencode', 'www.huf...  url_leaks
# 5219    [('www.huffpost.com',), ('urlencode', 'www.huf...  url_leaks
# 5400    [('/w/member-sale-9t7gt',), ('www.nike.com',),...  url_leaks
# 8361    [('urlencode', '/fitness'), ('www.healthline.c...  url_leaks
# 9949    [('urlencode', '/w/classics-collection-aj8oq')...  url_leaks
# 20724   [('/w/jordan-1-4foky',), ('www.nike.com',), ('...  url_leaks
# 30281   [('urlencode', '/articles/in-conversation-why-...  url_leaks
# 34083   [('www.medicalnewstoday.com',), ('urlencode', ...  url_leaks
# 34154   [('www.medicalnewstoday.com',), ('urlencode', ...  url_leaks
# 35970   [('www.medicalnewstoday.com',), ('urlencode', ...  url_leaks
# 36571   [('www.medicalnewstoday.com',), ('urlencode', ...  url_leaks
# 40582                                      [('/events',)]  url_leaks
# 59252   [('urlencode', '/health/viral-vs-verified-quiz...  url_leaks
# 66459   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66460   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66462   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66463   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66465   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66466   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66468   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66469   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66470   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66471   [('urlencode', '/topics/6077/tiktok/'), ('www....  url_leaks
# 66655   [('urlencode', '/w/air-force-1-shoes-5sj3yzy7o...  url_leaks
# 72269   [('/w/daily-deals-5ks9w',), ('www.nike.com',),...  url_leaks
# 82085   [('www.medicalnewstoday.com',), ('urlencode', ...  url_leaks
# 87017   [('urlencode', '/sleep'), ('www.healthline.com...  url_leaks
# 90004   [('urlencode', '/mental-health'), ('www.health...  url_leaks
# 100642  [('www.healthline.com',), ('urlencode', 'www.h...  url_leaks
#
#                           netloc  \
# 4272                    time.com
# 4295              www.adjust.com
# 4298              www.adjust.com
# 5176            www.huffpost.com
# 5178            www.huffpost.com
# 5199            www.huffpost.com
# 5219            www.huffpost.com
# 5400                www.nike.com
# 8361          www.healthline.com
# 9949                www.nike.com
# 20724               www.nike.com
# 30281   www.medicalnewstoday.com
# 34083   www.medicalnewstoday.com
# 34154   www.medicalnewstoday.com
# 35970   www.medicalnewstoday.com
# 36571   www.medicalnewstoday.com
# 40582
# 59252         www.healthline.com
# 66459           www.statista.com
# 66460           www.statista.com
# 66462           www.statista.com
# 66463           www.statista.com
# 66465           www.statista.com
# 66466           www.statista.com
# 66468           www.statista.com
# 66469           www.statista.com
# 66470           www.statista.com
# 66471           www.statista.com
# 66655               www.nike.com
# 72269               www.nike.com
# 82085   www.medicalnewstoday.com
# 87017         www.healthline.com
# 90004         www.healthline.com
# 100642        www.healthline.com
#
#                                                      path query params  \
# 4272       /6342806/person-of-the-year-2023-taylor-swift/
# 4295                 /resources/ebooks/skadnetwork-4-ios/
# 4298                 /resources/ebooks/skadnetwork-4-ios/
# 5176    /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 5178    /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 5199    /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 5219    /entry/comfy-shoes-tiktok-ano_l_6567b611e4b066...
# 5400                                 /w/member-sale-9t7gt
# 8361                                             /fitness
# 9949                         /w/classics-collection-aj8oq
# 20724                                   /w/jordan-1-4foky
# 30281   /articles/in-conversation-why-exercise-is-key-...
# 34083   /articles/reduction-in-hippocampus-in-brain-li...
# 34154   /articles/reduction-in-hippocampus-in-brain-li...
# 35970   /articles/how-accurate-are-the-claims-about-as...
# 36571        /articles/psoriasis-and-chronic-inflammation
# 40582                                             /events
# 59252   /health/viral-vs-verified-quiz-debunking-cold-...
# 66459                                /topics/6077/tiktok/
# 66460                                /topics/6077/tiktok/
# 66462                                /topics/6077/tiktok/
# 66463                                /topics/6077/tiktok/
# 66465                                /topics/6077/tiktok/
# 66466                                /topics/6077/tiktok/
# 66468                                /topics/6077/tiktok/
# 66469                                /topics/6077/tiktok/
# 66470                                /topics/6077/tiktok/
# 66471                                /topics/6077/tiktok/
# 66655                     /w/air-force-1-shoes-5sj3yzy7ok
# 72269                                /w/daily-deals-5ks9w
# 82085   /articles/probiotic-bacteria-lactobacillus-yog...
# 87017                                              /sleep
# 90004                                      /mental-health
# 100642  /health-news/safe-travel-tips-people-with-medi...
#
#        fragments  violation
# 4272              Violation
# 4295              Violation
# 4298              Violation
# 5176              Violation
# 5178              Violation
# 5199              Violation
# 5219              Violation
# 5400              Violation
# 8361              Violation
# 9949              Violation
# 20724             Violation
# 30281             Violation
# 34083             Violation
# 34154             Violation
# 35970             Violation
# 36571             Violation
# 40582             Violation
# 59252             Violation
# 66459             Violation
# 66460             Violation
# 66462             Violation
# 66463             Violation
# 66465             Violation
# 66466             Violation
# 66468             Violation
# 66469             Violation
# 66470             Violation
# 66471             Violation
# 66655             Violation
# 72269             Violation
# 82085             Violation
# 87017             Violation
# 90004             Violation
# 100642            Violation

# %% [markdown]
# ## Leaks on Post Data

# %%
# create a new dataframe with non-empty 'post_leaks' column
post_leaks_df = drop_non_leak(extracted_df, 'post_leaks')
post_leaks_df
# Out:
#                                                 init_url  \
# 5                          https://www.ox.ac.uk/research
# 7                          https://www.ox.ac.uk/research
# 8                          https://www.ox.ac.uk/research
# 13                         https://www.ox.ac.uk/research
# 15                         https://www.ox.ac.uk/research
# ...                                                  ...
# 110830                           https://shop.wired.com/
# 110838                           https://shop.wired.com/
# 110844                           https://shop.wired.com/
# 110885  https://www.mbga.jp/_game_intro?game_id=12016007
# 110887  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 5                           https://www.ox.ac.uk/research
# 7                           https://www.ox.ac.uk/research
# 8                           https://www.ox.ac.uk/research
# 13                          https://www.ox.ac.uk/research
# 15                          https://www.ox.ac.uk/research
# ...                                                   ...
# 110830                            https://shop.wired.com/
# 110838                            https://shop.wired.com/
# 110844                            https://shop.wired.com/
# 110885  https://www.andapp.jp/apps/12016007?from=www_m...
# 110887  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 5       https://www.youtube.com/youtubei/v1/player?key...       POST
# 7       https://www.youtube.com/youtubei/v1/player?key...       POST
# 8       https://www.youtube.com/youtubei/v1/next?key=A...       POST
# 13      https://www.youtube.com/youtubei/v1/log_event?...       POST
# 15      https://www.youtube.com/youtubei/v1/log_event?...       POST
# ...                                                   ...        ...
# 110830    https://monorail-edge.shopifysvc.com/v1/produce       POST
# 110838                https://events.privy.com/v2/collect       POST
# 110844                     https://a.ad.gt/api/v1/collect       POST
# 110885  https://www.youtube.com/youtubei/v1/log_event?...       POST
# 110887                https://id5-sync.com/g/v2/1270.json       POST
#
#                            ref_pol_data  \
# 5       strict-origin-when-cross-origin
# 7       strict-origin-when-cross-origin
# 8       strict-origin-when-cross-origin
# 13      strict-origin-when-cross-origin
# 15      strict-origin-when-cross-origin
# ...                                 ...
# 110830  strict-origin-when-cross-origin
# 110838  strict-origin-when-cross-origin
# 110844  strict-origin-when-cross-origin
# 110885  strict-origin-when-cross-origin
# 110887  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 5       {"videoId":"MJNz9_M3kFg","context":{"client":{...
# 7       {"videoId":"ogkc1FmfiuI","context":{"client":{...
# 8       {"context":{"client":{"hl":"en","gl":"US","rem...
# 13      {"context":{"client":{"hl":"en","gl":"US","cli...
# 15      {"context":{"client":{"hl":"en","gl":"US","cli...
# ...                                                   ...
# 110830  {"schema_id":"online_store_media_video_created...
# 110838  {"event":"new-session","properties":{"referrin...
# 110844  eyJjYXRlZ29yeSI6InBhZ2VWaWV3IiwidmVyc2lvbiI6In...
# 110885  {"context":{"client":{"hl":"en","gl":"US","cli...
# 110887  {"partner":1270,"v":"1.0.36","o":"api","tml":"...
#
#                                                post_leaks  \
# 5       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 7       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 8       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 13                                    [('www.ox.ac.uk',)]
# 15                                    [('www.ox.ac.uk',)]
# ...                                                   ...
# 110830                              [('shop.wired.com',)]
# 110838                              [('shop.wired.com',)]
# 110844                     [('base64', 'shop.wired.com')]
# 110885                               [('www.andapp.jp',)]
# 110887                               [('www.andapp.jp',)]
#
#                              leaks
# 5                       post_leaks
# 7                       post_leaks
# 8                       post_leaks
# 13                      post_leaks
# 15                      post_leaks
# ...                            ...
# 110830                  post_leaks
# 110838                  post_leaks
# 110844                  post_leaks
# 110885  post_leaks - referer_leaks
# 110887                  post_leaks
#
# [16364 rows x 8 columns]

# %%
# expand the datarame with the result from check_urlparse function and create a new colomn with the result from check_violation function
post_leaks_df[['netloc', 'path', 'query', 'params', 'fragments']] = post_leaks_df.apply(check_urlparse, axis=1, result_type='expand')

post_leaks_df['violation'] = post_leaks_df.apply(check_violation, axis=1, result_type='expand')

post_leaks_df
# Out:
#                                                 init_url  \
# 5                          https://www.ox.ac.uk/research
# 7                          https://www.ox.ac.uk/research
# 8                          https://www.ox.ac.uk/research
# 13                         https://www.ox.ac.uk/research
# 15                         https://www.ox.ac.uk/research
# ...                                                  ...
# 110830                           https://shop.wired.com/
# 110838                           https://shop.wired.com/
# 110844                           https://shop.wired.com/
# 110885  https://www.mbga.jp/_game_intro?game_id=12016007
# 110887  https://www.mbga.jp/_game_intro?game_id=12016007
#
#                                                 final_url  \
# 5                           https://www.ox.ac.uk/research
# 7                           https://www.ox.ac.uk/research
# 8                           https://www.ox.ac.uk/research
# 13                          https://www.ox.ac.uk/research
# 15                          https://www.ox.ac.uk/research
# ...                                                   ...
# 110830                            https://shop.wired.com/
# 110838                            https://shop.wired.com/
# 110844                            https://shop.wired.com/
# 110885  https://www.andapp.jp/apps/12016007?from=www_m...
# 110887  https://www.andapp.jp/apps/12016007?from=www_m...
#
#                                                   req_url req_method  \
# 5       https://www.youtube.com/youtubei/v1/player?key...       POST
# 7       https://www.youtube.com/youtubei/v1/player?key...       POST
# 8       https://www.youtube.com/youtubei/v1/next?key=A...       POST
# 13      https://www.youtube.com/youtubei/v1/log_event?...       POST
# 15      https://www.youtube.com/youtubei/v1/log_event?...       POST
# ...                                                   ...        ...
# 110830    https://monorail-edge.shopifysvc.com/v1/produce       POST
# 110838                https://events.privy.com/v2/collect       POST
# 110844                     https://a.ad.gt/api/v1/collect       POST
# 110885  https://www.youtube.com/youtubei/v1/log_event?...       POST
# 110887                https://id5-sync.com/g/v2/1270.json       POST
#
#                            ref_pol_data  \
# 5       strict-origin-when-cross-origin
# 7       strict-origin-when-cross-origin
# 8       strict-origin-when-cross-origin
# 13      strict-origin-when-cross-origin
# 15      strict-origin-when-cross-origin
# ...                                 ...
# 110830  strict-origin-when-cross-origin
# 110838  strict-origin-when-cross-origin
# 110844  strict-origin-when-cross-origin
# 110885  strict-origin-when-cross-origin
# 110887  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 5       {"videoId":"MJNz9_M3kFg","context":{"client":{...
# 7       {"videoId":"ogkc1FmfiuI","context":{"client":{...
# 8       {"context":{"client":{"hl":"en","gl":"US","rem...
# 13      {"context":{"client":{"hl":"en","gl":"US","cli...
# 15      {"context":{"client":{"hl":"en","gl":"US","cli...
# ...                                                   ...
# 110830  {"schema_id":"online_store_media_video_created...
# 110838  {"event":"new-session","properties":{"referrin...
# 110844  eyJjYXRlZ29yeSI6InBhZ2VWaWV3IiwidmVyc2lvbiI6In...
# 110885  {"context":{"client":{"hl":"en","gl":"US","cli...
# 110887  {"partner":1270,"v":"1.0.36","o":"api","tml":"...
#
#                                                post_leaks  \
# 5       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 7       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 8       [('urlencode', 'www.ox.ac.uk'), ('www.ox.ac.uk...
# 13                                    [('www.ox.ac.uk',)]
# 15                                    [('www.ox.ac.uk',)]
# ...                                                   ...
# 110830                              [('shop.wired.com',)]
# 110838                              [('shop.wired.com',)]
# 110844                     [('base64', 'shop.wired.com')]
# 110885                               [('www.andapp.jp',)]
# 110887                               [('www.andapp.jp',)]
#
#                              leaks          netloc path query params  \
# 5                       post_leaks    www.ox.ac.uk
# 7                       post_leaks    www.ox.ac.uk
# 8                       post_leaks    www.ox.ac.uk
# 13                      post_leaks    www.ox.ac.uk
# 15                      post_leaks    www.ox.ac.uk
# ...                            ...             ...  ...   ...    ...
# 110830                  post_leaks  shop.wired.com
# 110838                  post_leaks  shop.wired.com
# 110844                  post_leaks  shop.wired.com
# 110885  post_leaks - referer_leaks   www.andapp.jp
# 110887                  post_leaks   www.andapp.jp
#
#        fragments violation
# 5                     Safe
# 7                     Safe
# 8                     Safe
# 13                    Safe
# 15                    Safe
# ...          ...       ...
# 110830                Safe
# 110838                Safe
# 110844                Safe
# 110885                Safe
# 110887                Safe
#
# [16364 rows x 14 columns]

# %%
# Check wheter the params or fragments leak on post
post_leaks_df[post_leaks_df['violation'] == "Warning"]
# Out:
# Empty DataFrame
# Columns: [init_url, final_url, req_url, req_method, ref_pol_data, post_data, post_leaks, leaks, netloc, path, query, params, fragments, violation]
# Index: []

# %%
post_leaks_vioilation_df = post_leaks_df[post_leaks_df['violation'] == "Violation"]
post_leaks_vioilation_df
# Out:
#                                                  init_url  \
# 16                          https://www.ox.ac.uk/research
# 62      https://ameblo.jp/borderfreecosmetics/entry-12...
# 78        https://www.marktplaats.nl/cp/621/kleding-dames
# 81        https://www.marktplaats.nl/cp/621/kleding-dames
# 82        https://www.marktplaats.nl/cp/621/kleding-dames
# ...                                                   ...
# 110815       https://www.docker.com/products/docker-scout
# 110817       https://www.docker.com/products/docker-scout
# 110819       https://www.docker.com/products/docker-scout
# 110820       https://www.docker.com/products/docker-scout
# 110821       https://www.docker.com/products/docker-scout
#
#                                                 final_url  \
# 16                          https://www.ox.ac.uk/research
# 62      https://ameblo.jp/borderfreecosmetics/entry-12...
# 78       https://www.marktplaats.nl/cp/621/kleding-dames/
# 81       https://www.marktplaats.nl/cp/621/kleding-dames/
# 82       https://www.marktplaats.nl/cp/621/kleding-dames/
# ...                                                   ...
# 110815      https://www.docker.com/products/docker-scout/
# 110817      https://www.docker.com/products/docker-scout/
# 110819      https://www.docker.com/products/docker-scout/
# 110820      https://www.docker.com/products/docker-scout/
# 110821      https://www.docker.com/products/docker-scout/
#
#                                                   req_url req_method  \
# 16                        https://px.ads.linkedin.com/wa/       POST
# 62                             https://id5-sync.com/gm/v3       POST
# 78      https://htlb.casalemedia.com/openrtb/pbjs?s=23...       POST
# 81      https://pre.ads.justpremium.com/v/2.0/t/xhr?i=...       POST
# 82               https://ib.adnxs-simple.com/ut/v3/prebid       POST
# ...                                                   ...        ...
# 110815  https://bootstrap.api.drift.com/widget_bootstr...       POST
# 110817   https://bootstrap.api.drift.com/widget_bootstrap       POST
# 110819                  https://event.api.drift.com/track       POST
# 110820  https://targeting.api.drift.com/targeting/eval...       POST
# 110821  https://flow.api.drift.com/flows/render_initia...       POST
#
#                            ref_pol_data  \
# 16      strict-origin-when-cross-origin
# 62                               origin
# 78      strict-origin-when-cross-origin
# 81      strict-origin-when-cross-origin
# 82      strict-origin-when-cross-origin
# ...                                 ...
# 110815  strict-origin-when-cross-origin
# 110817  strict-origin-when-cross-origin
# 110819  strict-origin-when-cross-origin
# 110820  strict-origin-when-cross-origin
# 110821  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 16      {"pids":[9293],"scriptVersion":1029,"time":170...
# 62      {"requests":[{"requestId":"39a51fe1-6803-467a-...
# 78      {"id":"17daa0cecd9fec","site":{"page":"https:/...
# 81      {"zone":[148381],"referer":"https://www.marktp...
# 82      {"tags":[{"sizes":[{"width":728,"height":90},{...
# ...                                                   ...
# 110815  ping_context=%7B%22embedId%22%3A%22p4d2wxp9n4g...
# 110817  embed_id=p4d2wxp9n4gk&client_id=f6zuizdyhxrm7r...
# 110819  {"orgId":5090900,"inboxId":732344,"userId":nul...
# 110820  {"conditionGroups":[{"status":"EVALUATED","mat...
# 110821  {"playbookId":2710693,"campaignId":2807427,"in...
#
#                                                post_leaks       leaks  \
# 16                                       [('/research',)]  post_leaks
# 62      [('ameblo.jp',), ('/borderfreecosmetics/entry-...  post_leaks
# 78      [('www.marktplaats.nl',), ('/cp/621/kleding-da...  post_leaks
# 81      [('www.marktplaats.nl',), ('/cp/621/kleding-da...  post_leaks
# 82      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# ...                                                   ...         ...
# 110815  [('urlencode', '/products/docker-scout/'), ('w...  post_leaks
# 110817  [('urlencode', '/products/docker-scout/'), ('w...  post_leaks
# 110819  [('/products/docker-scout/',), ('www.docker.co...  post_leaks
# 110820  [('/products/docker-scout/',), ('www.docker.co...  post_leaks
# 110821  [('/products/docker-scout/',), ('www.docker.co...  post_leaks
#
#                     netloc                                         path query  \
# 16                                                            /research
# 62               ameblo.jp  /borderfreecosmetics/entry-12761950217.html
# 78      www.marktplaats.nl                       /cp/621/kleding-dames/
# 81      www.marktplaats.nl                       /cp/621/kleding-dames/
# 82      www.marktplaats.nl                       /cp/621/kleding-dames/
# ...                    ...                                          ...   ...
# 110815      www.docker.com                      /products/docker-scout/
# 110817      www.docker.com                      /products/docker-scout/
# 110819      www.docker.com                      /products/docker-scout/
# 110820      www.docker.com                      /products/docker-scout/
# 110821      www.docker.com                      /products/docker-scout/
#
#        params fragments  violation
# 16                       Violation
# 62                       Violation
# 78                       Violation
# 81                       Violation
# 82                       Violation
# ...       ...       ...        ...
# 110815                   Violation
# 110817                   Violation
# 110819                   Violation
# 110820                   Violation
# 110821                   Violation
#
# [9843 rows x 14 columns]

# %%
# print to csv

post_leaks_vioilation_df['post_data'] = [str(x)[:2048] for x in post_leaks_vioilation_df['post_data']] # convert to string and truncate post_data to 2048 characters
print_leak_to_csv(post_leaks_vioilation_df)

# %%
post_leaks_vioilation_df.count()
# Out:
# init_url        9843
# final_url       9843
# req_url         9843
# req_method      9843
# ref_pol_data    9843
# post_data       9843
# post_leaks      9843
# leaks           9843
# netloc          9843
# path            9843
# query           9843
# params          9843
# fragments       9843
# violation       9843
# dtype: int64

# %%
post_leaks_vioilation_df.req_method.value_counts()
# Out:
# POST    9841
# PUT        2
# Name: req_method, dtype: int64

# %% [markdown]
# ### Leaks to Google, facebook, and Meta

# %%
# list of post data leaks to google
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)]
# Out:
#                                                  init_url  \
# 84        https://www.marktplaats.nl/cp/621/kleding-dames
# 85        https://www.marktplaats.nl/cp/621/kleding-dames
# 86        https://www.marktplaats.nl/cp/621/kleding-dames
# 88        https://www.marktplaats.nl/cp/621/kleding-dames
# 89        https://www.marktplaats.nl/cp/621/kleding-dames
# ...                                                   ...
# 107625  https://www.hurriyet.com.tr/ekonomi/borsa-ista...
# 108676  https://www.gismeteo.ru/weather-hayward-execut...
# 109393  https://wordpress.com/start/?ref=logged-out-ho...
# 110154                    https://www.weebly.com/websites
# 110158                    https://www.weebly.com/websites
#
#                                                 final_url  \
# 84       https://www.marktplaats.nl/cp/621/kleding-dames/
# 85       https://www.marktplaats.nl/cp/621/kleding-dames/
# 86       https://www.marktplaats.nl/cp/621/kleding-dames/
# 88       https://www.marktplaats.nl/cp/621/kleding-dames/
# 89       https://www.marktplaats.nl/cp/621/kleding-dames/
# ...                                                   ...
# 107625  https://www.hurriyet.com.tr/ekonomi/borsa-ista...
# 108676  https://www.gismeteo.ru/weather-hayward-execut...
# 109393  https://wordpress.com/start/user-social?ref=lo...
# 110154                    https://www.weebly.com/websites
# 110158                    https://www.weebly.com/websites
#
#                                          req_url req_method  \
# 84      https://www.google-analytics.com/collect       POST
# 85      https://www.google-analytics.com/collect       POST
# 86      https://www.google-analytics.com/collect       POST
# 88      https://www.google-analytics.com/collect       POST
# 89      https://www.google-analytics.com/collect       POST
# ...                                          ...        ...
# 107625  https://www.google-analytics.com/collect       POST
# 108676  https://www.google-analytics.com/collect       POST
# 109393  https://www.google-analytics.com/collect       POST
# 110154  https://www.google-analytics.com/collect       POST
# 110158  https://www.google-analytics.com/collect       POST
#
#                            ref_pol_data  \
# 84      strict-origin-when-cross-origin
# 85      strict-origin-when-cross-origin
# 86      strict-origin-when-cross-origin
# 88      strict-origin-when-cross-origin
# 89      strict-origin-when-cross-origin
# ...                                 ...
# 107625  strict-origin-when-cross-origin
# 108676  strict-origin-when-cross-origin
# 109393                           origin
# 110154  strict-origin-when-cross-origin
# 110158  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 84      v=1&_v=j101&a=2133699423&t=event&_s=2&dl=https...
# 85      v=1&_v=j101&a=2133699423&t=event&_s=3&dl=https...
# 86      v=1&_v=j101&a=2133699423&t=event&_s=4&dl=https...
# 88      v=1&_v=j101&a=2133699423&t=event&_s=5&dl=https...
# 89      v=1&_v=j101&a=2133699423&t=event&_s=6&dl=https...
# ...                                                   ...
# 107625  v=1&_v=j101&a=1722949931&t=event&ni=1&_s=1&dl=...
# 108676  v=1&_v=j101&aip=0&a=147209700&t=timing&ds=desk...
# 109393  v=1&_v=j101&aip=1&a=408908049&t=pageview&_s=2&...
# 110154  v=1&_v=j101&a=1578457713&t=pageview&_s=1&dl=ht...
# 110158  v=1&_v=j101&a=1578457713&t=event&ni=0&_s=1&dl=...
#
#                                                post_leaks       leaks  \
# 84      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 85      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 86      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 88      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# 89      [('urlencode', '/cp/621/kleding-dames/'), ('ww...  post_leaks
# ...                                                   ...         ...
# 107625  [('urlencode', '/ekonomi/borsa-istanbulda-seyi...  post_leaks
# 108676  [('www.gismeteo.ru',), ('urlencode', '/weather...  post_leaks
# 109393  [('urlencode', '/start/user-social'), ('urlenc...  post_leaks
# 110154  [('urlencode', '/websites'), ('www.weebly.com',)]  post_leaks
# 110158  [('urlencode', '/websites'), ('www.weebly.com',)]  post_leaks
#
#                      netloc  \
# 84       www.marktplaats.nl
# 85       www.marktplaats.nl
# 86       www.marktplaats.nl
# 88       www.marktplaats.nl
# 89       www.marktplaats.nl
# ...                     ...
# 107625  www.hurriyet.com.tr
# 108676      www.gismeteo.ru
# 109393        wordpress.com
# 110154       www.weebly.com
# 110158       www.weebly.com
#
#                                                      path  \
# 84                                 /cp/621/kleding-dames/
# 85                                 /cp/621/kleding-dames/
# 86                                 /cp/621/kleding-dames/
# 88                                 /cp/621/kleding-dames/
# 89                                 /cp/621/kleding-dames/
# ...                                                   ...
# 107625  /ekonomi/borsa-istanbulda-seyir-ne-olacak-uzma...
# 108676                  /weather-hayward-executive-28925/
# 109393                                 /start/user-social
# 110154                                          /websites
# 110158                                          /websites
#
#                              query params fragments  violation
# 84                                                   Violation
# 85                                                   Violation
# 86                                                   Violation
# 88                                                   Violation
# 89                                                   Violation
# ...                            ...    ...       ...        ...
# 107625                                               Violation
# 108676                                               Violation
# 109393  ref=logged-out-homepage-lp                   Violation
# 110154                                               Violation
# 110158                                               Violation
#
# [540 rows x 14 columns]

# %%
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('google').fillna(False)].count()
# Out:
# init_url        540
# final_url       540
# req_url         540
# req_method      540
# ref_pol_data    540
# post_data       540
# post_leaks      540
# leaks           540
# netloc          540
# path            540
# query           540
# params          540
# fragments       540
# violation       540
# dtype: int64

# %%
# list of post data leaks to Meta or Facebook
post_leaks_vioilation_df[
    post_leaks_vioilation_df['req_url']
    .str
    .contains('meta') 
    | post_leaks_vioilation_df['req_url']
        .str.contains('facebook')]
# Out:
#                                                  init_url  \
# 1950     https://www.samsung.com/us/watches/galaxy-watch6
# 2819    https://www.oracle.com/cx/advertising/measurem...
# 7812           https://store.netgear.com/home/?lang=en_us
# 9191    https://www.samsung.com/us/mobile/audio/headph...
# 19975   https://www.appsflyer.com/solutions/entertainm...
# 24447                        https://www.pendo.io/pricing
# 24448                        https://www.pendo.io/pricing
# 26350             https://explore.zoom.us/en/ai-assistant
# 27331   https://www.nikkei.com/article/dgxzqoua067j10w...
# 27505   https://www.pendo.io/ai-for-product-management...
# 27506   https://www.pendo.io/ai-for-product-management...
# 28833          https://www.appsflyer.com/solutions/travel
# 29430   https://www.nikkei.com/article/dgxzqogn061ye0w...
# 33924                https://www.aliexpress.us/?a11y=true
# 34773   https://consumer.huawei.com/en/wearables/watch...
# 35184   https://www.appsflyer.com/solutions/health-fit...
# 41504   https://www.index.hr/vijesti/rubrika/komentari...
# 42059   https://www.aliexpress.us/?gatewayadapt=glo2us...
# 44941                   https://www.upwork.com/enterprise
# 47943                             https://zoom.us/pricing
# 48511   https://www.nikkei.com/article/dgxzqouc282yd0y...
# 51966         https://www.netgear.com/home/wifi/mesh/orbi
# 56274   https://www.nikkei.com/article/dgxzqogn0688e0w...
# 57369                          https://www.netgear.com/av
# 64134             https://www.pendo.io/legal/cookiepolicy
# 64135             https://www.pendo.io/legal/cookiepolicy
# 67594                       https://www.pendo.io/startups
# 67595                       https://www.pendo.io/startups
# 71369        https://www.appsflyer.com/products/audiences
# 75615   https://www.index.hr/vijesti/rubrika/crna-kron...
# 106313  https://www.britannica.com/news/625197/c031c2e...
# 106314  https://www.britannica.com/news/625197/c031c2e...
#
#                                                 final_url  \
# 1950    https://www.samsung.com/us/watches/galaxy-watch6/
# 2819    https://www.oracle.com/cx/advertising/measurem...
# 7812    https://store.netgear.com/home/?lang=en_us&ref...
# 9191    https://www.samsung.com/us/mobile/audio/headph...
# 19975   https://www.appsflyer.com/solutions/entertainm...
# 24447                       https://www.pendo.io/pricing/
# 24448                       https://www.pendo.io/pricing/
# 26350               https://www.zoom.com/en/ai-assistant/
# 27331   https://www.nikkei.com/article/dgxzqoua067j10w...
# 27505   https://www.pendo.io/ai-for-product-management...
# 27506   https://www.pendo.io/ai-for-product-management...
# 28833         https://www.appsflyer.com/solutions/travel/
# 29430   https://www.nikkei.com/article/dgxzqogn061ye0w...
# 33924                https://www.aliexpress.us/?a11y=true
# 34773   https://consumer.huawei.com/en/wearables/watch...
# 35184   https://www.appsflyer.com/solutions/health-fit...
# 41504   https://www.index.hr/vijesti/rubrika/komentari...
# 42059   https://www.aliexpress.us/?gatewayadapt=glo2us...
# 44941                   https://www.upwork.com/enterprise
# 47943                             https://zoom.us/pricing
# 48511   https://www.nikkei.com/article/dgxzqouc282yd0y...
# 51966        https://www.netgear.com/home/wifi/mesh/orbi/
# 56274   https://www.nikkei.com/article/dgxzqogn0688e0w...
# 57369                         https://www.netgear.com/av/
# 64134            https://www.pendo.io/legal/cookiepolicy/
# 64135            https://www.pendo.io/legal/cookiepolicy/
# 67594                      https://www.pendo.io/startups/
# 67595                      https://www.pendo.io/startups/
# 71369       https://www.appsflyer.com/products/audiences/
# 75615   https://www.index.hr/vijesti/rubrika/crna-kron...
# 106313  https://www.britannica.com/news/625197/c031c2e...
# 106314  https://www.britannica.com/news/625197/c031c2e...
#
#                                                   req_url req_method  \
# 1950                         https://www.facebook.com/tr/       POST
# 2819                         https://www.facebook.com/tr/       POST
# 7812                         https://www.facebook.com/tr/       POST
# 9191                         https://www.facebook.com/tr/       POST
# 19975                  https://api-gw.metadata.io/traffic       POST
# 24447                  https://api-gw.metadata.io/traffic       POST
# 24448                  https://api-gw.metadata.io/traffic       POST
# 26350                  https://api-gw.metadata.io/traffic       POST
# 27331                        https://www.facebook.com/tr/       POST
# 27505                  https://api-gw.metadata.io/traffic       POST
# 27506                  https://api-gw.metadata.io/traffic       POST
# 28833                  https://api-gw.metadata.io/traffic       POST
# 29430                        https://www.facebook.com/tr/       POST
# 33924                        https://www.facebook.com/tr/       POST
# 34773                        https://www.facebook.com/tr/       POST
# 35184                  https://api-gw.metadata.io/traffic       POST
# 41504   https://www.facebook.com/platform/plugin/page/...       POST
# 42059                        https://www.facebook.com/tr/       POST
# 44941                        https://www.facebook.com/tr/       POST
# 47943                  https://api-gw.metadata.io/traffic       POST
# 48511                        https://www.facebook.com/tr/       POST
# 51966                        https://www.facebook.com/tr/       POST
# 56274                        https://www.facebook.com/tr/       POST
# 57369                        https://www.facebook.com/tr/       POST
# 64134                  https://api-gw.metadata.io/traffic       POST
# 64135                  https://api-gw.metadata.io/traffic       POST
# 67594                  https://api-gw.metadata.io/traffic       POST
# 67595                  https://api-gw.metadata.io/traffic       POST
# 71369                  https://api-gw.metadata.io/traffic       POST
# 75615   https://www.facebook.com/platform/plugin/page/...       POST
# 106313                      https://api.assertcom.de/meta       POST
# 106314                      https://api.assertcom.de/meta       POST
#
#                            ref_pol_data  \
# 1950    strict-origin-when-cross-origin
# 2819    strict-origin-when-cross-origin
# 7812    strict-origin-when-cross-origin
# 9191    strict-origin-when-cross-origin
# 19975   strict-origin-when-cross-origin
# 24447   strict-origin-when-cross-origin
# 24448   strict-origin-when-cross-origin
# 26350          origin-when-cross-origin
# 27331   strict-origin-when-cross-origin
# 27505   strict-origin-when-cross-origin
# 27506   strict-origin-when-cross-origin
# 28833   strict-origin-when-cross-origin
# 29430   strict-origin-when-cross-origin
# 33924   strict-origin-when-cross-origin
# 34773   strict-origin-when-cross-origin
# 35184   strict-origin-when-cross-origin
# 41504          origin-when-cross-origin
# 42059   strict-origin-when-cross-origin
# 44941   strict-origin-when-cross-origin
# 47943          origin-when-cross-origin
# 48511   strict-origin-when-cross-origin
# 51966   strict-origin-when-cross-origin
# 56274   strict-origin-when-cross-origin
# 57369   strict-origin-when-cross-origin
# 64134   strict-origin-when-cross-origin
# 64135   strict-origin-when-cross-origin
# 67594   strict-origin-when-cross-origin
# 67595   strict-origin-when-cross-origin
# 71369   strict-origin-when-cross-origin
# 75615          origin-when-cross-origin
# 106313  strict-origin-when-cross-origin
# 106314  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 1950    id=1049256285582240&ev=Microdata&dl=https%3A%2...
# 2819    id=704367189971874&ev=PageView&dl=https%3A%2F%...
# 7812    id=431542533712561&ev=Microdata&dl=https%3A%2F...
# 9191    id=1049256285582240&ev=Microdata&dl=https%3A%2...
# 19975   {"url":"https://www.appsflyer.com/solutions/en...
# 24447   {"url":"https://www.pendo.io/pricing/","url_re...
# 24448   {"url":"https://www.pendo.io/pricing/","url_re...
# 26350   {"url":"https://www.zoom.com/en/ai-assistant/"...
# 27331   id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 27505   {"url":"https://www.pendo.io/ai-for-product-ma...
# 27506   {"url":"https://www.pendo.io/ai-for-product-ma...
# 28833   {"url":"https://www.appsflyer.com/solutions/tr...
# 29430   id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 33924   id=1650958108523345&ev=Microdata&dl=https%3A%2...
# 34773   id=594019051559898&ev=Microdata&dl=https%3A%2F...
# 35184   {"url":"https://www.appsflyer.com/solutions/he...
# 41504   event_name=page_plugin.tab.configured&page_id=...
# 42059   id=1650958108523345&ev=Microdata&dl=https%3A%2...
# 44941   id=816554411748126&ev=Microdata&dl=https%3A%2F...
# 47943   {"url":"https://zoom.us/pricing","url_referrer...
# 48511   id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 51966   id=431542533712561&ev=Microdata&dl=https%3A%2F...
# 56274   id=517132292271830&ev=Microdata&dl=https%3A%2F...
# 57369   id=431542533712561&ev=Microdata&dl=https%3A%2F...
# 64134   {"url":"https://www.pendo.io/legal/cookiepolic...
# 64135   {"url":"https://www.pendo.io/legal/cookiepolic...
# 67594   {"url":"https://www.pendo.io/startups/","url_r...
# 67595   {"url":"https://www.pendo.io/startups/","url_r...
# 71369   {"url":"https://www.appsflyer.com/products/aud...
# 75615   event_name=page_plugin.tab.configured&page_id=...
# 106313                                                  |
# 106314                                                  |
#
#                                                post_leaks  \
# 1950    [('www.samsung.com',), ('urlencode', '/us/watc...
# 2819    [('urlencode', 'urlencode', '/cx/advertising/m...
# 7812    [('urlencode', 'lang=en_us&referrerPageUrl='),...
# 9191    [('www.samsung.com',), ('urlencode', '/us/mobi...
# 19975   [('/solutions/entertainment-music/',), ('www.a...
# 24447                 [('www.pendo.io',), ('/pricing/',)]
# 24448                 [('www.pendo.io',), ('/pricing/',)]
# 26350         [('www.zoom.com',), ('/en/ai-assistant/',)]
# 27331   [('urlencode', '/article/dgxzqoua067j10w3a201c...
# 27505   [('/ai-for-product-management-course/',), ('ww...
# 27506   [('/ai-for-product-management-course/',), ('ww...
# 28833   [('/solutions/travel/',), ('www.appsflyer.com',)]
# 29430   [('urlencode', '/article/dgxzqogn061ye0w3a201c...
# 33924   [('urlencode', 'a11y=true'), ('www.aliexpress....
# 34773   [('urlencode', 'ic_medium=hwdc&ic_source=corp_...
# 35184   [('www.appsflyer.com',), ('/solutions/health-f...
# 41504   [('urlencode', '/vijesti/rubrika/komentari/141...
# 42059   [('urlencode', 'gatewayadapt=glo2usa'), ('www....
# 44941   [('urlencode', '/enterprise'), ('www.upwork.co...
# 47943                       [('/pricing',), ('zoom.us',)]
# 48511   [('urlencode', '/article/dgxzqouc282yd0y3a121c...
# 51966   [('urlencode', '/home/wifi/mesh/orbi/'), ('www...
# 56274   [('urlencode', '/article/dgxzqogn0688e0w3a201c...
# 57369       [('urlencode', '/av/'), ('www.netgear.com',)]
# 64134      [('/legal/cookiepolicy/',), ('www.pendo.io',)]
# 64135      [('/legal/cookiepolicy/',), ('www.pendo.io',)]
# 67594                [('www.pendo.io',), ('/startups/',)]
# 67595                [('www.pendo.io',), ('/startups/',)]
# 71369   [('www.appsflyer.com',), ('/products/audiences...
# 75615   [('urlencode', '/vijesti/rubrika/crna-kronika/...
# 106313  [('/news/625197/c031c2e6264392183503d988d6346e...
# 106314  [('/news/625197/c031c2e6264392183503d988d6346e...
#
#                              leaks               netloc  \
# 1950                    post_leaks      www.samsung.com
# 2819                    post_leaks       www.oracle.com
# 7812                    post_leaks    store.netgear.com
# 9191                    post_leaks      www.samsung.com
# 19975                   post_leaks    www.appsflyer.com
# 24447                   post_leaks         www.pendo.io
# 24448                   post_leaks         www.pendo.io
# 26350                   post_leaks         www.zoom.com
# 27331                   post_leaks       www.nikkei.com
# 27505                   post_leaks         www.pendo.io
# 27506                   post_leaks         www.pendo.io
# 28833                   post_leaks    www.appsflyer.com
# 29430                   post_leaks       www.nikkei.com
# 33924                   post_leaks    www.aliexpress.us
# 34773                   post_leaks  consumer.huawei.com
# 35184                   post_leaks    www.appsflyer.com
# 41504   post_leaks - referer_leaks         www.index.hr
# 42059                   post_leaks    www.aliexpress.us
# 44941                   post_leaks       www.upwork.com
# 47943                   post_leaks              zoom.us
# 48511                   post_leaks       www.nikkei.com
# 51966                   post_leaks      www.netgear.com
# 56274                   post_leaks       www.nikkei.com
# 57369                   post_leaks      www.netgear.com
# 64134                   post_leaks         www.pendo.io
# 64135                   post_leaks         www.pendo.io
# 67594                   post_leaks         www.pendo.io
# 67595                   post_leaks         www.pendo.io
# 71369                   post_leaks    www.appsflyer.com
# 75615   post_leaks - referer_leaks         www.index.hr
# 106313                  post_leaks   www.britannica.com
# 106314                  post_leaks   www.britannica.com
#
#                                                      path  \
# 1950                           /us/watches/galaxy-watch6/
# 2819    /cx/advertising/measurement/publishers-platforms/
# 7812                                               /home/
# 9191    /us/mobile/audio/headphones/galaxy-buds2-pro-b...
# 19975                     /solutions/entertainment-music/
# 24447                                           /pricing/
# 24448                                           /pricing/
# 26350                                   /en/ai-assistant/
# 27331              /article/dgxzqoua067j10w3a201c2000000/
# 27505                  /ai-for-product-management-course/
# 27506                  /ai-for-product-management-course/
# 28833                                  /solutions/travel/
# 29430              /article/dgxzqogn061ye0w3a201c2000000/
# 33924
# 34773                            /en/wearables/watch-gt4/
# 35184                          /solutions/health-fitness/
# 41504                /vijesti/rubrika/komentari/1413.aspx
# 42059
# 44941                                         /enterprise
# 47943                                            /pricing
# 48511              /article/dgxzqouc282yd0y3a121c2000000/
# 51966                               /home/wifi/mesh/orbi/
# 56274              /article/dgxzqogn0688e0w3a201c2000000/
# 57369                                                /av/
# 64134                                /legal/cookiepolicy/
# 64135                                /legal/cookiepolicy/
# 67594                                          /startups/
# 67595                                          /startups/
# 71369                                /products/audiences/
# 75615               /vijesti/rubrika/crna-kronika/46.aspx
# 106313      /news/625197/c031c2e6264392183503d988d6346e8e
# 106314      /news/625197/c031c2e6264392183503d988d6346e8e
#
#                                                  query params fragments  \
# 1950
# 2819
# 7812                       lang=en_us&referrerPageUrl=
# 9191
# 19975
# 24447
# 24448
# 26350
# 27331
# 27505
# 27506
# 28833
# 29430
# 33924                                        a11y=true
# 34773   ic_medium=hwdc&ic_source=corp_banner1_watchgt4
# 35184
# 41504
# 42059                             gatewayadapt=glo2usa
# 44941
# 47943
# 48511
# 51966
# 56274
# 57369
# 64134
# 64135
# 67594
# 67595
# 71369
# 75615
# 106313
# 106314
#
#         violation
# 1950    Violation
# 2819    Violation
# 7812    Violation
# 9191    Violation
# 19975   Violation
# 24447   Violation
# 24448   Violation
# 26350   Violation
# 27331   Violation
# 27505   Violation
# 27506   Violation
# 28833   Violation
# 29430   Violation
# 33924   Violation
# 34773   Violation
# 35184   Violation
# 41504   Violation
# 42059   Violation
# 44941   Violation
# 47943   Violation
# 48511   Violation
# 51966   Violation
# 56274   Violation
# 57369   Violation
# 64134   Violation
# 64135   Violation
# 67594   Violation
# 67595   Violation
# 71369   Violation
# 75615   Violation
# 106313  Violation
# 106314  Violation

# %%
post_leaks_vioilation_df[
    post_leaks_vioilation_df['req_url']
    .str
    .contains('meta') 
    | post_leaks_vioilation_df['req_url']
        .str.contains('facebook')].count()
# Out:
# init_url        32
# final_url       32
# req_url         32
# req_method      32
# ref_pol_data    32
# post_data       32
# post_leaks      32
# leaks           32
# netloc          32
# path            32
# query           32
# params          32
# fragments       32
# violation       32
# dtype: int64

# %%
# list of post data leaks to tiktok
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('tiktok').fillna(False)]
# Out:
#                                                  init_url  \
# 277                https://www.life360.com/driving-safety
# 280                https://www.life360.com/driving-safety
# 296     https://www.change.org/member?source_location=...
# 297     https://www.change.org/member?source_location=...
# 399                         https://app.life360.com/login
# ...                                                   ...
# 108640          https://www.eventbrite.com/b/local/health
# 108645          https://www.eventbrite.com/b/local/health
# 109378  https://www.discogs.com/group/thread/963554?ev...
# 109379  https://www.discogs.com/group/thread/963554?ev...
# 109380  https://www.discogs.com/group/thread/963554?ev...
#
#                                                 final_url  \
# 277               https://www.life360.com/driving-safety/
# 280               https://www.life360.com/driving-safety/
# 296     https://www.change.org/s/member?source_locatio...
# 297     https://www.change.org/s/member?source_locatio...
# 399           https://app.life360.com/login?web_loc=login
# ...                                                   ...
# 108640  https://www.eventbrite.com/d/ca--santa-clara/e...
# 108645  https://www.eventbrite.com/d/ca--santa-clara/e...
# 109378  https://www.discogs.com/group/thread/963554?ev...
# 109379  https://www.discogs.com/group/thread/963554?ev...
# 109380  https://www.discogs.com/group/thread/963554?ev...
#
#                                               req_url req_method  \
# 277         https://analytics.tiktok.com/api/v2/pixel       POST
# 280     https://analytics.tiktok.com/api/v2/pixel/act       POST
# 296         https://analytics.tiktok.com/api/v2/pixel       POST
# 297     https://analytics.tiktok.com/api/v2/pixel/act       POST
# 399         https://analytics.tiktok.com/api/v2/pixel       POST
# ...                                               ...        ...
# 108640      https://analytics.tiktok.com/api/v2/pixel       POST
# 108645  https://analytics.tiktok.com/api/v2/pixel/act       POST
# 109378      https://analytics.tiktok.com/api/v2/pixel       POST
# 109379  https://analytics.tiktok.com/api/v2/pixel/act       POST
# 109380  https://analytics.tiktok.com/api/v2/pixel/act       POST
#
#                            ref_pol_data  \
# 277     strict-origin-when-cross-origin
# 280     strict-origin-when-cross-origin
# 296     strict-origin-when-cross-origin
# 297     strict-origin-when-cross-origin
# 399                       strict-origin
# ...                                 ...
# 108640  strict-origin-when-cross-origin
# 108645  strict-origin-when-cross-origin
# 109378  strict-origin-when-cross-origin
# 109379  strict-origin-when-cross-origin
# 109380  strict-origin-when-cross-origin
#
#                                                 post_data  \
# 277     {"event":"Pageview","message_id":"messageId-17...
# 280     {"message_id":"messageId-1702157632999-5894138...
# 296     {"event":"Pageview","message_id":"messageId-17...
# 297     {"message_id":"messageId-1702115796023-7889799...
# 399     {"event":"Pageview","message_id":"messageId-17...
# ...                                                   ...
# 108640  {"event":"Pageview","message_id":"messageId-17...
# 108645  {"message_id":"messageId-1702083281103-2993420...
# 109378  {"event":"Pageview","message_id":"messageId-17...
# 109379  {"message_id":"messageId-1702158357927-5548643...
# 109380  {"message_id":"messageId-1702158359588-3868749...
#
#                                                post_leaks       leaks  \
# 277         [('www.life360.com',), ('/driving-safety/',)]  post_leaks
# 280         [('www.life360.com',), ('/driving-safety/',)]  post_leaks
# 296     [('/s/member',), ('www.change.org',), ('source...  post_leaks
# 297     [('/s/member',), ('www.change.org',), ('urlenc...  post_leaks
# 399                   [('app.life360.com',), ('/login',)]  post_leaks
# ...                                                   ...         ...
# 108640  [('/d/ca--santa-clara/events/',), ('www.eventb...  post_leaks
# 108645  [('urlencode', 'www.eventbrite.com'), ('/d/ca-...  post_leaks
# 109378  [('www.discogs.com',), ('/group/thread/963554'...  post_leaks
# 109379  [('www.discogs.com',), ('/group/thread/963554'...  post_leaks
# 109380  [('www.discogs.com',), ('/group/thread/963554'...  post_leaks
#
#                     netloc                        path  \
# 277        www.life360.com            /driving-safety/
# 280        www.life360.com            /driving-safety/
# 296         www.change.org                   /s/member
# 297         www.change.org                   /s/member
# 399        app.life360.com                      /login
# ...                    ...                         ...
# 108640  www.eventbrite.com  /d/ca--santa-clara/events/
# 108645  www.eventbrite.com  /d/ca--santa-clara/events/
# 109378     www.discogs.com        /group/thread/963554
# 109379     www.discogs.com        /group/thread/963554
# 109380     www.discogs.com        /group/thread/963554
#
#                                      query params fragments  violation
# 277                                                          Violation
# 280                                                          Violation
# 296     source_location=member_link_header                   Violation
# 297     source_location=member_link_header                   Violation
# 399                                                          Violation
# ...                                    ...    ...       ...        ...
# 108640                                                       Violation
# 108645                                                       Violation
# 109378                            ev=em_bt                   Violation
# 109379                            ev=em_bt                   Violation
# 109380                            ev=em_bt                   Violation
#
# [435 rows x 14 columns]

# %%
post_leaks_vioilation_df[post_leaks_vioilation_df['req_url'].str.contains('tiktok').fillna(False)].count()
# Out:
# init_url        435
# final_url       435
# req_url         435
# req_method      435
# ref_pol_data    435
# post_data       435
# post_leaks      435
# leaks           435
# netloc          435
# path            435
# query           435
# params          435
# fragments       435
# violation       435
# dtype: int64
